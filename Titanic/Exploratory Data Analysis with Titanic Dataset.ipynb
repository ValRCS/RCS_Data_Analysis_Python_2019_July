# %% [markdown]
# # Exploratory Data Analysis with Titanic dataset

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb

# %%
plt.style.use('fivethirtyeight')
import warnings
warnings.filterwarnings('ignore')
# we need below line for displaying graphis inline (in  a notebook)
# %matplotlib inline

# %%
train_data=pd.read_csv('train.csv')
test_data=pd.read_csv('test.csv')

# %%
train_data.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# 6                            McCarthy, Mr. Timothy J    male  54.0      0
# 7                     Palsson, Master. Gosta Leonard    male   2.0      3
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S
# 5      0            330877   8.4583   NaN        Q
# 6      0             17463  51.8625   E46        S
# 7      1            349909  21.0750   NaN        S
# 8      2            347742  11.1333   NaN        S
# 9      0            237736  30.0708   NaN        C

# %%
train_data.shape
# Out:
# (891, 12)

# %%
test_data.shape
# Out:
# (418, 11)

# %%
train_data.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
test_data.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
train_data.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
sb.countplot('Survived',data=train_data)
plt.show()

# %% [markdown]
# From the above graph it is clear that not many persons survived.
# Out of 891 persons in training dataset only 350, 38.4% of total training dataset survived. We will get more insight of data by exploring more.

# %% [markdown]
# Here we'll explore features

# %%
train_data.groupby(['Sex', 'Survived'])['Survived'].count()
# Out:
# Sex     Survived
# female  0            81
#         1           233
# male    0           468
#         1           109
# Name: Survived, dtype: int64

# %% [markdown]
# It is clear that 233 female survived out of 344. And out of 577 male 109 survived. The survival ratio of female is much greater than that of male. It can be seen clearly in following graph

# %%
train_data[['Sex','Survived']].groupby(['Sex']).mean().plot.bar()
sb.countplot('Sex',hue='Survived',data=train_data,)
plt.show()

# %% [markdown]
# 'Sex' is very interesting feature. Isn't it? Let's explore more features

# %%
# Pclass is a column name and we color by another column 'Survived'
sb.countplot('Pclass', hue='Survived', data=train_data)
plt.title('Pclass: Survived vs Dead')
plt.show()

# %% [markdown]
# Wow.... That looks amazing. It is usually said that Money can't buy Everything, But it is clearly seen that pasangers of Class 1 are given high priority while Rescue. There are greater number of passangers in Class 3 than Class 1 and Class 2 but very few, almost 25% in Class 3 survived. In Class 2, survivail and non-survival rate is 49% and 51% approx.
# While in Class 1 almost 68% people survived. So money and status matters here.
#
# Let's dive in again into data to check more interesting observations.

# %%
# cmap is a color map setting 
pd.crosstab([train_data.Sex,train_data.Survived],train_data.Pclass,margins=True).style.background_gradient(cmap='summer_r')
# Out:
# <style  type="text/css" >
#     #T_3712972e_885f_11e9_9874_48f17f90ffa0row0_col0 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_3712972e_885f_11e9_9874_48f17f90ffa0row0_col1 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_3712972e_885f_11e9_9874_48f17f90ffa0row0_col2 {
#             background-color:  #f1f866;
#             color:  #000000;
#         }    #T_3712972e_885f_11e9_9874_48f17f90ffa0row0_col3 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_3712972e_885f_11e9_9874_48f17f90ffa0row1_col0 {
#             background-color:  #96cb66;
#             color:  #000000;
#         }    #T_3712972e_885f_11e9_9874_48f17f90ffa0row1_col1 {
#             background-color:  #a3d166;
#             color:  #000000;
#         }    #T_3712972e_885f_11e9_9874_48f17f90ffa0row1_col2 {
#             background-color:  #f1f866;
#             color:  #000000;
#         }    #T_3712972e_885f_11e9_9874_48f17f90ffa0row1_col3 {
#             background-color:  #cfe766;
#             color:  #000000;
#         }    #T_3712972e_885f_11e9_9874_48f17f90ffa0row2_col0 {
#             background-color:  #a7d366;
#             color:  #000000;
#         }    #T_3712972e_885f_11e9_9874_48f17f90ffa0row2_col1 {
#             background-color:  #85c266;
#             color:  #000000;
#         }    #T_3712972e_885f_11e9_9874_48f17f90ffa0row2_col2 {
#             background-color:  #6eb666;
#             color:  #000000;
#         }    #T_3712972e_885f_11e9_9874_48f17f90ffa0row2_col3 {
#             background-color:  #85c266;
#             color:  #000000;
#         }    #T_3712972e_885f_11e9_9874_48f17f90ffa0row3_col0 {
#             background-color:  #cde666;
#             color:  #000000;
#         }    #T_3712972e_885f_11e9_9874_48f17f90ffa0row3_col1 {
#             background-color:  #f0f866;
#             color:  #000000;
#         }    #T_3712972e_885f_11e9_9874_48f17f90ffa0row3_col2 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_3712972e_885f_11e9_9874_48f17f90ffa0row3_col3 {
#             background-color:  #f7fb66;
#             color:  #000000;
#         }    #T_3712972e_885f_11e9_9874_48f17f90ffa0row4_col0 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_3712972e_885f_11e9_9874_48f17f90ffa0row4_col1 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_3712972e_885f_11e9_9874_48f17f90ffa0row4_col2 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_3712972e_885f_11e9_9874_48f17f90ffa0row4_col3 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }</style><table id="T_3712972e_885f_11e9_9874_48f17f90ffa0" ><thead>    <tr>        <th class="blank" ></th>        <th class="index_name level0" >Pclass</th>        <th class="col_heading level0 col0" >1</th>        <th class="col_heading level0 col1" >2</th>        <th class="col_heading level0 col2" >3</th>        <th class="col_heading level0 col3" >All</th>    </tr>    <tr>        <th class="index_name level0" >Sex</th>        <th class="index_name level1" >Survived</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_3712972e_885f_11e9_9874_48f17f90ffa0level0_row0" class="row_heading level0 row0" rowspan=2>female</th>
#                         <th id="T_3712972e_885f_11e9_9874_48f17f90ffa0level1_row0" class="row_heading level1 row0" >0</th>
#                         <td id="T_3712972e_885f_11e9_9874_48f17f90ffa0row0_col0" class="data row0 col0" >3</td>
#                         <td id="T_3712972e_885f_11e9_9874_48f17f90ffa0row0_col1" class="data row0 col1" >6</td>
#                         <td id="T_3712972e_885f_11e9_9874_48f17f90ffa0row0_col2" class="data row0 col2" >72</td>
#                         <td id="T_3712972e_885f_11e9_9874_48f17f90ffa0row0_col3" class="data row0 col3" >81</td>
#             </tr>
#             <tr>
#                                 <th id="T_3712972e_885f_11e9_9874_48f17f90ffa0level1_row1" class="row_heading level1 row1" >1</th>
#                         <td id="T_3712972e_885f_11e9_9874_48f17f90ffa0row1_col0" class="data row1 col0" >91</td>
#                         <td id="T_3712972e_885f_11e9_9874_48f17f90ffa0row1_col1" class="data row1 col1" >70</td>
#                         <td id="T_3712972e_885f_11e9_9874_48f17f90ffa0row1_col2" class="data row1 col2" >72</td>
#                         <td id="T_3712972e_885f_11e9_9874_48f17f90ffa0row1_col3" class="data row1 col3" >233</td>
#             </tr>
#             <tr>
#                         <th id="T_3712972e_885f_11e9_9874_48f17f90ffa0level0_row2" class="row_heading level0 row2" rowspan=2>male</th>
#                         <th id="T_3712972e_885f_11e9_9874_48f17f90ffa0level1_row2" class="row_heading level1 row2" >0</th>
#                         <td id="T_3712972e_885f_11e9_9874_48f17f90ffa0row2_col0" class="data row2 col0" >77</td>
#                         <td id="T_3712972e_885f_11e9_9874_48f17f90ffa0row2_col1" class="data row2 col1" >91</td>
#                         <td id="T_3712972e_885f_11e9_9874_48f17f90ffa0row2_col2" class="data row2 col2" >300</td>
#                         <td id="T_3712972e_885f_11e9_9874_48f17f90ffa0row2_col3" class="data row2 col3" >468</td>
#             </tr>
#             <tr>
#                                 <th id="T_3712972e_885f_11e9_9874_48f17f90ffa0level1_row3" class="row_heading level1 row3" >1</th>
#                         <td id="T_3712972e_885f_11e9_9874_48f17f90ffa0row3_col0" class="data row3 col0" >45</td>
#                         <td id="T_3712972e_885f_11e9_9874_48f17f90ffa0row3_col1" class="data row3 col1" >17</td>
#                         <td id="T_3712972e_885f_11e9_9874_48f17f90ffa0row3_col2" class="data row3 col2" >47</td>
#                         <td id="T_3712972e_885f_11e9_9874_48f17f90ffa0row3_col3" class="data row3 col3" >109</td>
#             </tr>
#             <tr>
#                         <th id="T_3712972e_885f_11e9_9874_48f17f90ffa0level0_row4" class="row_heading level0 row4" >All</th>
#                         <th id="T_3712972e_885f_11e9_9874_48f17f90ffa0level1_row4" class="row_heading level1 row4" ></th>
#                         <td id="T_3712972e_885f_11e9_9874_48f17f90ffa0row4_col0" class="data row4 col0" >216</td>
#                         <td id="T_3712972e_885f_11e9_9874_48f17f90ffa0row4_col1" class="data row4 col1" >184</td>
#                         <td id="T_3712972e_885f_11e9_9874_48f17f90ffa0row4_col2" class="data row4 col2" >491</td>
#                         <td id="T_3712972e_885f_11e9_9874_48f17f90ffa0row4_col3" class="data row4 col3" >891</td>
#             </tr>
#     </tbody></table>

# %%
sb.factorplot('Pclass', 'Survived', hue='Sex', data=train_data)
plt.show()

# %% [markdown]
# I use FactorPlot and CrossTab here because with these plots categorical variables can easily be visualized. Looking at FactorPlot and CrossTab, it is clear that women survival rate in Class 1 is about 95-96%, as only 3 out of 94 women died. So, it is now more clear that irrespective of Class, women are given first priority during Rescue. Because survival rate for men in even Class 1 is also very low.
# From this conclusion, PClass is also a important feature.

# %%
print('Oldest person Survived was of:',train_data['Age'].max())
print('Youngest person Survived was of:',train_data['Age'].min())
print('Average person Survived was of:',train_data['Age'].mean())
# Out:
# Oldest person Survived was of: 80.0
# Youngest person Survived was of: 0.42
# Average person Survived was of: 29.69911764705882

# %%
f,ax=plt.subplots(1,2,figsize=(18,8))
sb.violinplot('Pclass','Age',hue='Survived',data=train_data,split=True,ax=ax[0])
ax[0].set_title('PClass and Age vs Survived')
ax[0].set_yticks(range(0,110,10))
sb.violinplot("Sex","Age", hue="Survived", data=train_data,split=True,ax=ax[1])
ax[1].set_title('Sex and Age vs Survived')
ax[1].set_yticks(range(0,110,10))
plt.show()

# %% [markdown]
# From above violen plots, following observations are clear,
# 1) The no of children is increasing from Class 1 to 3, the number of children in Class 3 is greater than other two.
# 2) Survival rate of children, for age 10 and below is good irrespective of Class
# 3) Survival rate between age 20-30 is well and is quite better for women.
#
# Now, in Age feature we have 177 null values filled with NaN. We have to deal with it. But we can't enter mean of age in every NaN column, because our average/mean is 29 and we cannot put 29 for a child or some olde man. So we have to discover something better.
# Let's do something more interesting with dataset by exploring more.

# %% [markdown]
# What is, if I look at 'Name' feature, It looks interesting. Let's check it....

# %%
train_data['Initial']=0
for i in train_data:
    train_data['Initial']=train_data.Name.str.extract('([A-Za-z]+)\.') #extracting Name initials

# %%
train_data['First']=""

# %%
for i in train_data:
    train_data['First']=train_data.Name.str.extract('[A-Za-z]+\. ([A-Za-z]+)') #extracting First Name

# %%
train_data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked Initial    First
# 0      0         A/5 21171   7.2500   NaN        S      Mr     Owen
# 1      0          PC 17599  71.2833   C85        C     Mrs     John
# 2      0  STON/O2. 3101282   7.9250   NaN        S    Miss    Laina
# 3      0            113803  53.1000  C123        S     Mrs  Jacques
# 4      0            373450   8.0500   NaN        S      Mr  William

# %%
train_data['First'].isnull().sum()
# Out:
# 16

# %%
train_data[train_data.First.isnull()]
# Out:
#      PassengerId  Survived  Pclass  \
# 15            16         1       2
# 66            67         1       2
# 166          167         1       1
# 190          191         1       2
# 259          260         1       2
# 272          273         1       2
# 327          328         1       2
# 362          363         0       3
# 367          368         1       3
# 483          484         1       3
# 516          517         1       2
# 556          557         1       1
# 564          565         0       3
# 772          773         0       2
# 823          824         1       3
# 865          866         1       2
#
#                                                   Name     Sex   Age  SibSp  \
# 15                    Hewlett, Mrs. (Mary D Kingcome)   female  55.0      0
# 66                        Nye, Mrs. (Elizabeth Ramell)  female  29.0      0
# 166             Chibnall, Mrs. (Edith Martha Bowerman)  female   NaN      0
# 190                                Pinsky, Mrs. (Rosa)  female  32.0      0
# 259                        Parrish, Mrs. (Lutie Davis)  female  50.0      0
# 272          Mellinger, Mrs. (Elizabeth Anne Maidment)  female  41.0      0
# 327                            Ball, Mrs. (Ada E Hall)  female  36.0      0
# 362                    Barbara, Mrs. (Catherine David)  female  45.0      0
# 367                     Moussa, Mrs. (Mantoura Boulos)  female   NaN      0
# 483                             Turkula, Mrs. (Hedwig)  female  63.0      0
# 516                       Lemore, Mrs. (Amelia Milley)  female  34.0      0
# 556  Duff Gordon, Lady. (Lucille Christiana Sutherl...  female  48.0      1
# 564                     Meanwell, Miss. (Marion Ogden)  female   NaN      0
# 772                                  Mack, Mrs. (Mary)  female  57.0      0
# 823                                 Moor, Mrs. (Beila)  female  27.0      0
# 865                           Bystrom, Mrs. (Karolina)  female  42.0      0
#
#      Parch             Ticket     Fare Cabin Embarked Initial First
# 15       0             248706  16.0000   NaN        S     Mrs   NaN
# 66       0         C.A. 29395  10.5000   F33        S     Mrs   NaN
# 166      1             113505  55.0000   E33        S     Mrs   NaN
# 190      0             234604  13.0000   NaN        S     Mrs   NaN
# 259      1             230433  26.0000   NaN        S     Mrs   NaN
# 272      1             250644  19.5000   NaN        S     Mrs   NaN
# 327      0              28551  13.0000     D        S     Mrs   NaN
# 362      1               2691  14.4542   NaN        C     Mrs   NaN
# 367      0               2626   7.2292   NaN        C     Mrs   NaN
# 483      0               4134   9.5875   NaN        S     Mrs   NaN
# 516      0         C.A. 34260  10.5000   F33        S     Mrs   NaN
# 556      0              11755  39.6000   A16        C    Lady   NaN
# 564      0  SOTON/O.Q. 392087   8.0500   NaN        S    Miss   NaN
# 772      0        S.O./P.P. 3  10.5000   E77        S     Mrs   NaN
# 823      1             392096  12.4750  E121        S     Mrs   NaN
# 865      0             236852  13.0000   NaN        S     Mrs   NaN

# %%
train_data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked Initial
# 0      0         A/5 21171   7.2500   NaN        S      Mr
# 1      0          PC 17599  71.2833   C85        C     Mrs
# 2      0  STON/O2. 3101282   7.9250   NaN        S    Miss
# 3      0            113803  53.1000  C123        S     Mrs
# 4      0            373450   8.0500   NaN        S      Mr

# %%
pd.crosstab(train_data.Initial,train_data.Sex).T.style.background_gradient(cmap='summer_r')
# Out:
# <style  type="text/css" >
#     #T_1b535a6c_8861_11e9_829e_48f17f90ffa0row0_col0 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_1b535a6c_8861_11e9_829e_48f17f90ffa0row0_col1 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_1b535a6c_8861_11e9_829e_48f17f90ffa0row0_col2 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_1b535a6c_8861_11e9_829e_48f17f90ffa0row0_col3 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_1b535a6c_8861_11e9_829e_48f17f90ffa0row0_col4 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_1b535a6c_8861_11e9_829e_48f17f90ffa0row0_col5 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_1b535a6c_8861_11e9_829e_48f17f90ffa0row0_col6 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_1b535a6c_8861_11e9_829e_48f17f90ffa0row0_col7 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_1b535a6c_8861_11e9_829e_48f17f90ffa0row0_col8 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_1b535a6c_8861_11e9_829e_48f17f90ffa0row0_col9 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_1b535a6c_8861_11e9_829e_48f17f90ffa0row0_col10 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_1b535a6c_8861_11e9_829e_48f17f90ffa0row0_col11 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_1b535a6c_8861_11e9_829e_48f17f90ffa0row0_col12 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_1b535a6c_8861_11e9_829e_48f17f90ffa0row0_col13 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_1b535a6c_8861_11e9_829e_48f17f90ffa0row0_col14 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_1b535a6c_8861_11e9_829e_48f17f90ffa0row0_col15 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_1b535a6c_8861_11e9_829e_48f17f90ffa0row0_col16 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_1b535a6c_8861_11e9_829e_48f17f90ffa0row1_col0 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_1b535a6c_8861_11e9_829e_48f17f90ffa0row1_col1 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_1b535a6c_8861_11e9_829e_48f17f90ffa0row1_col2 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_1b535a6c_8861_11e9_829e_48f17f90ffa0row1_col3 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_1b535a6c_8861_11e9_829e_48f17f90ffa0row1_col4 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_1b535a6c_8861_11e9_829e_48f17f90ffa0row1_col5 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_1b535a6c_8861_11e9_829e_48f17f90ffa0row1_col6 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_1b535a6c_8861_11e9_829e_48f17f90ffa0row1_col7 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_1b535a6c_8861_11e9_829e_48f17f90ffa0row1_col8 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_1b535a6c_8861_11e9_829e_48f17f90ffa0row1_col9 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_1b535a6c_8861_11e9_829e_48f17f90ffa0row1_col10 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_1b535a6c_8861_11e9_829e_48f17f90ffa0row1_col11 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_1b535a6c_8861_11e9_829e_48f17f90ffa0row1_col12 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_1b535a6c_8861_11e9_829e_48f17f90ffa0row1_col13 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_1b535a6c_8861_11e9_829e_48f17f90ffa0row1_col14 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_1b535a6c_8861_11e9_829e_48f17f90ffa0row1_col15 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_1b535a6c_8861_11e9_829e_48f17f90ffa0row1_col16 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }</style><table id="T_1b535a6c_8861_11e9_829e_48f17f90ffa0" ><thead>    <tr>        <th class="index_name level0" >Initial</th>        <th class="col_heading level0 col0" >Capt</th>        <th class="col_heading level0 col1" >Col</th>        <th class="col_heading level0 col2" >Countess</th>        <th class="col_heading level0 col3" >Don</th>        <th class="col_heading level0 col4" >Dr</th>        <th class="col_heading level0 col5" >Jonkheer</th>        <th class="col_heading level0 col6" >Lady</th>        <th class="col_heading level0 col7" >Major</th>        <th class="col_heading level0 col8" >Master</th>        <th class="col_heading level0 col9" >Miss</th>        <th class="col_heading level0 col10" >Mlle</th>        <th class="col_heading level0 col11" >Mme</th>        <th class="col_heading level0 col12" >Mr</th>        <th class="col_heading level0 col13" >Mrs</th>        <th class="col_heading level0 col14" >Ms</th>        <th class="col_heading level0 col15" >Rev</th>        <th class="col_heading level0 col16" >Sir</th>    </tr>    <tr>        <th class="index_name level0" >Sex</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_1b535a6c_8861_11e9_829e_48f17f90ffa0level0_row0" class="row_heading level0 row0" >female</th>
#                         <td id="T_1b535a6c_8861_11e9_829e_48f17f90ffa0row0_col0" class="data row0 col0" >0</td>
#                         <td id="T_1b535a6c_8861_11e9_829e_48f17f90ffa0row0_col1" class="data row0 col1" >0</td>
#                         <td id="T_1b535a6c_8861_11e9_829e_48f17f90ffa0row0_col2" class="data row0 col2" >1</td>
#                         <td id="T_1b535a6c_8861_11e9_829e_48f17f90ffa0row0_col3" class="data row0 col3" >0</td>
#                         <td id="T_1b535a6c_8861_11e9_829e_48f17f90ffa0row0_col4" class="data row0 col4" >1</td>
#                         <td id="T_1b535a6c_8861_11e9_829e_48f17f90ffa0row0_col5" class="data row0 col5" >0</td>
#                         <td id="T_1b535a6c_8861_11e9_829e_48f17f90ffa0row0_col6" class="data row0 col6" >1</td>
#                         <td id="T_1b535a6c_8861_11e9_829e_48f17f90ffa0row0_col7" class="data row0 col7" >0</td>
#                         <td id="T_1b535a6c_8861_11e9_829e_48f17f90ffa0row0_col8" class="data row0 col8" >0</td>
#                         <td id="T_1b535a6c_8861_11e9_829e_48f17f90ffa0row0_col9" class="data row0 col9" >182</td>
#                         <td id="T_1b535a6c_8861_11e9_829e_48f17f90ffa0row0_col10" class="data row0 col10" >2</td>
#                         <td id="T_1b535a6c_8861_11e9_829e_48f17f90ffa0row0_col11" class="data row0 col11" >1</td>
#                         <td id="T_1b535a6c_8861_11e9_829e_48f17f90ffa0row0_col12" class="data row0 col12" >0</td>
#                         <td id="T_1b535a6c_8861_11e9_829e_48f17f90ffa0row0_col13" class="data row0 col13" >125</td>
#                         <t

# %% [markdown]
# There are many names which are not relevant like Mr, Mrs etc. So I will replace them with some relevant names,

# %%
train_data.groupby('Initial')['Age'].mean()
# Out:
# Initial
# Capt        70.000000
# Col         58.000000
# Countess    33.000000
# Don         40.000000
# Dr          42.000000
# Jonkheer    38.000000
# Lady        48.000000
# Major       48.500000
# Master       4.574167
# Miss        21.773973
# Mlle        24.000000
# Mme         24.000000
# Mr          32.368090
# Mrs         35.898148
# Ms          28.000000
# Rev         43.166667
# Sir         49.000000
# Name: Age, dtype: float64

# %%
train_data['Initial'].replace(['Mlle','Mme','Ms','Dr','Major','Lady','Countess',
                               'Jonkheer','Col','Rev','Capt','Sir','Don'],['Miss',
                                'Miss','Miss','Mr','Mr','Mrs','Mrs','Other','Other','Other','Mr','Mr','Mr'],inplace=True)

# %%
train_data.groupby('Initial')['Age'].mean()
# Out:
# Initial
# Capt        70.000000
# Col         58.000000
# Countess    33.000000
# Don         40.000000
# Dr          42.000000
# Jonkheer    38.000000
# Lady        48.000000
# Major       48.500000
# Master       4.574167
# Miss        21.773973
# Mlle        24.000000
# Mme         24.000000
# Mr          32.368090
# Mrs         35.898148
# Ms          28.000000
# Rev         43.166667
# Sir         49.000000
# Name: Age, dtype: float64

# %%
train_data.loc[(train_data.Age.isnull()) & (train_data.Initial=='Mr'),'Age']=33
train_data.loc[(train_data.Age.isnull()) & (train_data.Initial=='Mrs'),'Age']=36
train_data.loc[(train_data.Age.isnull()) & (train_data.Initial=='Master'),'Age']=5
train_data.loc[(train_data.Age.isnull()) & (train_data.Initial=='Miss'),'Age']=22
train_data.loc[(train_data.Age.isnull()) & (train_data.Initial=='Other'),'Age']=46

# %%
train_data.Age.isnull().any()
# Out:
# False

# %%
f,ax=plt.subplots(1,2,figsize=(20,20))
train_data[train_data['Survived']==0].Age.plot.hist(ax=ax[0],bins=20,edgecolor='black',color='red')
ax[0].set_title('Survived = 0')
x1=list(range(0,85,5))
ax[0].set_xticks(x1)
train_data[train_data['Survived']==1].Age.plot.hist(ax=ax[1],bins=20,edgecolor='black',color='green')
x2=list(range(0,85,5))
ax[1].set_xticks(x2)
ax[1].set_title('Survived = 1')
plt.show()

# %% [markdown]
# From the above plots, I found the following observations

# %% [markdown]
# (1) First priority during Rescue is given to children and women, as the persons<5 are save by large numbers
# (2) The oldest saved passanger is of 80
# (3) The most deaths were between 30-40

# %%
sb.factorplot('Pclass','Survived',col='Initial',data=train_data)
plt.show()

# %% [markdown]
# From the above FactorPlots it is Clearly seen that women and children were saved irrespective of PClass

# %% [markdown]
# Let's explore some more

# %% [markdown]
# # Feature: SibSip

# %% [markdown]
# SibSip feature indicates that whether a person is alone or with his family. Siblings=brother,sister, etc
# and Spouse= husband,wife

# %%
pd.crosstab([train_data.SibSp],train_data.Survived).style.background_gradient('summer_r')
# Out:
# <style  type="text/css" >
#     #T_80a0851c_8861_11e9_a04f_48f17f90ffa0row0_col0 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_80a0851c_8861_11e9_a04f_48f17f90ffa0row0_col1 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_80a0851c_8861_11e9_a04f_48f17f90ffa0row1_col0 {
#             background-color:  #c4e266;
#             color:  #000000;
#         }    #T_80a0851c_8861_11e9_a04f_48f17f90ffa0row1_col1 {
#             background-color:  #77bb66;
#             color:  #000000;
#         }    #T_80a0851c_8861_11e9_a04f_48f17f90ffa0row2_col0 {
#             background-color:  #f9fc66;
#             color:  #000000;
#         }    #T_80a0851c_8861_11e9_a04f_48f17f90ffa0row2_col1 {
#             background-color:  #f0f866;
#             color:  #000000;
#         }    #T_80a0851c_8861_11e9_a04f_48f17f90ffa0row3_col0 {
#             background-color:  #fbfd66;
#             color:  #000000;
#         }    #T_80a0851c_8861_11e9_a04f_48f17f90ffa0row3_col1 {
#             background-color:  #fbfd66;
#             color:  #000000;
#         }    #T_80a0851c_8861_11e9_a04f_48f17f90ffa0row4_col0 {
#             background-color:  #f9fc66;
#             color:  #000000;
#         }    #T_80a0851c_8861_11e9_a04f_48f17f90ffa0row4_col1 {
#             background-color:  #fcfe66;
#             color:  #000000;
#         }    #T_80a0851c_8861_11e9_a04f_48f17f90ffa0row5_col0 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_80a0851c_8861_11e9_a04f_48f17f90ffa0row5_col1 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_80a0851c_8861_11e9_a04f_48f17f90ffa0row6_col0 {
#             background-color:  #fefe66;
#             color:  #000000;
#         }    #T_80a0851c_8861_11e9_a04f_48f17f90ffa0row6_col1 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }</style><table id="T_80a0851c_8861_11e9_a04f_48f17f90ffa0" ><thead>    <tr>        <th class="index_name level0" >Survived</th>        <th class="col_heading level0 col0" >0</th>        <th class="col_heading level0 col1" >1</th>    </tr>    <tr>        <th class="index_name level0" >SibSp</th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_80a0851c_8861_11e9_a04f_48f17f90ffa0level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_80a0851c_8861_11e9_a04f_48f17f90ffa0row0_col0" class="data row0 col0" >398</td>
#                         <td id="T_80a0851c_8861_11e9_a04f_48f17f90ffa0row0_col1" class="data row0 col1" >210</td>
#             </tr>
#             <tr>
#                         <th id="T_80a0851c_8861_11e9_a04f_48f17f90ffa0level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_80a0851c_8861_11e9_a04f_48f17f90ffa0row1_col0" class="data row1 col0" >97</td>
#                         <td id="T_80a0851c_8861_11e9_a04f_48f17f90ffa0row1_col1" class="data row1 col1" >112</td>
#             </tr>
#             <tr>
#                         <th id="T_80a0851c_8861_11e9_a04f_48f17f90ffa0level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_80a0851c_8861_11e9_a04f_48f17f90ffa0row2_col0" class="data row2 col0" >15</td>
#                         <td id="T_80a0851c_8861_11e9_a04f_48f17f90ffa0row2_col1" class="data row2 col1" >13</td>
#             </tr>
#             <tr>
#                         <th id="T_80a0851c_8861_11e9_a04f_48f17f90ffa0level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_80a0851c_8861_11e9_a04f_48f17f90ffa0row3_col0" class="data row3 col0" >12</td>
#                         <td id="T_80a0851c_8861_11e9_a04f_48f17f90ffa0row3_col1" class="data row3 col1" >4</td>
#             </tr>
#             <tr>
#                         <th id="T_80a0851c_8861_11e9_a04f_48f17f90ffa0level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_80a0851c_8861_11e9_a04f_48f17f90ffa0row4_col0" class="data row4 col0" >15</td>
#                         <td id="T_80a0851c_8861_11e9_a04f_48f17f90ffa0row4_col1" class="data row4 col1" >3</td>
#             </tr>
#             <tr>
#                         <th id="T_80a0851c_8861_11e9_a04f_48f17f90ffa0level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_80a0851c_8861_11e9_a04f_48f17f90ffa0row5_col0" class="data row5 col0" >5</td>
#                         <td id="T_80a0851c_8861_11e9_a04f_48f17f90ffa0row5_col1" class="data row5 col1" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_80a0851c_8861_11e9_a04f_48f17f90ffa0level0_row6" class="row_heading level0 row6" >8</th>
#                         <td id="T_80a0851c_8861_11e9_a04f_48f17f90ffa0row6_col0" class="data row6 col0" >7</td>
#                         <td id="T_80a0851c_8861_11e9_a04f_48f17f90ffa0row6_col1" class="data row6 col1" >0</td>
#             </tr>
#     </tbody></table>

# %%
f,ax=plt.subplots(1,2,figsize=(20,8))
sb.barplot('SibSp','Survived', data=train_data,ax=ax[0])
ax[0].set_title('SipSp vs Survived in BarPlot')
sb.factorplot('SibSp','Survived', data=train_data,ax=ax[1])
ax[1].set_title('SibSp vs Survived in FactorPlot')
plt.close(2)
plt.show()

# %%
pd.crosstab(train_data.SibSp,train_data.Pclass).style.background_gradient('summer_r')
# Out:
# <style  type="text/css" >
#     #T_905f601e_8861_11e9_bee4_48f17f90ffa0row0_col0 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_905f601e_8861_11e9_bee4_48f17f90ffa0row0_col1 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_905f601e_8861_11e9_bee4_48f17f90ffa0row0_col2 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_905f601e_8861_11e9_bee4_48f17f90ffa0row1_col0 {
#             background-color:  #7bbd66;
#             color:  #000000;
#         }    #T_905f601e_8861_11e9_bee4_48f17f90ffa0row1_col1 {
#             background-color:  #8ac466;
#             color:  #000000;
#         }    #T_905f601e_8861_11e9_bee4_48f17f90ffa0row1_col2 {
#             background-color:  #c6e266;
#             color:  #000000;
#         }    #T_905f601e_8861_11e9_bee4_48f17f90ffa0row2_col0 {
#             background-color:  #f6fa66;
#             color:  #000000;
#         }    #T_905f601e_8861_11e9_bee4_48f17f90ffa0row2_col1 {
#             background-color:  #eef666;
#             color:  #000000;
#         }    #T_905f601e_8861_11e9_bee4_48f17f90ffa0row2_col2 {
#             background-color:  #f8fc66;
#             color:  #000000;
#         }    #T_905f601e_8861_11e9_bee4_48f17f90ffa0row3_col0 {
#             background-color:  #fafc66;
#             color:  #000000;
#         }    #T_905f601e_8861_11e9_bee4_48f17f90ffa0row3_col1 {
#             background-color:  #fdfe66;
#             color:  #000000;
#         }    #T_905f601e_8861_11e9_bee4_48f17f90ffa0row3_col2 {
#             background-color:  #fafc66;
#             color:  #000000;
#         }    #T_905f601e_8861_11e9_bee4_48f17f90ffa0row4_col0 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_905f601e_8861_11e9_bee4_48f17f90ffa0row4_col1 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_905f601e_8861_11e9_bee4_48f17f90ffa0row4_col2 {
#             background-color:  #f6fa66;
#             color:  #000000;
#         }    #T_905f601e_8861_11e9_bee4_48f17f90ffa0row5_col0 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_905f601e_8861_11e9_bee4_48f17f90ffa0row5_col1 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_905f601e_8861_11e9_bee4_48f17f90ffa0row5_col2 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_905f601e_8861_11e9_bee4_48f17f90ffa0row6_col0 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_905f601e_8861_11e9_bee4_48f17f90ffa0row6_col1 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_905f601e_8861_11e9_bee4_48f17f90ffa0row6_col2 {
#             background-color:  #fefe66;
#             color:  #000000;
#         }</style><table id="T_905f601e_8861_11e9_bee4_48f17f90ffa0" ><thead>    <tr>        <th class="index_name level0" >Pclass</th>        <th class="col_heading level0 col0" >1</th>        <th class="col_heading level0 col1" >2</th>        <th class="col_heading level0 col2" >3</th>    </tr>    <tr>        <th class="index_name level0" >SibSp</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_905f601e_8861_11e9_bee4_48f17f90ffa0level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_905f601e_8861_11e9_bee4_48f17f90ffa0row0_col0" class="data row0 col0" >137</td>
#                         <td id="T_905f601e_8861_11e9_bee4_48f17f90ffa0row0_col1" class="data row0 col1" >120</td>
#                         <td id="T_905f601e_8861_11e9_bee4_48f17f90ffa0row0_col2" class="data row0 col2" >351</td>
#             </tr>
#             <tr>
#                         <th id="T_905f601e_8861_11e9_bee4_48f17f90ffa0level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_905f601e_8861_11e9_bee4_48f17f90ffa0row1_col0" class="data row1 col0" >71</td>
#                         <td id="T_905f601e_8861_11e9_bee4_48f17f90ffa0row1_col1" class="data row1 col1" >55</td>
#                         <td id="T_905f601e_8861_11e9_bee4_48f17f90ffa0row1_col2" class="data row1 col2" >83</td>
#             </tr>
#             <tr>
#                         <th id="T_905f601e_8861_11e9_bee4_48f17f90ffa0level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_905f601e_8861_11e9_bee4_48f17f90ffa0row2_col0" class="data row2 col0" >5</td>
#                         <td id="T_905f601e_8861_11e9_bee4_48f17f90ffa0row2_col1" class="data row2 col1" >8</td>
#                         <td id="T_905f601e_8861_11e9_bee4_48f17f90ffa0row2_col2" class="data row2 col2" >15</td>
#             </tr>
#             <tr>
#                         <th id="T_905f601e_8861_11e9_bee4_48f17f90ffa0level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_905f601e_8861_11e9_bee4_48f17f90ffa0row3_col0" class="data row3 col0" >3</td>
#                         <td id="T_905f601e_8861_11e9_bee4_48f17f90ffa0row3_col1" class="data row3 col1" >1</td>
#                         <td id="T_905f601e_8861_11e9_bee4_48f17f90ffa0row3_col2" class="data row3 col2" >12</td>
#             </tr>
#             <tr>
#                         <th id="T_905f601e_8861_11e9_bee4_48f17f90ffa0level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_905f601e_8861_11e9_bee4_48f17f90ffa0row4_col0" class="data row4 col0" >0</td>
#                         <td id="T_905f601e_8861_11e9_bee4_48f17f90ffa0row4_col1" class="data row4 col1" >0</td>
#                         <td id="T_905f601e_8861_11e9_bee4_48f17f90ffa0row4_col2" class="data row4 col2" >18</td>
#             </tr>
#             <tr>
#                         <th id="T_905f601e_8861_11e9_bee4_48f17f90ffa0level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_905f601e_8861_11e9_bee4_48f17f90ffa0row5_col0" class="data row5 col0" >0</td>
#                         <td id="T_905f601e_8861_11e9_bee4_48f17f90ffa0row5_col1" class="data row5 col1" >0</td>
#                         <td id="T_905f601e_8861_11e9_bee4_48f17f90ffa0row5_col2" class="data row5 col2" >5</td>
#             </tr>
#             <tr>
#                         <th id="T_905f601e_8861_11e9_bee4_48f17f90ffa0level0_row6" class="row_heading level0 row6" >8</th>
#                         <td id="T_905f601e_8861_11e9_bee4_48f17f90ffa0row6_col0" class="data row6 col0" >0</td>
#                         <td id="T_905f601e_8861_11e9_bee4_48f17f90ffa0row6_col1" class="data row6 col1" >0</td>
#                         <td id="T_905f601e_8861_11e9_bee4_48f17f90ffa0row6_col2" class="data row6 col2" >7</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# There are many interesting facts with this feature. Barplot and FactorPlot shows that if a passanger is alone in ship with no siblings, survival rate is 34.5%. The graph decreases as no of siblings increase. This is interesting because, If I have a family onboard, I will save them instead of saving myself. But there's something wrong, the survival rate for families with 5-8 members is 0%. Is this because of PClass?
# Yes this is PClass,  The crosstab shows that Person with SibSp>3 were all in Pclass3. It is imminent that all the large families in Pclass3(>3) died.

# %% [markdown]
# That are some interesting facts we have observed with Titanic dataset.
