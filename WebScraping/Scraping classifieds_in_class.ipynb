# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup

# %%
# if we did no have requests then we would install it manually:
# !pip install requests from Jupyter notebook
# pip install requests from command line

# %%
url = "https://www.ss.com/lv/real-estate/wood/"

# %%
req = requests.get(url)
req.status_code
# Out:
# 200

# %%
len(req.text)
# Out:
# 61442

# %%
req.text[:100]
# Out:
# '<!DOCTYPE html>\r\n<HTML><HEAD>\r\n<title>SS.COM Nekustamais īpašums - Mežs - Sludinājumi</title>\r\n<meta'

# %%
req.url
# Out:
# 'https://www.ss.com/lv/real-estate/wood/'

# %%
req.cookies
# Out:
# <RequestsCookieJar[]>

# %%
req.headers
# Out:
# {'Server': 'Internet', 'Date': 'Sat, 01 Jun 2019 07:18:36 GMT', 'Content-Type': 'text/html; charset=UTF-8', 'Last-Modified': 'Sat, 01 Jun 2019 07:07:56 GMT', 'Transfer-Encoding': 'chunked', 'Connection': 'keep-alive', 'Vary': 'Accept-Encoding', 'ETag': 'W/"5cf2244c-f109"', 'Expires': '-1', 'Cache-Control': 'must-revalidate', 'Strict-Transport-Security': 'max-age=63072000; includeSubdomains; preload', 'Content-Encoding': 'gzip'}

# %%
req.content[:30]
# Out:
# b'<!DOCTYPE html>\r\n<HTML><HEAD>\r'

# %%
# lxml parser is an optional parser which is supposed to work better than built in Python html parser
soup = BeautifulSoup(req.text, 'lxml')
soup.title
# Out:
# <title>SS.COM Nekustamais īpašums - Mežs - Sludinājumi</title>

# %%
soup.body
# Out:
# <body bgcolor="#FFFFFF" class="body" onload="window.defaultStatus='Sludinājumi - SS.COM';">
# <div id="left_banner" style="position:absolute;height:0px;width:0px;top:15px;left:10px;z-index:0;" z-index="0"></div>
# <div align="center">
# <div class="page_header page_bg" id="main_table">
# <div id="sslogin" z-index="20"></div>
# <span class="page_header_head"><a href="/" title="Sludinājumi"><img alt="Sludinājumi" border="0" class="page_header_logo" src="https://i.ss.com/img/p.gif"/></a><h1>SLUDINĀJUMI</h1></span>
# <span class="page_header_menu"><b class="menu_main"><a class="a_menu" href="/lv/real-estate/wood/new/" title="Iesniegt Sludinājumu">Iesniegt Sludinājumu</a></b>
# <b class="menu_main"><a class="a_menu" href="/lv/login/" title="Mani Sludinājumi">Mani Sludinājumi</a></b>
# <b class="menu_main"><a class="a_menu" href="/lv/real-estate/wood/search/" title="Meklēt sludinājumus">Meklēšana</a></b>
# <span style="display:inline-block;text-align:left;"><b class="menu_main" style="padding-right:0px;"><a class="a_menu" href="/lv/favorites/" title="Memo">Memo</a></b><span id="mnu_fav_id"></span></span></span>
# <span id="mails_status_menu"></span>
# <span class="menu_lang"><a class="a_menu" href="/ru/real-estate/wood/" title="По-русски">RU</a></span>
# </div>
# </div>
# <div align="center">
# <div class="page_header">
# <table border="0" cellpadding="0" cellspacing="0" width="100%"><tr><td>
# <div style="float:left;">
# <table border="0" cellpadding="0" cellspacing="0" id="page_main" width="100%"><tr><td valign="top"><div class="top_head"><div style="float:left;padding-top:2px;"><h2 class="headtitle"><a class="a14" href="/lv/real-estate/" title="Sludinājumi Mežs">Mežs</a><!-- CAT_LIST --></h2></div><div style="float:right;"><select id="today_cnt_sl" onchange="go(this.value+'');"><option value="/lv/real-estate/wood/">Visi sludinājumi</option></select></div></div><br/><div align="right"><table align="center" border="0" cellpadding="0" cellspacing="0" style="padding-left:1px;" width="100%"><tr>
# <td align="left" nowrap="" valign="top" width="25%">
# <table border="0" cellpadding="0" cellspacing="0">
# <tr><td align="left" nowrap=""><h4 class="category" id="sc_24203"><a class="a_category" href="/lv/real-estate/wood/riga-region/" id="ahc_24203" title="Rīgas rajons, Sludinājumi">Rīgas rajons</a></h4>
# <h4 class="category" id="sc_24971"><a class="a_category" href="/lv/real-estate/wood/aizkraukle-and-reg/" id="ahc_24971" title="Aizkraukle un rajons, Sludinājumi">Aizkraukle un rajons</a></h4>
# <h4 class="category" id="sc_25023"><a class="a_category" href="/lv/real-estate/wood/aluksne-and-reg/" id="ahc_25023" title="Alūksne un rajons, Sludinājumi">Alūksne un rajons</a></h4>
# <h4 class="category" id="sc_25071"><a class="a_category" href="/lv/real-estate/wood/balvi-and-reg/" id="ahc_25071" title="Balvi un rajons, Sludinājumi">Balvi un rajons</a></h4>
# <h4 class="category" id="sc_25119"><a class="a_category" href="/lv/real-estate/wood/bauska-and-reg/" id="ahc_25119" title="Bauska un rajons, Sludinājumi">Bauska un rajons</a></h4>
# <h4 class="category" id="sc_26095"><a class="a_category" href="/lv/real-estate/wood/cesis-and-reg/" id="ahc_26095" title="Cēsis un rajons, Sludinājumi">Cēsis un rajons</a></h4>
# <h4 class="category" id="sc_25333"><a class="a_category" href="/lv/real-estate/wood/daugavpils-and-reg/" id="ahc_25333" title="Daugavpils un rajons, Sludinājumi">Daugavpils un rajons</a></h4>
# <h4 class="category" id="sc_25395"><a class="a_category" href="/lv/real-estate/wood/dobele-and-reg/" id="ahc_25395" title="Dobele un rajons, Sludinājumi">Dobele un rajons</a></h4>
# <h4 class="category" id="sc_25299"><a class="a_category" href="/lv/real-estate/wood/gulbene-and-reg/" id="ahc_25299" title="Gulbene un rajons, Sludinājumi">Gulbene un rajons</a></h4>
# </td></tr></table></td>
# <td align="center" nowrap="" valign="top" width="25%">
# <table border="0" cellpadding="0" cellspacing="0">
# <tr><td align="left" nowrap=""><h4 class="category" id="sc_25443"><a class="a_category" href="/lv/real-estate/wood/jekabpils-and-reg/" id="ahc_25443" title="Jēkabpils un rajons, Sludinājumi">Jēkabpils un rajons</a></h4>
# <h4 class="category" id="sc_24883"><a class="a_category" href="/lv/real-estate/wood/jelgava-and-reg/" id="ahc_24883" title="Jelgava un rajons, Sludinājumi">Jelgava un rajons</a></h4>
# <h4 class="category" id="sc_25499"><a class="a_category" href="/lv/real-estate/wood/kraslava-and-reg/" id="ahc_25499" title="Krāslava un rajons, Sludinājumi">Krāslava un rajons</a></h4>
# <h4 class="category" id="sc_25557"><a class="a_category" href="/lv/real-estate/wood/kuldiga-and-reg/" id="ahc_25557" title="Kuldīga un rajons, Sludinājumi">Kuldīga un rajons</a></h4>
# <h4 class="category" id="sc_25603"><a class="a_category" href="/lv/real-estate/wood/liepaja-and-reg/" id="ahc_25603" title="Liepāja un rajons, Sludinājumi">Liepāja un rajons</a></h4>
# <h4 class="category" id="sc_25673"><a class="a_category" href="/lv/real-estate/wood/limbadzi-and-reg/" id="ahc_25673" title="Limbaži un rajons, Sludinājumi">Limbaži un rajons</a></h4>
# <h4 class="category" id="sc_25719"><a class="a_category" href="/lv/real-estate/wood/ludza-and-reg/" id="ahc_25719" title="Ludza un rajons, Sludinājumi">Ludza un rajons</a></h4>
# <h4 class="category" id="sc_25775"><a class="a_category" href="/lv/real-estate/wood/madona-and-reg/" id="ahc_25775" title="Madona un rajons, Sludinājumi">Madona un rajons</a></h4>
# <h4 class="category" id="sc_24925"><a class="a_category" href="/lv/real-estate/wood/ogre-and-reg/" id="ahc_24925" title="Ogre un rajons, Sludinājumi">Ogre un rajons</a></h4>
# </td></tr></table></td>
# <td align="center" nowrap="" valign="top" width="25%">
# <table border="0" cellpadding="0" cellspacing="0">
# <tr><td align="left" nowrap=""><h4 class="category" id="sc_25831"><a class="a_category" href="/lv/real-estate/wood/preili-and-reg/" id="ahc_25831" title="Preiļi un rajons, Sludinājumi">Preiļi un rajons</a></h4>
# <h4 class="category" id="sc_25879"><a class="a_category" href="/lv/real-estate/wood/rezekne-and-reg/" id="ahc_25879" title="Rēzekne un rajons, Sludinājumi">Rēzekne un rajons</a></h4>
# <h4 class="category" id="sc_25945"><a class="a_category" href="/lv/real-estate/wood/saldus-and-reg/" id="ahc_25945" title="Saldus un rajons, Sludinājumi">Saldus un rajons</a></h4>
# <h4 class="category" id="sc_25993"><a class="a_category" href="/lv/real-estate/wood/talsi-and-reg/" id="ahc_25993" title="Talsi un rajons, Sludinājumi">Talsi un rajons</a></h4>
# <h4 class="category" id="sc_26043"><a class="a_category" href="/lv/real-estate/wood/tukums-and-reg/" id="ahc_26043" title="Tukums un rajons, Sludinājumi">Tukums un rajons</a></h4>
# <h4 class="category" id="sc_25159"><a class="a_category" href="/lv/real-estate/wood/valka-and-reg/" id="ahc_25159" title="Valka un rajons, Sludinājumi">Valka un rajons</a></h4>
# <h4 class="category" id="sc_25209"><a class="a_category" href="/lv/real-estate/wood/valmiera-and-reg/" id="ahc_25209" title="Valmiera un rajons, Sludinājumi">Valmiera un rajons</a></h4>
# <h4 class="category" id="sc_25265"><a class="a_category" href="/lv/real-estate/wood/ventspils-and-reg/" id="ahc_25265" title="Ventspils un rajons, Sludinājumi">Ventspils un rajons</a></h4>
# <h4 class="category" id="sc_26151"><a class="a_category" href="/lv/real-estate/wood/other/" id="ahc_26151" title="Cits, Sludinājumi">Cits</a></h4>
# </td></tr></table></td>
# </tr>
# </table></div><br/><script type="text/javascript">print_ccnt();print_ccnts();</script><center><br/><br/>
# <input class="b" onclick="go('/lv/real-estate/wood/new/' );" style="width:250px;" type="button" value="Izvietot sludinājumu"/>
# <br/><br/><br/>
# </center>
# <table cellpadding="0" cellspacing="0" width="100%"><tr><td align="center">
# <div align="center" style="position:relative;height:375px;width:600px;">
# <img height="375" id="overc" src="https://i.ss.com/img/p.gif" style="position:absolute;" width="600"/>
# <canvas height="375" id="canvas" width="600"></canvas>
# </div>
# </td></tr></table>
# <script>
# var map = [
# 	links[25] = "/lv/real-estate/wood/limbadzi-and-reg/";titles[8] = "Ludza un rajons";
# 	links[8] = "/lv/real-estate/wood/ludza-and-reg/";titles[14] = "Madona un rajons";
# 	links[14] = "/lv/real-estate/wood/madona-and-reg/";titles[2] = "Preiļi un rajons";
# 	links[2] = "/lv/real-estate/wood/preili-and-reg/";titles[7] = "Rēzekne un rajons";
# 	links[7] = "/lv/real-estate/wood/rezekne-and-reg/";titles[10] = "Saldus un rajons";
# 	links[10] = "/lv/real-estate/wood/saldus-and-reg/";titles[23] = "Talsi un rajons";
# 	links[23] = "/lv/real-estate/wood/talsi-and-reg/";titles[16] = "Tukums un rajons";
# 	links[16] = "/lv/real-estate/wood/tukums-and-reg/";titles[20] = "Cēsis un rajons";
# 	links[20] = "/lv/real-estate/wood/cesis-and-reg/";
# _map( document.getElementById( "overc" ), document.getElementById( "canvas" ), {	//ссылки на объекты <img> и <canvas> соответственно
# 	"map" : map,			//координаты карты (массив массивов чисел)
# 	"links" : links,		//ссылки (массив строк)
# 	"titles" : titles,	//подсказки по наведению (массив строк, опционально)
# 	"dcolor" : "#bdd8bd",	//цвет областей
# 	"acolor" : "#dbeadb"	//цвет областей при наведении
# } );
#
#
# </script>
# </td></tr></table>
# </div>
# <div style="float:left;"><div id="page_right"><div id="ads_sys_div1"></div><script type="text/javascript">load_script_async( "/w_inc/reklama.php?1530|0|4832|"+Math.random()+"|0|"+escape(document.referrer) );</script></div></div>
# </td></tr></table>
# <div id="page_footer"><a class="a1" href="/lv/rules/">Noteikumi</a>   |   <a class="a1" href="/lv/feedback/">Saikne ar redaktoru</a>   |   <a class="a1" href="/lv/reklama/">Reklāma</a>   |   <a class="a1" href="/lv/api/">Sadarbība</a>  |  <a class="a1" href="/lv/real-estate/wood/rss/" target="_blank">RSS</a>  |  Sludinājumi © ss sia 2000</div>
# </div>
# </div>
# <script type="text/javascript">
# <!--
# if( window.add_link_to_selection && document.body.addEventListener ){document.body.addEventListener( "copy", add_link_to_selection );}window.onscroll=scbnrtop;window.onresize = new Function ( "scbnrtop();" );
# load_script_async( "https://i.ss.com/w_inc/js/msg.count-ss.js?"+new Date() );
# load_script_async( "/w_inc/chk.php?mm=1&c=4832&db=lv&mode=0" );
# -->
# </script>
# <div style="display:none;">
# <script>document.write( '<img src="/counter/index.php?c=4832&m=0&'+new Date()+Math.random()+'" width=1 height=1 border=0 alt="">' );</script>
# <script>
# (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
# (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
# m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
# })(window,document,'script','//www.google-analytics.com/analytics.js','ga');
# ga('create', 'UA-6772378-2', 'auto');ga('send', 'pageview');
# </script>
# <img alt="" border="0" height="1" src="https://top.lv/counter.php?sid=2774&amp;type=4" style="display:none" width="1"/>
# <!-- puls.lv START //-->
# <div id="_puls.lv_232" style="display:inline-block;"></div>
# <script type="text/javascript">_puls_counter_local( 232 );</script>
# <noscript>
# <a href="http://puls.lv/" target="_blank"><img alt="" border="0" height="1" src="https://hits.puls.lv/?sid=232&amp;jsver=0" width="1"/></a>
# </noscript>
# <!-- puls.lv END //-->
# <!-- puls.lv START //-->
# <div id="_puls.lv_26935" style="display:inline-block;"></div>
# <script type="text/javascript">_puls_counter_local( 26935 );</script>
# <noscript>
# <a href="http://puls.lv/" target="_blank"><img alt="" border="0" height="1" src="https://hits.puls.lv/?sid=26935&amp;jsver=0" width="1"/></a>
# </noscript>
# <!-- puls.lv END //-->
# <!-- europuls.eu START //-->
# <div id="_europuls.eu_2" style="display:inline-block;"></div>
# <script type="text/javascript">_ps_counter_local(2);</script>
# <noscript>
# <a href="http://europuls.eu/" target="_blank"><img alt="" border="0" height="1" src="https://hits.europuls.eu/?sid=2&amp;jsver=0" width="1"/></a>
# </noscript>
# <!-- europuls.eu END //-->
# </div></body>

# %%
soup.body.h1
# Out:
# <h1>SLUDINĀJUMI</h1>

# %%
dir(soup.body.a)
# Out:
# ['HTML_FORMATTERS',
#  'XML_FORMATTERS',
#  '__bool__',
#  '__call__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__unicode__',
#  '__weakref__',
#  '_all_strings',
#  '_find_all',
#  '_find_one',
#  '_formatter_for_name',
#  '_is_xml',
#  '_lastRecursiveChild',
#  '_last_descendant',
#  '_should_pretty_print',
#  'append',
#  'attrs',
#  'can_be_empty_element',
#  'childGenerator',
#  'children',
#  'clear',
#  'contents',
#  'decode',
#  'decode_contents',
#  'decompose',
#  'descendants',
#  'encode',
#  'encode_contents',
#  'extend',
#  'extract',
#  'fetchNextSiblings',
#  'fetchParents',
#  'fetchPrevious',
#  'fetchPreviousSiblings',
#  'find',
#  'findAll',
#  'findAllNext',
#  'findAllPrevious',
#  'findChild',
#  'findChildren',
#  'findNext',
#  'findNextSibling',
#  'findNextSiblings',
#  'findParent',
#  'findParents',
#  'findPrevious',
#  'findPreviousSibling',
#  'findPreviousSiblings',
#  'find_all',
#  'find_all_next',
#  'find_all_previous',
#  'find_next',
#  'find_next_sibling',
#  'find_next_siblings',
#  'find_parent',
#  'find_parents',
#  'find_previous',
#  'find_previous_sibling',
#  'find_previous_siblings',
#  'format_string',
#  'get',
#  'getText',
#  'get_attribute_list',
#  'get_text',
#  'has_attr',
#  'has_key',
#  'hidden',
#  'index',
#  'insert',
#  'insert_after',
#  'insert_before',
#  'isSelfClosing',
#  'is_empty_element',
#  'known_xml',
#  'name',
#  'namespace',
#  'next',
#  'nextGenerator',
#  'nextSibling',
#  'nextSiblingGenerator',
#  'next_element',
#  'next_elements',
#  'next_sibling',
#  'next_siblings',
#  'parent',
#  'parentGenerator',
#  'parents',
#  'parserClass',
#  'parser_class',
#  'prefix',
#  'preserve_whitespace_tags',
#  'prettify',
#  'previous',
#  'previousGenerator',
#  'previousSibling',
#  'previousSiblingGenerator',
#  'previous_element',
#  'previous_elements',
#  'previous_sibling',
#  'previous_siblings',
#  'recursiveChildGenerator',
#  'renderContents',
#  'replaceWith',
#  'replaceWithChildren',
#  'replace_with',
#  'replace_with_children',
#  'select',
#  'select_one',
#  'setup',
#  'string',
#  'strings',
#  'stripped_strings',
#  'text',
#  'unwrap',
#  'wrap']

# %%
soup.body.a.contents
# Out:
# [<img alt="Sludinājumi" border="0" class="page_header_logo" src="https://i.ss.com/img/p.gif"/>]

# %%
soup.body.a.attrs
# Out:
# {'href': '/', 'title': 'Sludinājumi'}

# %%
soup.body.a.attrs['href']
# Out:
# '/'

# %%
soup.body.a.img
# Out:
# <img alt="Sludinājumi" border="0" class="page_header_logo" src="https://i.ss.com/img/p.gif"/>

# %%
soup.body.a.img.attrs['src']
# Out:
# 'https://i.ss.com/img/p.gif'

# %%
type(soup)
# Out:
# bs4.BeautifulSoup

# %%
# finds all anchor tags (those with <a .... >)
allanchors = soup.find_all('a')
len(allanchors)
# Out:
# 42

# %%
someanch = allanchors[20]
someanch
# Out:
# <a class="a_category" href="/lv/real-estate/wood/liepaja-and-reg/" id="ahc_25603" title="Liepāja un rajons, Sludinājumi">Liepāja un rajons</a>

# %%
someanch.attrs['class']
# Out:
# ['a_category']

# %%
someanch['class']
# Out:
# ['a_category']

# %%
someanch['href']
# Out:
# '/lv/real-estate/wood/liepaja-and-reg/'

# %%
# we find all anchor tags with a specific class ('a_category') here
anchorlist = soup.find_all('a', {'class': 'a_category'})
len(anchorlist)
# Out:
# 27

# %%
# we create a list of web addresses(urls) using a list comprehension
urlist = [el['href'] for el in anchorlist]
len(urlist)
# Out:
# 27

# %%
urlist[0]
# Out:
# '/lv/real-estate/wood/riga-region/'

# %%
urlist[:10]
# Out:
# ['/lv/real-estate/wood/riga-region/',
#  '/lv/real-estate/wood/aizkraukle-and-reg/',
#  '/lv/real-estate/wood/aluksne-and-reg/',
#  '/lv/real-estate/wood/balvi-and-reg/',
#  '/lv/real-estate/wood/bauska-and-reg/',
#  '/lv/real-estate/wood/cesis-and-reg/',
#  '/lv/real-estate/wood/daugavpils-and-reg/',
#  '/lv/real-estate/wood/dobele-and-reg/',
#  '/lv/real-estate/wood/gulbene-and-reg/',
#  '/lv/real-estate/wood/jekabpils-and-reg/']

# %%
# lambda is an anonymous function
myadder = lambda a,b:a+b

# %%
myadder(6,7)
# Out:
# 13

# %%
# recipe if we need a fuzzy search through an id attribute
# we need to check if id attribute exists and only then check for the value
ahclist = soup.find_all(lambda el: 'id' in el.attrs and 'ahc' in el.attrs['id'])
len(ahclist)
# Out:
# 27

# %%
ahclist[:3]
# Out:
# [<a class="a_category" href="/lv/real-estate/wood/riga-region/" id="ahc_24203" title="Rīgas rajons, Sludinājumi">Rīgas rajons</a>,
#  <a class="a_category" href="/lv/real-estate/wood/aizkraukle-and-reg/" id="ahc_24971" title="Aizkraukle un rajons, Sludinājumi">Aizkraukle un rajons</a>,
#  <a class="a_category" href="/lv/real-estate/wood/aluksne-and-reg/" id="ahc_25023" title="Alūksne un rajons, Sludinājumi">Alūksne un rajons</a>]

# %%
alist = soup.find_all(lambda el: 'class' in el.attrs and el.attrs['class'] == 'a_category')
len(alist)
# Out:
# 0

# %%
alist = soup.find_all(lambda el: 'class' in el.attrs and 'a_category' in el.attrs['class'])
len(alist)
# Out:
# 27

# %%
alist = soup.find_all(lambda el: len(el.attrs) > 3)
len(alist)
# Out:
# 40

# %%
alist[0]
# Out:
# <img alt="Sludinājumi" border="0" class="page_header_logo" src="https://i.ss.com/img/p.gif"/>

# %%
alist[0]['class']
# Out:
# ['page_header_logo']

# %%
alist = soup.find_all(lambda el: 'class' in el and el['class'] == 'a_category')
len(alist)
# Out:
# 0

# %%
mytags = soup.find_all()
len(mytags)
# Out:
# 179

# %%
mytags[30].attrs
# Out:
# {'href': '/', 'title': 'Sludinājumi'}

# %%
allid = soup.find_all(lambda el: 'id' in el.attrs)
len(allid)
# Out:
# 69

# %%
cleantags=[]
mytags = soup.find_all()
for tag in mytags:
    if 'id' in tag.attrs:
        cleantags.append(tag)
len(cleantags)
# Out:
# 69

# %%
ahctags=[]
mytags = soup.find_all()
for tag in mytags:
    if 'id' in tag.attrs and 'ahc' in tag.attrs['id']:
        ahctags.append(tag)
len(ahctags)
# Out:
# 27

# %%
urlist
# Out:
# ['/lv/real-estate/wood/riga-region/',
#  '/lv/real-estate/wood/aizkraukle-and-reg/',
#  '/lv/real-estate/wood/aluksne-and-reg/',
#  '/lv/real-estate/wood/balvi-and-reg/',
#  '/lv/real-estate/wood/bauska-and-reg/',
#  '/lv/real-estate/wood/cesis-and-reg/',
#  '/lv/real-estate/wood/daugavpils-and-reg/',
#  '/lv/real-estate/wood/dobele-and-reg/',
#  '/lv/real-estate/wood/gulbene-and-reg/',
#  '/lv/real-estate/wood/jekabpils-and-reg/',
#  '/lv/real-estate/wood/jelgava-and-reg/',
#  '/lv/real-estate/wood/kraslava-and-reg/',
#  '/lv/real-estate/wood/kuldiga-and-reg/',
#  '/lv/real-estate/wood/liepaja-and-reg/',
#  '/lv/real-estate/wood/limbadzi-and-reg/',
#  '/lv/real-estate/wood/ludza-and-reg/',
#  '/lv/real-estate/wood/madona-and-reg/',
#  '/lv/real-estate/wood/ogre-and-reg/',
#  '/lv/real-estate/wood/preili-and-reg/',
#  '/lv/real-estate/wood/rezekne-and-reg/',
#  '/lv/real-estate/wood/saldus-and-reg/',
#  '/lv/real-estate/wood/talsi-and-reg/',
#  '/lv/real-estate/wood/tukums-and-reg/',
#  '/lv/real-estate/wood/valka-and-reg/',
#  '/lv/real-estate/wood/valmiera-and-reg/',
#  '/lv/real-estate/wood/ventspils-and-reg/',
#  '/lv/real-estate/wood/other/']

# %%
baseurl = "https://www.ss.com"
postfix = "sell/"

# %%
fullurls = [baseurl + el + postfix for el in urlist]
fullurls[:3]
#could write loop go through urlist
# Out:
# ['https://www.ss.com/lv/real-estate/wood/riga-region/sell/',
#  'https://www.ss.com/lv/real-estate/wood/aizkraukle-and-reg/sell/',
#  'https://www.ss.com/lv/real-estate/wood/aluksne-and-reg/sell/']

# %%
fullurls = []
#could write loop go through urlist
for el in urlist:
    fullurls.append(baseurl + el + postfix)
fullurls[:3]
# Out:
# ['https://www.ss.com/lv/real-estate/wood/riga-region/sell/',
#  'https://www.ss.com/lv/real-estate/wood/aizkraukle-and-reg/sell/',
#  'https://www.ss.com/lv/real-estate/wood/aluksne-and-reg/sell/']

# %%
furlist = [baseurl + el for el in urlist]
furlist[:2]
# Out:
# ['https://www.ss.com/lv/real-estate/wood/riga-region/',
#  'https://www.ss.com/lv/real-estate/wood/aizkraukle-and-reg/']

# %%
postfix = 'sell/'

# %%
sellist = [el+postfix for el in furlist]
sellist[:2]
# Out:
# ['https://www.ss.com/lv/real-estate/wood/riga-region/sell/',
#  'https://www.ss.com/lv/real-estate/wood/aizkraukle-and-reg/sell/']

# %%
dftables = pd.read_html(sellist[0])
len(dftables)
# Out:
# 11

# %%
riga = dftables[8]
riga
# Out:
#                       0                     1  \
# 0  Sludinājumi \tdatums  Sludinājumi \tdatums
# 1                   NaN                   NaN
# 2                   NaN                   NaN
# 3                   NaN                   NaN
# 4                   NaN                   NaN
# 5                   NaN                   NaN
# 6                   NaN                   NaN
# 7                   NaN                   NaN
#
#                                                    2  \
# 0                               Sludinājumi \tdatums
# 1  Pārdod pieauguša meža audzi. Daļēji izstrādāts...
# 2  Pārdod cirsmu 80m3 Priedes, īpašums ceļa malā,...
# 3  Īpašnieks pārdod cirsmu. Var izstrādāt priedi,...
# 4  AS Privatbank meitas uzņēmuma īpašums. Zemes g...
# 5  Saimnieks pārdod neizcirstu mežu ar zemi glezn...
# 6  Pārdodu cirsmas izstrādes tiesības saskaņā ar ...
# 7  Privātai apbūvei paredzēts zemes gabals 5500 m...
#
#                            3         4         5
# 0                    Pagasts        m2      Cena
# 1          Ropažu nov.Ropaži    10 ha.  12,500 €
# 2      Stopiņu nov.Upeslejas     80 m²   3,500 €
# 3    Carnikavas nov.Garciems     1 ha.  12,000 €
# 4  Garkalnes nov.Makstenieki  3.45 ha.  95,000 €
# 5      Krimuldas pag.Turaida  9.20 ha.  39,000 €
# 6           Sējas nov.Pabaži  2.50 ha.   3,500 €
# 7     Inčukalna nov.Krustiņi   5500 m²  14,000 €

# %%
type(riga)
# Out:
# pandas.core.frame.DataFrame

# %%
rigaurl = sellist[0]
rigaurl
# Out:
# 'https://www.ss.com/lv/real-estate/wood/riga-region/sell/'

# %%
def getRows(url):
    req = requests.get(url)
    rows = []
    if req.status_code != 200:
        print("Bad Request"+req.status_code)
        return
    soup = BeautifulSoup(req.text, 'lxml')
    print("Processing: "+ str(soup.title))
    alltrs = rsoup.find_all('tr')
    for el in alltrs:
        if 'id' in el.attrs and 'tr_' in el.attrs['id']:
            rows.append(el)
    rows.pop() # we do not need the last one nor do we need to store
    return rows

# %%
sellist[1]
# Out:
# 'https://www.ss.com/lv/real-estate/wood/aizkraukle-and-reg/sell
saimnieks pārdod neizcirstu mežu ar zemi gleznainā vietā. Labs piebraucamais ceļš. M</a></div></td><td c="1" class="msga2-o pp6" nowrap="">Krimuldas pag.<br/>Turaida</td><td c="1" class="msga2-o pp6" nowrap="">9.20 ha.</td><td c="1" class="msga2-o pp6" nowrap="">39,000  €</td></tr>,
#  <tr id="tr_45672273"><td class="msga2 pp0"><input id="c45672273" name="mid[]" type="checkbox" value="45672273_24651_0"/></td><td class="msga2"><a href="/msg/lv/real-estate/wood/riga-region/sejas-nov/knfgb.html" id="im45672273"><img alt="" class="isfoto foto_list" src="https://i.ss.com/gallery/3/493/123090/24617900.th2.jpg"/></a></td><td class="msg2"><div class="d1"><a class="am" data="JTlCaSU4QiU4NiVBQ2slQjJqJTlDYSU4QSU4QyVBRmlqaiU5Q2QlODUlOEElQTllag==|g1RUx269" href="/msg/lv/real-estate/wood/riga-region/sejas-nov/knfgb.html" id="dm_45672273">Pārdodu cirsmas izstrādes tiesības saskaņā ar apliecinājumu koku ciršanai. Melnalksn</a></div></td><td c="1" class="msga2-o pp6" nowrap="">Sējas nov.<br/>Pabaži</td><td c="1" class="msga2-o pp6" nowrap="">2.50 ha.</td><td c="1" class="msga2-o pp6" nowrap="">3,500  €</td></tr>,
#  <tr id="tr_44914768"><td class="msga2 pp0"><input id="c44914768" name="mid[]" type="checkbox" value="44914768_24575_0"/></td><td class="msga2"><a href="/msg/lv/real-estate/wood/riga-region/incukalna-nov/icnbn.html" id="im44914768"><img alt="" class="isfoto foto_list" src="https://i.ss.com/gallery/1/5/1250/249979.th2.jpg"/></a></td><td class="msg2"><div class="d1"><a class="am" data="JTg2JUEzdSU5RCVBOCU4MSVFRiU4MyU4QSU4NiVBMHklQTUlQTclODAlQTglODIlOEQlODYlQTR0JTlE|TkBmrPsRU" href="/msg/lv/real-estate/wood/riga-region/incukalna-nov/icnbn.html" id="dm_44914768">Privātai apbūvei paredzēts zemes gabals 5500 m2 26 km no Rīgas robežas Pleskavas šos</a></div></td><td c="1" class="msga2-o pp6" nowrap="">Inčukalna nov.<br/>Krustiņi</td><td c="1" class="msga2-o pp6" nowrap="">5500 m²</td><td c="1" class="msga2-o pp6" nowrap="">14,000  €</td></tr>]

# %%
rreq = requests.get(rigaurl)
rreq.status_code
# Out:
# 200

# %%
rsoup = BeautifulSoup(rreq.text, 'lxml')
rsoup.title
# Out:
# <title>SS.COM Mežs - Rīgas rajons, Cenas, Pārdod - Sludinājumi</title>

# %%
ranchors = rsoup.find_all('a', class_ = 'am')
len(ranchors)
# Out:
# 7

# %%
alltrs = rsoup.find_all('tr')
len(alltrs)
# Out:
# 21

# %%
myrows = []
for el in alltrs:
    if 'id' in el.attrs and 'tr_' in el.attrs['id']:
        myrows.append(el)
len(myrows)
# Out:
# 8

# %%
myrows[0]
# Out:
# <tr id="tr_46210202"><td class="msga2 pp0"><input id="c46210202" name="mid[]" type="checkbox" value="46210202_24595_0"/></td><td class="msga2"><a href="/msg/lv/real-estate/wood/riga-region/ropazu-nov/goxxb.html" id="im46210202"><img alt="" class="isfoto foto_list" src="https://i.ss.com/gallery/3/540/134845/26968947.th2.jpg"/></a></td><td class="msg2"><div class="d1"><a class="am" data="JUFEJUFCeSU4MiU4OSU4OCVGNiVBM3olODAlODYlODUlQUElQTR5JTgwJTgwJTg5JUFDJUEzdSU3RCU4Mw==|zrEKPU" href="/msg/lv/real-estate/wood/riga-region/ropazu-nov/goxxb.html" id="dm_46210202"><b>Pārdod pieauguša meža audzi.
# Daļēji izstrādāts.
# Izstrādājamā krāja redzama invet</b></a></div></td><td c="1" class="msga2-o pp6" nowrap=""><b>Ropažu nov.<br/>Ropaži</b></td><td c="1" class="msga2-o pp6" nowrap=""><b>10 ha.</b></td><td c="1" class="msga2-o pp6" nowrap=""><b>12,500</b>  €</td></tr>

# %%
myrows[-1]
# Out:
# <tr id="tr_bnr_712" style="display:none;"><td align="center" colspan="12">
# <div align="center" id="div_bnr_712"></div>
# <script>load_script_async("/w_inc/reklama.728.php?0||24203||"+escape(document.referrer));</script>
# </td></tr>

# %%
# we do not need the last one so we just throw away the last one
myrows = myrows[:-1]
len(myrows)
# Out:
# 7

# %%
# get first row
row1 = myrows[0]
row1
# Out:
# <tr id="tr_46210202"><td class="msga2 pp0"><input id="c46210202" name="mid[]" type="checkbox" value="46210202_24595_0"/></td><td class="msga2"><a href="/msg/lv/real-estate/wood/riga-region/ropazu-nov/goxxb.html" id="im46210202"><img alt="" class="isfoto foto_list" src="https://i.ss.com/gallery/3/540/134845/26968947.th2.jpg"/></a></td><td class="msg2"><div class="d1"><a class="am" data="JUFEJUFCeSU4MiU4OSU4OCVGNiVBM3olODAlODYlODUlQUElQTR5JTgwJTgwJTg5JUFDJUEzdSU3RCU4Mw==|zrEKPU" href="/msg/lv/real-estate/wood/riga-region/ropazu-nov/goxxb.html" id="dm_46210202"><b>Pārdod pieauguša meža audzi.
# Daļēji izstrādāts.
# Izstrādājamā krāja redzama invet</b></a></div></td><td c="1" class="msga2-o pp6" nowrap=""><b>Ropažu nov.<br/>Ropaži</b></td><td c="1" class="msga2-o pp6" nowrap=""><b>10 ha.</b></td><td c="1" class="msga2-o pp6" nowrap=""><b>12,500</b>  €</td></tr>

# %%
# find all data cells for first row
tds = row1.find_all('td')
len(tds)
# Out:
# 6

# %%
tds[1].a
# Out:
# <a href="/msg/lv/real-estate/wood/riga-region/ropazu-nov/goxxb.html" id="im46210202"><img alt="" class="isfoto foto_list" src="https://i.ss.com/gallery/3/540/134845/26968947.th2.jpg"/></a>

# %%
tds[1].a['href']
# Out:
# '/msg/lv/real-estate/wood/riga-region/ropazu-nov/goxxb.html'

# %%
tds[1].a['badattribute']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-93-d92f3d1f55a4> in <module>
# ----> 1 tds[1].a['badattribute']
#
# C:\ProgramData\Anaconda3\lib\site-packages\bs4\element.py in __getitem__(self, key)
#    1014         """tag[key] returns the value of the 'key' attribute for the tag,
#    1015         and throws an exception if it's not there."""
# -> 1016         return self.attrs[key]
#    1017
#    1018     def __iter__(self):
#
# KeyError: 'badattribute'

# %%
# clean some text
tds[2].text.strip().replace('\r','').replace('\n', '')
# Out:
# 'Pārdod pieauguša meža audzi. Daļēji izstrādāts. Izstrādājamā krāja redzama invet'

# %%
tds[3].text
# Out:
# 'Ropažu nov.Ropaži'

# %%
tds[4].text
# Out:
# '10 ha.'

# %%
tds[5]
# Out:
# <td c="1" class="msga2-o pp6" nowrap=""><b>12,500</b>  €</td>

# %%
tds[5].text
# Out:
# '12,500  €'

# %%
tds[5].text.split()[0]
# Out:
# '12,500'

# %%
price = int(tds[5].text.split()[0].replace(',',''))
price
# Out:
# 12500

# %%
tds[5].text.split()[1]
# Out:
# '€'

# %%
def processRow(row, baseurl='https://www.ss.com'):
    ritems = []
    tds = row.find_all('td')
    ritems.append(baseurl + tds[1].a['href'])
    ritems.append(tds[2].text.strip().replace('\r','').replace('\n', ''))
    for td in tds[3:-1]:
        ritems.append(td.text)
    ritems.append(int(tds[-1].text.split()[0].replace(',','')))
    ritems.append(tds[-1].text.split()[1])
    return ritems

# %%
myrow = processRow(myrows[0])
myrow
# Out:
# ['https://www.ss.com/msg/lv/real-estate/wood/riga-region/ropazu-nov/goxxb.html',
#  'Pārdod pieauguša meža audzi. Daļēji izstrādāts. Izstrādājamā krāja redzama invet',
#  'Ropažu nov.Ropaži',
#  '10 ha.',
#  12500,
#  '€']

# %%
def processRows(rows):
    rowlist=[]
    for row in rows:
        rowlist.append(processRow(row))
    return rowlist

# %%
def getRows(url):
    req = requests.get(url)
    rows = []
    if req.status_code != 200:
        print("Bad Request"+req.status_code)
        return
    soup = BeautifulSoup(req.text, 'lxml')
    print("Processing: "+ str(soup.title))
    # this will be specific to ss.lv and ss.com
    alltrs = soup.find_all('tr')
    for el in alltrs:
        if 'id' in el.attrs and 'tr_' in el.attrs['id']:
            rows.append(el)
    rows.pop() # we do not need the last one nor do we need to store
    return rows

# %%
def processPage(url):
    rows = getRows(url)
    mylist = processRows(rows)
    return mylist # could return processRows(rows)

# %%
import time

# %%
def processPages(urls):
    results = []
    for url in urls:
        print("Processing: "+url)
        results += processPage(url)
        time.sleep(0.1)
    return results

# %%
mlist2 = processPages(sellist)
len(mlist2)
# Out:
# Processing:https://www.ss.com/lv/real-estate/wood/riga-region/sell/
# Processing: <title>SS.COM Mežs - Rīgas rajons, Cenas, Pārdod - Sludinājumi</title>
# Processing:https://www.ss.com/lv/real-estate/wood/aizkraukle-and-reg/sell/
# Processing: <title>SS.COM Mežs - Aizkraukle un raj., Cenas, Pārdod - Sludinājumi</title>
# Processing:https://www.ss.com/lv/real-estate/wood/aluksne-and-reg/sell/
# Processing: <title>SS.COM Mežs - Alūksne un raj., Cenas, Pārdod - Sludinājumi</title>
# Processing:https://www.ss.com/lv/real-estate/wood/balvi-and-reg/sell/
# Processing: <title>SS.COM Mežs - Balvi un raj., Cenas, Pārdod - Sludinājumi</title>
# Processing:https://www.ss.com/lv/real-estate/wood/bauska-and-reg/sell/
# Processing: <title>SS.COM Mežs - Bauska un raj., Cenas, Pārdod - Sludinājumi</title>
# Processing:https://www.ss.com/lv/real-estate/wood/cesis-and-reg/sell/
# Processing: <title>SS.COM Mežs - Cēsis un raj., Cenas, Pārdod - Sludinājumi</title>
# Processing:https://www.ss.com/lv/real-estate/wood/daugavpils-and-reg/sell/
# Processing: <title>SS.COM Mežs - Daugavpils un raj., Cenas, Pārdod - Sludinājumi</title>
# Processing:https://www.ss.com/lv/real-estate/wood/dobele-and-reg/sell/
# Processing: <title>SS.COM Mežs - Dobele un raj., Cenas, Pārdod - Sludinājumi</title>
# Processing:https://www.ss.com/lv/real-estate/wood/gulbene-and-reg/sell/
# Processing: <title>SS.COM Mežs - Gulbene un raj., Pārdod - Sludinājumi</title>
# Processing:https://www.ss.com/lv/real-estate/wood/jekabpils-and-reg/sell/
# Processing: <title>SS.COM Mežs - Jēkabpils un raj., Cenas, Pārdod - Sludinājumi</title>
# Processing:https://www.ss.com/lv/real-estate/wood/jelgava-and-reg/sell/
# Processing: <title>SS.COM Mežs - Jelgava un raj., Cenas, Pārdod - Sludinājumi</title>
# Processing:https://www.ss.com/lv/real-estate/wood/kraslava-and-reg/sell/
# Processing: <title>SS.COM Mežs - Krāslava un raj., Cenas, Pārdod - Sludinājumi</title>
# Processing:https://www.ss.com/lv/real-estate/wood/kuldiga-and-reg/sell/
# Processing: <title>SS.COM Mežs - Kuldīga un raj., Cenas, Pārdod - Sludinājumi</title>
# Processing:https://www.ss.com/lv/real-estate/wood/liepaja-and-reg/sell/
# Processing: <title>SS.COM Mežs - Liepāja un raj., Cenas, Pārdod - Sludinājumi</title>
# Processing:https://www.ss.com/lv/real-estate/wood/limbadzi-and-reg/sell/
# Processing: <title>SS.COM Mežs - Limbaži un raj., Cenas, Pārdod - Sludinājumi</title>
# Processing:https://www.ss.com/lv/real-estate/wood/ludza-and-reg/sell/
# Processing: <title>SS.COM Mežs - Ludza un raj., Cenas, Pārdod - Sludinājumi</title>
# Processing:https://www.ss.com/lv/real-estate/wood/madona-and-reg/sell/
# Processing: <title>SS.COM Mežs - Madona un raj., Cenas, Pārdod - Sludinājumi</title>
# Processing:https://www.ss.com/lv/real-estate/wood/ogre-and-reg/sell/
# Processing: <title>SS.COM Mežs - Ogre un raj., Cenas, Pārdod - Sludinājumi</title>
# Processing:https://www.ss.com/lv/real-estate/wood/preili-and-reg/sell/
# Processing: <title>SS.COM Mežs - Preiļi un raj., Cenas, Pārdod - Sludinājumi</title>
# Processing:https://www.ss.com/lv/real-estate/wood/rezekne-and-reg/sell/
# Processing: <title>SS.COM Mežs - Rēzekne un raj., Cenas, Pārdod - Sludinājumi</title>
# Processing:https://www.ss.com/lv/real-estate/wood/saldus-and-reg/sell/
# Processing: <title>SS.COM Mežs - Saldus un raj., Cenas, Pārdod - Sludinājumi</title>
# Processing:https://www.ss.com/lv/real-estate/wood/talsi-and-reg/sell/
# Processing: <title>SS.COM Mežs - Talsi un raj., Cenas, Pārdod - Sludinājumi</title>
# Processing:https://www.ss.com/lv/real-estate/wood/tukums-and-reg/sell/
# Processing: <title>SS.COM Mežs - Tukums un raj., Cenas, Pārdod - Sludinājumi</title>
# Processing:https://www.ss.com/lv/real-estate/wood/valka-and-reg/sell/
# Processing: <title>SS.COM Mežs - Valka un raj., Cenas, Pārdod - Sludinājumi</title>
# Processing:https://www.ss.com/lv/real-estate/wood/valmiera-and-reg/sell/
# Processing: <title>SS.COM Mežs - Valmiera un raj., Cenas, Pārdod - Sludinājumi</title>
# Processing:https://www.ss.com/lv/real-estate/wood/ventspils-and-reg/sell/
# Processing: <title>SS.COM Mežs - Ventspils un raj., Cenas, Pārdod - Sludinājumi</title>
# Processing:https://www.ss.com/lv/real-estate/wood/other/sell/
# Processing: <title>SS.COM Mežs - Cits, Pārdod - Sludinājumi</title>
# 189

# %%
mlist2[10]
# Out:
# ['https://www.ss.com/msg/lv/real-estate/wood/riga-region/garkalnes-nov/jplnx.html',
#  'AS Privatbank meitas uzņēmuma īpašums. Zemes gabala kopējā platība 3.45 ha. Zemes',
#  'Garkalnes nov.Makstenieki',
#  '3.45 ha.',
#  95000,
#  '€']

# %%
mylist = processPages(sellist)
len(mylist)
# Out:
# Processing:https://www.ss.com/lv/real-estate/wood/riga-region/sell/
# Processing: <title>SS.COM Mežs - Rīgas rajons, Cenas, Pārdod - Sludinājumi</title>
# Processing:https://www.ss.com/lv/real-estate/wood/aizkraukle-and-reg/sell/
# Processing: <title>SS.COM Mežs - Aizkraukle un raj., Cenas, Pārdod - Sludinājumi</title>
# Processing:https://www.ss.com/lv/real-estate/wood/aluksne-and-reg/sell/
# Processing: <title>SS.COM Mežs - Alūksne un raj., Cenas, Pārdod - Sludinājumi</title>
# Processing:https://www.ss.com/lv/real-estate/wood/balvi-and-reg/sell/
# Processing: <title>SS.COM Mežs - Balvi un raj., Cenas, Pārdod - Sludinājumi</title>
# Processing:https://www.ss.com/lv/real-estate/wood/bauska-and-reg/sell/
# Processing: <title>SS.COM Mežs - Bauska un raj., Cenas, Pārdod - Sludinājumi</title>
# Processing:https://www.ss.com/lv/real-estate/wood/cesis-and-reg/sell/
# Processing: <title>SS.COM Mežs - Cēsis un raj., Cenas, Pārdod - Sludinājumi</title>
# Processing:https://www.ss.com/lv/real-estate/wood/daugavpils-and-reg/sell/
# Processing: <title>SS.COM Mežs - Daugavpils un raj., Cenas, Pārdod - Sludinājumi</title>
# Processing:https://www.ss.com/lv/real-estate/wood/dobele-and-reg/sell/
# Processing: <title>SS.COM Mežs - Dobele un raj., Cenas, Pārdod - Sludinājumi</title>
# Processing:https://www.ss.com/lv/real-estate/wood/gulbene-and-reg/sell/
# Processing: <title>SS.COM Mežs - Gulbene un raj., Pārdod - Sludinājumi</title>
# Processing:https://www.ss.com/lv/real-estate/wood/jekabpils-and-reg/sell/
# Processing: <title>SS.COM Mežs - Jēkabpils un raj., Cenas, Pārdod - Sludinājumi</title>
# Processing:https://www.ss.com/lv/real-estate/wood/jelgava-and-reg/sell/
# Processing: <title>SS.COM Mežs - Jelgava un raj., Cenas, Pārdod - Sludinājumi</title>
# Processing:https://www.ss.com/lv/real-estate/wood/kraslava-and-reg/sell/
# Processing: <title>SS.COM Mežs - Krāslava un raj., Cenas, Pārdod - Sludinājumi</title>
# Processing:https://www.ss.com/lv/real-estate/wood/kuldiga-and-reg/sell/
# Processing: <title>SS.COM Mežs - Kuldīga un raj., Cenas, Pārdod - Sludinājumi</title>
# Processing:https://www.ss.com/lv/real-estate/wood/liepaja-and-reg/sell/
# Processing: <title>SS.COM Mežs - Liepāja un raj., Cenas, Pārdod - Sludinājumi</title>
# Processing:https://www.ss.com/lv/real-estate/wood/limbadzi-and-reg/sell/
# Processing: <title>SS.COM Mežs - Limbaži un raj., Cenas, Pārdod - Sludinājumi</title>
# Processing:https://www.ss.com/lv/real-estate/wood/ludza-and-reg/sell/
# Processing: <title>SS.COM Mežs - Ludza un raj., Cenas, Pārdod - Sludinājumi</title>
# Processing:https://www.ss.com/lv/real-estate/wood/madona-and-reg/sell/
# Processing: <title>SS.COM Mežs - Madona un raj., Cenas, Pārdod - Sludinājumi</title>
# Processing:https://www.ss.com/lv/real-estate/wood/ogre-and-reg/sell/
# Processing: <title>SS.COM Mežs - Ogre un raj., Cenas, Pārdod - Sludinājumi</title>
# Processing:https://www.ss.com/lv/real-estate/wood/preili-and-reg/sell/
# Processing: <title>SS.COM Mežs - Preiļi un raj., Cenas, Pārdod - Sludinājumi</title>
# Processing:https://www.ss.com/lv/real-estate/wood/rezekne-and-reg/sell/
# Processing: <title>SS.COM Mežs - Rēzekne un raj., Cenas, Pārdod - Sludinājumi</title>
# Processing:https://www.ss.com/lv/real-estate/wood/saldus-and-reg/sell/
# Processing: <title>SS.COM Mežs - Saldus un raj., Cenas, Pārdod - Sludinājumi</title>
# Processing:https://www.ss.com/lv/real-estate/wood/talsi-and-reg/sell/
# Processing: <title>SS.COM Mežs - Talsi un raj., Cenas, Pārdod - Sludinājumi</title>
# Processing:https://www.ss.com/lv/real-estate/wood/tukums-and-reg/sell/
# Processing: <title>SS.COM Mežs - Tukums un raj., Cenas, Pārdod - Sludinājumi</title>
# Processing:https://www.ss.com/lv/real-estate/wood/valka-and-reg/sell/
# Processing: <title>SS.COM Mežs - Valka un raj., Cenas, Pārdod - Sludinājumi</title>
# Processing:https://www.ss.com/lv/real-estate/wood/valmiera-and-reg/sell/
# Processing: <title>SS.COM Mežs - Valmiera un raj., Cenas, Pārdod - Sludinājumi</title>
# Processing:https://www.ss.com/lv/real-estate/wood/ventspils-and-reg/sell/
# Processing: <title>SS.COM Mežs - Ventspils un raj., Cenas, Pārdod - Sludinājumi</title>
# Processing:https://www.ss.com/lv/real-estate/wood/other/sell/
# Processing: <title>SS.COM Mežs - Cits, Pārdod - Sludinājumi</title>
# 189

# %%
mylist[30:50]
# Out:
# [['https://www.ss.com/msg/lv/real-estate/wood/riga-region/carnikavas-nov/njfcg.html',
#   'Īpašnieks pārdod cirsmu. Var izstrādāt priedi, virs 200m3',
#   'Carnikavas nov.Garciems',
#   '1 ha.',
#   12000,
#   '€'],
#  ['https://www.ss.com/msg/lv/real-estate/wood/riga-region/garkalnes-nov/jplnx.html',
#   'AS Privatbank meitas uzņēmuma īpašums. Zemes gabala kopējā platība 3.45 ha. Zemes',
#   'Garkalnes nov.Makstenieki',
#   '3.45 ha.',
#   95000,
#   '€'],
#  ['https://www.ss.com/msg/lv/real-estate/wood/riga-region/krimuldas-pag/fmlml.html',
#   'Saimnieks pārdod neizcirstu mežu ar zemi gleznainā vietā. Labs piebraucamais ceļš. M',
#   'Krimuldas pag.Turaida',
#   '9.20 ha.',
#   39000,
#   '€'],
#  ['https://www.ss.com/msg/lv/real-estate/wood/riga-region/sejas-nov/knfgb.html',
#   'Pārdodu cirsmas izstrādes tiesības saskaņā ar apliecinājumu koku ciršanai. Melnalksn',
#   'Sējas nov.Pabaži',
#   '2.50 ha.',
#   3500,
#   '€'],
#  ['https://www.ss.com/msg/lv/real-estate/wood/riga-region/incukalna-nov/icnbn.html',
#   'Privātai apbūvei paredzēts zemes gabals 5500 m2 26 km no Rīgas robežas Pleskavas šos',
#   'Inčukalna nov.Krustiņi',
#   '5500 m²',
#   14000,
#   '€'],
#  ['https://www.ss.com/msg/lv/real-estate/wood/riga-region/ropazu-nov/goxxb.html',
#   'Pārdod pieauguša meža audzi. Daļēji izstrādāts. Izstrādājamā krāja redzama invet',
#   'Ropažu nov.Ropaži',
#   '10 ha.',
#   12500,
#   '€'],
#  ['https://www.ss.com/msg/lv/real-estate/wood/riga-region/stopinu-nov/gcdeb.html',
#   'Pārdod cirsmu 80m3 Priedes, īpašums ceļa malā, saņemts CA.',
#   'Stopiņu nov.Upeslejas',
#   '80 m²',
#   3500,
#   '€'],
#  ['https://www.ss.com/msg/lv/real-estate/wood/riga-region/carnikavas-nov/njfcg.html',
#   'Īpašnieks pārdod cirsmu. Var izstrādāt priedi, virs 200m3',
#   'Carnikavas nov.Garciems',
#   '1 ha.',
#   12000,
#   '€'],
#  ['https://www.ss.com/msg/lv/real-estate/wood/riga-region/garkalnes-nov/jplnx.html',
#   'AS Privatbank meitas uzņēmuma īpašums. Zemes gabala kopējā platība 3.45 ha. Zemes',
#   'Garkalnes nov.Makstenieki',
#   '3.45 ha.',
#   95000,
#   '€'],
#  ['https://www.ss.com/msg/lv/real-estate/wood/riga-region/krimuldas-pag/fmlml.html',
#   'Saimnieks pārdod neizcirstu mežu ar zemi gleznainā vietā. Labs piebraucamais ceļš. M',
#   'Krimuldas pag.Turaida',
#   '9.20 ha.',
#   39000,
#   '€'],
#  ['https://www.ss.com/msg/lv/real-estate/wood/riga-region/sejas-nov/knfgb.html',
#   'Pārdodu cirsmas izstrādes tiesības saskaņā ar apliecinājumu koku ciršanai. Melnalksn',
#   'Sējas nov.Pabaži',
#   '2.50 ha.',
#   3500,
#   '€'],
#  ['https://www.ss.com/msg/lv/real-estate/wood/riga-region/incukalna-nov/icnbn.html',
#   'Privātai apbūvei paredzēts zemes gabals 5500 m2 26 km no Rīgas robežas Pleskavas šos',
#   'Inčukalna nov.Krustiņi',
#   '5500 m²',
#   14000,
#   '€'],
#  ['https://www.ss.com/msg/lv/real-estate/wood/riga-region/ropazu-nov/goxxb.html',
#   'Pārdod pieauguša meža audzi. Daļēji izstrādāts. Izstrādājamā krāja redzama invet',
#   'Ropažu nov.Ropaži',
#   '10 ha.',
#   12500,
#   '€'],
#  ['https://www.ss.com/msg/lv/real-estate/wood/riga-region/stopinu-nov/gcdeb.html',
#   'Pārdod cirsmu 80m3 Priedes, īpašums ceļa malā, saņemts CA.',
#   'Stopiņu nov.Upeslejas',
#   '80 m²',
#   3500,
#   '€'],
#  ['https://www.ss.com/msg/lv/real-estate/wood/riga-region/carnikavas-nov/njfcg.html',
#   'Īpašnieks pārdod cirsmu. Var izstrādāt priedi, virs 200m3',
#   'Carnikavas nov.Garciems',
#   '1 ha.',
#   12000,
#   '€'],
#  ['https://www.ss.com/msg/lv/real-estate/wood/riga-region/garkalnes-nov/jplnx.html',
#   'AS Privatbank meitas uzņēmuma īpašums. Zemes gabala kopējā platība 3.45 ha. Zemes',
#   'Garkalnes nov.Makstenieki',
#   '3.45 ha.',
#   95000,
#   '€'],
#  ['https://www.ss.com/msg/lv/real-estate/wood/riga-region/krimuldas-pag/fmlml.html',
#   'Saimnieks pārdod neizcirstu mežu ar zemi gleznainā vietā. Labs piebraucamais ceļš. M',
#   'Krimuldas pag.Turaida',
#   '9.20 ha.',
#   39000,
#   '€'],
#  ['https://www.ss.com/msg/lv/real-estate/wood/riga-region/sejas-nov/knfgb.html',
#   'Pārdodu cirsmas izstrādes tiesības saskaņā ar apliecinājumu koku ciršanai. Melnalksn',
#   'Sējas nov.Pabaži',
#   '2.50 ha.',
#   3500,
#   '€'],
#  ['https://www.ss.com/msg/lv/real-estate/wood/riga-region/incukalna-nov/icnbn.html',
#   'Privātai apbūvei paredzēts zemes gabals 5500 m2 26 km no Rīgas robežas Pleskavas šos',
#   'Inčukalna nov.Krustiņi',
#   '5500 m²',
#   14000,
#   '€'],
#  ['https://www.ss.com/msg/lv/real-estate/wood/riga-region/ropazu-nov/goxxb.html',
#   'Pārdod pieauguša meža audzi. Daļēji izstrādāts. Izstrādājamā krāja redzama invet',
#   'Ropažu nov.Ropaži',
#   '10 ha.',
#   12500,
#   '€']]

# %%
index = ['URL','Desc','Region','Area','Price','Currency']

# %%
df = pd.DataFrame(mylist)
df.head()
# Out:
#                                                    0  \
# 0  https://www.ss.com/msg/lv/real-estate/wood/rig...
# 1  https://www.ss.com/msg/lv/real-estate/wood/rig...
# 2  https://www.ss.com/msg/lv/real-estate/wood/rig...
# 3  https://www.ss.com/msg/lv/real-estate/wood/rig...
# 4  https://www.ss.com/msg/lv/real-estate/wood/rig...
#
#                                                    1  \
# 0  Pārdod pieauguša meža audzi. Daļēji izstrādāts...
# 1  Pārdod cirsmu 80m3 Priedes, īpašums ceļa malā,...
# 2  Īpašnieks pārdod cirsmu. Var izstrādāt priedi,...
# 3  AS Privatbank meitas uzņēmuma īpašums. Zemes g...
# 4  Saimnieks pārdod neizcirstu mežu ar zemi glezn...
#
#                            2         3      4  5
# 0          Ropažu nov.Ropaži    10 ha.  12500  €
# 1      Stopiņu nov.Upeslejas     80 m²   3500  €
# 2    Carnikavas nov.Garciems     1 ha.  12000  €
# 3  Garkalnes nov.Makstenieki  3.45 ha.  95000  €
# 4      Krimuldas pag.Turaida  9.20 ha.  39000  €

# %%
df.columns = index
df.head()
# Out:
#                                                  URL  \
# 0  https://www.ss.com/msg/lv/real-estate/wood/rig...
# 1  https://www.ss.com/msg/lv/real-estate/wood/rig...
# 2  https://www.ss.com/msg/lv/real-estate/wood/rig...
# 3  https://www.ss.com/msg/lv/real-estate/wood/rig...
# 4  https://www.ss.com/msg/lv/real-estate/wood/rig...
#
#                                                 Desc  \
# 0  Pārdod pieauguša meža audzi. Daļēji izstrādāts...
# 1  Pārdod cirsmu 80m3 Priedes, īpašums ceļa malā,...
# 2  Īpašnieks pārdod cirsmu. Var izstrādāt priedi,...
# 3  AS Privatbank meitas uzņēmuma īpašums. Zemes g...
# 4  Saimnieks pārdod neizcirstu mežu ar zemi glezn...
#
#                       Region      Area  Price Currency
# 0          Ropažu nov.Ropaži    10 ha.  12500        €
# 1      Stopiņu nov.Upeslejas     80 m²   3500        €
# 2    Carnikavas nov.Garciems     1 ha.  12000        €
# 3  Garkalnes nov.Makstenieki  3.45 ha.  95000        €
# 4      Krimuldas pag.Turaida  9.20 ha.  39000        €

# %%
columns = list(df.columns)
columns
# Out:
# ['URL', 'Desc', 'Region', 'Area', 'Price', 'Currency']

# %%
# + can concatanate only same type elements so list with list
# so we need to make a single element such as index[0] into a list of one element such as [index[0]]

df2 = df[columns[1:]+[columns[0]]]
df2.head()
# Out:
#                                                 Desc  \
# 0  Pārdod pieauguša meža audzi. Daļēji izstrādāts...
# 1  Pārdod cirsmu 80m3 Priedes, īpašums ceļa malā,...
# 2  Īpašnieks pārdod cirsmu. Var izstrādāt priedi,...
# 3  AS Privatbank meitas uzņēmuma īpašums. Zemes g...
# 4  Saimnieks pārdod neizcirstu mežu ar zemi glezn...
#
#                       Region      Area  Price Currency  \
# 0          Ropažu nov.Ropaži    10 ha.  12500        €
# 1      Stopiņu nov.Upeslejas     80 m²   3500        €
# 2    Carnikavas nov.Garciems     1 ha.  12000        €
# 3  Garkalnes nov.Makstenieki  3.45 ha.  95000        €
# 4      Krimuldas pag.Turaida  9.20 ha.  39000        €
#
#                                                  URL
# 0  https://www.ss.com/msg/lv/real-estate/wood/rig...
# 1  https://www.ss.com/msg/lv/real-estate/wood/rig...
# 2  https://www.ss.com/msg/lv/real-estate/wood/rig...
# 3  https://www.ss.com/msg/lv/real-estate/wood/rig...
# 4  https://www.ss.com/msg/lv/real-estate/wood/rig...

# %%
# + can concatanate only same type elements so list with list
# so we need to make a single element such as index[0] into a list of one element such as [index[0]]

df2 = df[index[1:]+[index[0]]]
df2.head()
# Out:
#                                                 Desc  \
# 0  Pārdod pieauguša meža audzi. Daļēji izstrādāts...
# 1  Pārdod cirsmu 80m3 Priedes, īpašums ceļa malā,...
# 2  Īpašnieks pārdod cirsmu. Var izstrādāt priedi,...
# 3  AS Privatbank meitas uzņēmuma īpašums. Zemes g...
# 4  Saimnieks pārdod neizcirstu mežu ar zemi glezn...
#
#                       Region      Area  Price Currency  \
# 0          Ropažu nov.Ropaži    10 ha.  12500        €
# 1      Stopiņu nov.Upeslejas     80 m²   3500        €
# 2    Carnikavas nov.Garciems     1 ha.  12000        €
# 3  Garkalnes nov.Makstenieki  3.45 ha.  95000        €
# 4      Krimuldas pag.Turaida  9.20 ha.  39000        €
#
#                                                  URL
# 0  https://www.ss.com/msg/lv/real-estate/wood/rig...
# 1  https://www.ss.com/msg/lv/real-estate/wood/rig...
# 2  https://www.ss.com/msg/lv/real-estate/wood/rig...
# 3  https://www.ss.com/msg/lv/real-estate/wood/rig...
# 4  https://www.ss.com/msg/lv/real-estate/wood/rig...

# %%
aizlist = processPage(sellist[1])
aizlist
# Out:
# Processing: <title>SS.COM Mežs - Aizkraukle un raj., Cenas, Pārdod - Sludinājumi</title>
# [['https://www.ss.com/msg/lv/real-estate/wood/riga-region/ropazu-nov/goxxb.html',
#   'Pārdod pieauguša meža audzi. Daļēji izstrādāts. Izstrādājamā krāja redzama invet',
#   'Ropažu nov.Ropaži',
#   '10 ha.',
#   12500,
#   '€'],
#  ['https://www.ss.com/msg/lv/real-estate/wood/riga-region/stopinu-nov/gcdeb.html',
#   'Pārdod cirsmu 80m3 Priedes, īpašums ceļa malā, saņemts CA.',
#   'Stopiņu nov.Upeslejas',
#   '80 m²',
#   3500,
#   '€'],
#  ['https://www.ss.com/msg/lv/real-estate/wood/riga-region/carnikavas-nov/njfcg.html',
#   'Īpašnieks pārdod cirsmu. Var izstrādāt priedi, virs 200m3',
#   'Carnikavas nov.Garciems',
#   '1 ha.',
#   12000,
#   '€'],
#  ['https://www.ss.com/msg/lv/real-estate/wood/riga-region/garkalnes-nov/jplnx.html',
#   'AS Privatbank meitas uzņēmuma īpašums. Zemes gabala kopējā platība 3.45 ha. Zemes',
#   'Garkalnes nov.Makstenieki',
#   '3.45 ha.',
#   95000,
#   '€'],
#  ['https://www.ss.com/msg/lv/real-estate/wood/riga-region/krimuldas-pag/fmlml.html',
#   'Saimnieks pārdod neizcirstu mežu ar zemi gleznainā vietā. Labs piebraucamais ceļš. M',
#   'Krimuldas pag.Turaida',
#   '9.20 ha.',
#   39000,
#   '€'],
#  ['https://www.ss.com/msg/lv/real-estate/wood/riga-region/sejas-nov/knfgb.html',
#   'Pārdodu cirsmas izstrādes tiesības saskaņā ar apliecinājumu koku ciršanai. Melnalksn',
#   'Sējas nov.Pabaži',
#   '2.50 ha.',
#   3500,
#   '€'],
#  ['https://www.ss.com/msg/lv/real-estate/wood/riga-region/incukalna-nov/icnbn.html',
#   'Privātai apbūvei paredzēts zemes gabals 5500 m2 26 km no Rīgas robežas Pleskavas šos',
#   'Inčukalna nov.Krustiņi',
#   '5500 m²',
#   14000,
#   '€']]

# %%
df = pd.DataFrame(aizlist)
df
# Out:
#                                                    0  \
# 0  https://www.ss.com/msg/lv/real-estate/wood/rig...
# 1  https://www.ss.com/msg/lv/real-estate/wood/rig...
# 2  https://www.ss.com/msg/lv/real-estate/wood/rig...
# 3  https://www.ss.com/msg/lv/real-estate/wood/rig...
# 4  https://www.ss.com/msg/lv/real-estate/wood/rig...
# 5  https://www.ss.com/msg/lv/real-estate/wood/rig...
# 6  https://www.ss.com/msg/lv/real-estate/wood/rig...
#
#                                                    1  \
# 0  Pārdod pieauguša meža audzi. Daļēji izstrādāts...
# 1  Pārdod cirsmu 80m3 Priedes, īpašums ceļa malā,...
# 2  Īpašnieks pārdod cirsmu. Var izstrādāt priedi,...
# 3  AS Privatbank meitas uzņēmuma īpašums. Zemes g...
# 4  Saimnieks pārdod neizcirstu mežu ar zemi glezn...
# 5  Pārdodu cirsmas izstrādes tiesības saskaņā ar ...
# 6  Privātai apbūvei paredzēts zemes gabals 5500 m...
#
#                            2         3      4  5
# 0          Ropažu nov.Ropaži    10 ha.  12500  €
# 1      Stopiņu nov.Upeslejas     80 m²   3500  €
# 2    Carnikavas nov.Garciems     1 ha.  12000  €
# 3  Garkalnes nov.Makstenieki  3.45 ha.  95000  €
# 4      Krimuldas pag.Turaida  9.20 ha.  39000  €
# 5           Sējas nov.Pabaži  2.50 ha.   3500  €
# 6     Inčukalna nov.Krustiņi   5500 m²  14000  €

# %%
len(myrows)
# Out:
# 7

# %%
cleanedrows = processPage(myrows)
cleanedrows
# Out:
# [['https://www.ss.com/msg/lv/real-estate/wood/riga-region/ropazu-nov/goxxb.html',
#   'Pārdod pieauguša meža audzi. Daļēji izstrādāts. Izstrādājamā krāja redzama invet',
#   'Ropažu nov.Ropaži',
#   '10 ha.',
#   12500,
#   '€'],
#  ['https://www.ss.com/msg/lv/real-estate/wood/riga-region/stopinu-nov/gcdeb.html',
#   'Pārdod cirsmu 80m3 Priedes, īpašums ceļa malā, saņemts CA.',
#   'Stopiņu nov.Upeslejas',
#   '80 m²',
#   3500,
#   '€'],
#  ['https://www.ss.com/msg/lv/real-estate/wood/riga-region/carnikavas-nov/njfcg.html',
#   'Īpašnieks pārdod cirsmu. Var izstrādāt priedi, virs 200m3',
#   'Carnikavas nov.Garciems',
#   '1 ha.',
#   12000,
#   '€'],
#  ['https://www.ss.com/msg/lv/real-estate/wood/riga-region/garkalnes-nov/jplnx.html',
#   'AS Privatbank meitas uzņēmuma īpašums. Zemes gabala kopējā platība 3.45 ha. Zemes',
#   'Garkalnes nov.Makstenieki',
#   '3.45 ha.',
#   95000,
#   '€'],
#  ['https://www.ss.com/msg/lv/real-estate/wood/riga-region/krimuldas-pag/fmlml.html',
#   'Saimnieks pārdod neizcirstu mežu ar zemi gleznainā vietā. Labs piebraucamais ceļš. M',
#   'Krimuldas pag.Turaida',
#   '9.20 ha.',
#   39000,
#   '€'],
#  ['https://www.ss.com/msg/lv/real-estate/wood/riga-region/sejas-nov/knfgb.html',
#   'Pārdodu cirsmas izstrādes tiesības saskaņā ar apliecinājumu koku ciršanai. Melnalksn',
#   'Sējas nov.Pabaži',
#   '2.50 ha.',
#   3500,
#   '€'],
#  ['https://www.ss.com/msg/lv/real-estate/wood/riga-region/incukalna-nov/icnbn.html',
#   'Privātai apbūvei paredzēts zemes gabals 5500 m2 26 km no Rīgas robežas Pleskavas šos',
#   'Inčukalna nov.Krustiņi',
#   '5500 m²',
#   14000,
#   '€']]

# %%
def processPages(pages):
    mylist=[]
    for page in pages:
        mylist +=

# %%
ranchors[0]
# Out:
# <a class="am" data="JUFEJUFCeSU4MiU4OSU4OCVGNiVBM3olODAlODYlODUlQUElQTR5JTgwJTgwJTg5JUFDJUEzdSU3RCU4Mw==|zrEKPU" href="/msg/lv/real-estate/wood/riga-region/ropazu-nov/goxxb.html" id="dm_46210202"><b>Pārdod pieauguša meža audzi.
# Daļēji izstrādāts.
# Izstrādājamā krāja redzama invet</b></a>

# %%
rurls= [baseurl+el['href'] for el in ranchors]
rurls[0]
# Out:
# 'https://www.ss.com/msg/lv/real-estate/wood/riga-region/allazu-pag/delcg.html'

# %%
sellist[0]
# Out:
# 'https://www.ss.com/lv/real-estate/wood/riga-region/sell/'

# %%
def getUrlList(url, prefix='https://www.ss.com', postfix='sell/', tag='a', class_='a_category'):
    req = requests.get(url)
    if req.status_code != 200:
        print(f'Unexpected status code {req.status_code}. Stopping parse')
        return [] #return early and often principle
    soup = BeautifulSoup(req.text, 'lxml') # could skip soup variable as well but keeping for readability
    return [ prefix + el['href'] + postfix for el in soup.find_all(tag, class_) ]
    # What else could we pass as argument? How could our return fail?

# %%
alist = getUrlList("https://www.ss.com/lv/real-estate/flats/")
len(alist)
# Out:
# 30

# %%
alist[:3]
# Out:
# ['https://www.ss.com/lv/real-estate/flats/riga/sell/',
#  'https://www.ss.com/lv/real-estate/flats/jurmala/sell/',
#  'https://www.ss.com/lv/real-estate/flats/riga-region/sell/']

# %%
rlist=getUrlList('https://www.ss.com/lv/real-estate/flats/riga-region/sell/', postfix='')
rlist[:5]
# Out:
# ['https://www.ss.com/lv/real-estate/flats/riga-region/baldone/sell/',
#  'https://www.ss.com/lv/real-estate/flats/riga-region/balozi/sell/',
#  'https://www.ss.com/lv/real-estate/flats/riga-region/olaine/sell/',
#  'https://www.ss.com/lv/real-estate/flats/riga-region/salaspils/sell/',
#  'https://www.ss.com/lv/real-estate/flats/riga-region/saulkrasti/sell/']

# %%
rlist[0]
# Out:
# 'https://www.ss.com/lv/real-estate/flats/riga-region/baldone/sell/'

# %%
processPage(rlist[0])
# Out:
# Processing: <title>SS.COM Dzīvokļi - Rīgas rajons - Baldone, Cenas, Pārdod - Sludinājumi</title>
# [['https://www.ss.com/msg/lv/real-estate/flats/riga-region/baldone/ebelk.html',
#   'Īpašniece pārdod dzīvokli Baldones centrā. Ķieģeļu mūra māja. Ma',
#   'Rīgas 75',
#   '3',
#   '51',
#   '2/2',
#   'Specpr.',
#   '745 €',
#   38000,
#   '€'],
#  ['https://www.ss.com/msg/lv/real-estate/flats/riga-region/baldone/dpxcn.html',
#   'Pārdodu dzīvokli ar balkonu. Divas istabas izolētas. Balkons ar',
#   'Zīļu 15',
#   '2',
#   '52',
#   '3/2',
#   'Specpr.',
#   '1,000 €',
#   52000,
#   '€'],
#  ['https://www.ss.com/msg/lv/real-estate/flats/riga-region/baldone/kidii.html',
#   'Pārdodu dzīvokli kopā ar garāžu pilsētā pie dabas un ainavas pla',
#   'Zīļu 15 11',
#   '3',
#   '136',
#   '2/3',
#   'Renov.',
#   '560 €',
#   76160,
#   '€'],
#  ['https://www.ss.com/msg/lv/real-estate/flats/riga-region/baldone/kiilb.html',
#   'Pārdod 2-istabu dzīvokli 3. stāvā 3 stāvu mājā. 1. dzīvojamā',
#   'Pārupes ielā 2',
#   '2',
#   '55',
#   '3/3',
#   'LT proj.',
#   '818 €',
#   45000,
#   '€'],
#  ['https://www.ss.com/msg/lv/real-estate/flats/riga-region/baldone/ckled.html',
#   'Saimnieks pārdod 2 istabu dzīvokli Baldonē, centrā - ķieģeļu māj',
#   'Rīgas 61 3',
#   '2',
#   '46',
#   '1/2',
#   'Specpr.',
#   '652 €',
#   30000,
#   '€'],
#  ['https://www.ss.com/msg/lv/real-estate/flats/riga-region/baldone/cpkkg.html',
#   'Pardodas dzīvoklis Baldonē. 5minūšu gājienā no centra, blakus',
#   'Pārupes 4',
#   '2',
#   '61',
#   '3/3',
#   'Specpr.',
#   '852 €',
#   52000,
#   '€'],
#  ['https://www.ss.com/msg/lv/real-estate/flats/riga-region/baldone/fippx.html',
#   'Pārdodu maksimāli izremontētu dzīvokli. Gāzes apkure. Labi kaimi',
#   'Prieduļu 4',
#   '3',
#   '72',
#   '3/3',
#   'M. ģim.',
#   '694 €',
#   50000,
#   '€'],
#  ['https://www.ss.com/msg/lv/real-estate/flats/riga-region/baldone/fdeih.html',
#   'Pārdod 2-istabu dzīvokli Baldonē, renovētā, siltinātā mājā. Ļo',
#   'Vanagkalnu 21',
#   '2',
#   '48',
#   '3/3',
#   'Renov.',
#   '979 €',
#   47000,
#   '€'],
#  ['https://www.ss.com/msg/lv/real-estate/flats/riga-region/baldone/kclob.html',
#   'Pārdod divistabu dzīvokli 51 kv. m. Baldones lauku teritorija, b',
#   'Līgotāji 4',
#   '2',
#   '51',
#   '2/2',
#   'Specpr.',
#   '569 €',
#   29000,
#   '€'],
#  ['https://www.ss.com/msg/lv/real-estate/flats/riga-region/baldone/jilki.html',
#   'Pārdodu labiekārtotu dzīvokli ar iebūvējamām mēbelēm. Ja rodas k',
#   'Daugavas 9',
#   '1',
#   '35',
#   '4/4',
#   'Specpr.',
#   '1,014 €',
#   35500,
#   '€'],
#  ['https://www.ss.com/msg/lv/real-estate/flats/riga-region/baldone/edimp.html',
#   'Pārdod teicamā stāvoklī pilnībā renovētu labi aprīkotu dzīvokli',
#   'Rīgas 69',
#   '2',
#   '43',
#   '1/2',
#   'Specpr.',
#   '1,070 €',
#   46000,
#   '€'],
#  ['https://www.ss.com/msg/lv/real-estate/flats/riga-region/baldone/khkjp.html',
#   'Pārdod vienistabas dzīvokli 37 kv. m. Baldones lauku teritorijā,',
#   'Līgotāji 3',
#   '1',
#   '37',
#   '2/2',
#   'Specpr.',
#   '514 €',
#   19000,
#   '€']]

# %%
rreq = requests.get(rurl)
rreq.status_code
# Out:
# 200

# %%
rsoup = BeautifulSoup(rreq.text, 'lxml')
rsoup.title
# Out:
# <title>SS.COM Mežs - Rīgas rajons, Cenas, Pārdod - Sludinājumi</title>

# %%
rtables = rsoup.find_all('table')
len(rtables)
# Out:
# 11

# %%
import re

# %%
rrows = rsoup.find_all('tr',id = re.compile(r'tr_*')) #basic wildcard search could use tr_ in lambda function
len(rrows)
# Out:
# 15

# %%
headline = rsoup.find('tr', id = "head_line")
print(headline)
# Out:
# <tr id="head_line">
# <td class="msg_column" colspan="3" width="70%">
# <span style="float:left;"> Sludinājumi
# </span>
# <span align="right" class="msg_column" style="float:right;text-align:right;padding-right:3px;">
# <noindex>
# <a class="a19" href="/lv/real-estate/wood/riga-region/sell/fDgSeF4S.html" rel="nofollow">datums</a></noindex></span>
# </td>
# <td class="msg_column_td" nowrap=""><noindex><a class="a18" href="/lv/real-estate/wood/riga-region/sell/fDgSeF4bEFV8FQ==.html" rel="nofollow" title="">Pagasts</a></noindex></td><td class="msg_column_td" nowrap=""><noindex><a class="a18" href="/lv/real-estate/wood/riga-region/sell/fDgSeF4QelM=.html" rel="nofollow" title="">m2</a></noindex></td><td class="msg_column_td" nowrap=""><noindex><a class="a18" href="/lv/real-estate/wood/riga-region/sell/fDgSeF4belM=.html" rel="nofollow" title="">Cena</a></noindex></td></tr>

# %%
cindex = [el.text for el in headline.find_all('td')]
cindex
# Out:
# ['\n\xa0Sludinājumi\r\n\n\n\ndatums\n', 'Pagasts', 'm2', 'Cena']

# %%
cindex[0].split()[0]
# Out:
# 'Sludinājumi'

# %%
cindex[0] = cindex[0].split()[0]
cindex
# Out:
# ['Sludinājumi', 'Pagasts', 'm2', 'Cena']

# %%
cindex += ['URL']  #vai cindex.append('URL')
cindex
# Out:
# ['Sludinājumi', 'Pagasts', 'm2', 'Cena', 'URL']

# %%
def getRowData(row):
    return [el.text for el in row.find_all('td')[2:]] + [baseurl + row.find('a')['href']]

# %%
rowdata = getRowData(rrows[0])
rowdata
# Out:
# ['Ja vēlies dzīvot ekoloģiskā lauku vidē un tajā pašā laikā būt tuvumā pilsētas infras',
#  'Allažu pag.Allažmuiža',
#  '32.30 ha.',
#  '150,000  €',
#  'https://www.ss.com/msg/lv/real-estate/wood/riga-region/allazu-pag/delcg.html']

# %%
rowsdata = [getRowData(el) for el in rrows] # It should work but what there is a hidden last element :)
rowsdata
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-71-c613233d3943> in <module>()
# ----> 1 rowsdata = [getRowData(el) for el in rrows]
#       2 rowsdata
#
# <ipython-input-71-c613233d3943> in <listcomp>(.0)
# ----> 1 rowsdata = [getRowData(el) for el in rrows]
#       2 rowsdata
#
# <ipython-input-65-1af799dc4198> in getRowData(row)
#       1 def getRowData(row):
# ----> 2     return [el.text for el in row.find_all('td')[2:]] + [baseurl + row.find('a')['href']]
#
# TypeError: 'NoneType' object is not subscriptable

# %%
rowsdata = [getRowData(el) for el in rrows[:-1]] # so we just skip the last element
rowsdata
# Out:
# [['Ja vēlies dzīvot ekoloģiskā lauku vidē un tajā pašā laikā būt tuvumā pilsētas infras',
#   'Allažu pag.Allažmuiža',
#   '32.30 ha.',
#   '150,000  €',
#   'https://www.ss.com/msg/lv/real-estate/wood/riga-region/allazu-pag/delcg.html'],
#  ['Pardodu apaugumu, nodastots 2018 gada vasara. 160kubi, papirmalka, tara. (Berzs)\r\nIp',
#   'Olaines pag.Pēternieki',
#   '1 ha.',
#   '5,000  €',
#   'https://www.ss.com/msg/lv/real-estate/wood/riga-region/olaines-pag/iegfb.html'],
#  ['Pārdod cirsmu Mālpils pagastā, Mālpils novadā. Kopā 2775 m3. (Ba 1200m3, B 800m3, E ',
#   'Mālpils pag.Mālpils',
#   '9.90 ha.',
#   '100,000  €',
#   'https://www.ss.com/msg/lv/real-estate/wood/riga-region/malpils-pag/objbi.html'],
#  ['Pārdod cirsmu Siguldas pagastā, Siguldas novadā. Kopā 679, 59m3.',
#   'Siguldas pag.Peltes',
#   '2.30 ha.',
#   '30,000  €',
#   'https://www.ss.com/msg/lv/real-estate/wood/riga-region/siguldas-pag/dnxnb.html'],
#  ['Tirgoju cirsmas iztrādes tiesības (kokus uz celma).',
#   'Salaspils',
#   '2.30 ha.',
#   '10,100  €',
#   'https://www.ss.com/msg/lv/real-estate/wood/riga-region/salaspils/jnlkb.html'],
#  ['Kailcirtē tiek piedāvātas cirsmas 1. un 5. nogabalos, kuros audze pārsvarā sastāv no',
#   'Inčukalna nov.Inčukalns',
#   '0.50 ha.',
#   '8,000  €',
#   'https://www.ss.com/msg/lv/real-estate/wood/riga-region/incukalna-nov/ioopo.html'],
#  ['Pārdodu īpašumu - Indras, 7.8ha platībā, no kuriem 5.7ha ir mežs, pārējā ir lauksaim',
#   'Ropažu nov.Augšciems',
#   '7.80 ha.',
#   '18,000  €',
#   'https://www.ss.com/msg/lv/real-estate/wood/riga-region/ropazu-nov/bmkxk.html'],
#  ['Pārdodu Mežu kopā ar zemi Baldonē. Mežš 3, 18 ha. zeme 1 h. apkārtne apdzīvota, ir e',
#   'Baldone',
#   '4.13 ha.',
#   '55,000  €',
#   'https://www.ss.com/msg/lv/real-estate/wood/riga-region/baldone/gdfie.html'],
#  ['Privātai apbūvei paredzēts zemes gabals 5500 m2 26 km no Rīgas robežas Pleskavas šos',
#   'Inčukalna nov.Krustiņi',
#   '5500 m²',
#   '14,000  €',
#   'https://www.ss.com/msg/lv/real-estate/wood/riga-region/incukalna-nov/icnbn.html'],
#  ['Pārdodu cirsmas Ropažu novadā. \r\n\r\nMežā pie Tumšupes. \r\nKailcirte 0, 3ha. 10Ba53. Au',
#   'Ropažu nov.Ropaži',
#   '3 ha.',
#   '6,000  €',
#   'https://www.ss.com/msg/lv/real-estate/wood/riga-region/ropazu-nov/icbnj.html'],
#  ['Pardodu cirsmas izstrades tiesibas. 200cm3, vasara nodastots. \r\nUn 50-80 berkubi zar',
#   'Olaine',
#   '1 ha.',
#   '6,000  €',
#   'https://www.ss.com/msg/lv/real-estate/wood/riga-region/olaine/idpfh.html'],
#  ['Pārdodam izstrādātus mežus, platības nav lielas, ir arī ar nelielu atlikumu ciršanai',
#   'Sējas nov.',
#   '15 ha.',
#   '20,000  €',
#   'https://www.ss.com/msg/lv/real-estate/wood/riga-region/sejas-nov/bdpfe.html'],
#  ['Pārdod mežu Jūrmalā, inventarizācija nav veikta, iesp. kopšanas cirtes.',
#   '-',
#   '4.61 ha.',
#   '8,000  €',
#   'https://www.ss.com/msg/lv/real-estate/wood/riga-region/jurmala/mokin.html'],
#  ['Pārdodu cirsmas izstrādes tiesības. Cirsma ir izdastota 2016.gadā. Ir divi izvešanas',
#   'Ādažu nov.Eimuri',
#   '0.35 ha.',
#   '5,800  €',
#   'https://www.ss.com/msg/lv/real-estate/wood/riga-region/adazu-nov/dbdbi.html']]

# %%
df = pd.DataFrame(rowsdata, columns=cindex)
df
# Out:
#                                           Sludinājumi  \
# 0   Ja vēlies dzīvot ekoloģiskā lauku vidē un tajā...
# 1   Pardodu apaugumu, nodastots 2018 gada vasara. ...
# 2   Pārdod cirsmu Mālpils pagastā, Mālpils novadā....
# 3   Pārdod cirsmu Siguldas pagastā, Siguldas novad...
# 4   Tirgoju cirsmas iztrādes tiesības (kokus uz ce...
# 5   Kailcirtē tiek piedāvātas cirsmas 1. un 5. nog...
# 6   Pārdodu īpašumu - Indras, 7.8ha platībā, no ku...
# 7   Pārdodu Mežu kopā ar zemi Baldonē. Mežš 3, 18 ...
# 8   Privātai apbūvei paredzēts zemes gabals 5500 m...
# 9   Pārdodu cirsmas Ropažu novadā. \r\n\r\nMežā pi...
# 10  Pardodu cirsmas izstrades tiesibas. 200cm3, va...
# 11  Pārdodam izstrādātus mežus, platības nav liela...
# 12  Pārdod mežu Jūrmalā, inventarizācija nav veikt...
# 13  Pārdodu cirsmas izstrādes tiesības. Cirsma ir ...
#
#                     Pagasts         m2        Cena  \
# 0     Allažu pag.Allažmuiža  32.30 ha.  150,000  €
# 1    Olaines pag.Pēternieki      1 ha.    5,000  €
# 2       Mālpils pag.Mālpils   9.90 ha.  100,000  €
# 3       Siguldas pag.Peltes   2.30 ha.   30,000  €
# 4                 Salaspils   2.30 ha.   10,100  €
# 5   Inčukalna nov.Inčukalns   0.50 ha.    8,000  €
# 6      Ropažu nov.Augšciems   7.80 ha.   18,000  €
# 7                   Baldone   4.13 ha.   55,000  €
# 8    Inčukalna nov.Krustiņi    5500 m²   14,000  €
# 9         Ropažu nov.Ropaži      3 ha.    6,000  €
# 10                   Olaine      1 ha.    6,000  €
# 11               Sējas nov.     15 ha.   20,000  €
# 12                        -   4.61 ha.    8,000  €
# 13         Ādažu nov.Eimuri   0.35 ha.    5,800  €
#
#                                                   URL
# 0   https://www.ss.com/msg/lv/real-estate/wood/rig...
# 1   https://www.ss.com/msg/lv/real-estate/wood/rig...
# 2   https://www.ss.com/msg/lv/real-estate/wood/rig...
# 3   https://www.ss.com/msg/lv/real-estate/wood/rig...
# 4   https://www.ss.com/msg/lv/real-estate/wood/rig...
# 5   https://www.ss.com/msg/lv/real-estate/wood/rig...
# 6   https://www.ss.com/msg/lv/real-estate/wood/rig...
# 7   https://www.ss.com/msg/lv/real-estate/wood/rig...
# 8   https://www.ss.com/msg/lv/real-estate/wood/rig...
# 9   https://www.ss.com/msg/lv/real-estate/wood/rig...
# 10  https://www.ss.com/msg/lv/real-estate/wood/rig...
# 11  https://www.ss.com/msg/lv/real-estate/wood/rig...
# 12  https://www.ss.com/msg/lv/real-estate/wood/rig...
# 13  https://www.ss.com/msg/lv/real-estate/wood/rig...

# %%
bigdf = pd.concat([df,df])
bigdf
# Out:
#                                           Sludinājumi  \
# 0   Ja vēlies dzīvot ekoloģiskā lauku vidē un taj
https://www.ss.com/msg/lv/real-estate/wood/rig...
# 1   https://www.ss.com/msg/lv/real-estate/wood/rig...
# 2   https://www.ss.com/msg/lv/real-estate/wood/rig...
# 3   https://www.ss.com/msg/lv/real-estate/wood/rig...
# 4   https://www.ss.com/msg/lv/real-estate/wood/rig...
# 5   https://www.ss.com/msg/lv/real-estate/wood/rig...
# 6   https://www.ss.com/msg/lv/real-estate/wood/rig...
# 7   https://www.ss.com/msg/lv/real-estate/wood/rig...
# 8   https://www.ss.com/msg/lv/real-estate/wood/rig...
# 9   https://www.ss.com/msg/lv/real-estate/wood/rig...
# 10  https://www.ss.com/msg/lv/real-estate/wood/rig...
# 11  https://www.ss.com/msg/lv/real-estate/wood/rig...
# 12  https://www.ss.com/msg/lv/real-estate/wood/rig...
# 13  https://www.ss.com/msg/lv/real-estate/wood/rig...
# 0   https://www.ss.com/msg/lv/real-estate/wood/rig...
# 1   https://www.ss.com/msg/lv/real-estate/wood/rig...
# 2   https://www.ss.com/msg/lv/real-estate/wood/rig...
# 3   https://www.ss.com/msg/lv/real-estate/wood/rig...
# 4   https://www.ss.com/msg/lv/real-estate/wood/rig...
# 5   https://www.ss.com/msg/lv/real-estate/wood/rig...
# 6   https://www.ss.com/msg/lv/real-estate/wood/rig...
# 7   https://www.ss.com/msg/lv/real-estate/wood/rig...
# 8   https://www.ss.com/msg/lv/real-estate/wood/rig...
# 9   https://www.ss.com/msg/lv/real-estate/wood/rig...
# 10  https://www.ss.com/msg/lv/real-estate/wood/rig...
# 11  https://www.ss.com/msg/lv/real-estate/wood/rig...
# 12  https://www.ss.com/msg/lv/real-estate/wood/rig...
# 13  https://www.ss.com/msg/lv/real-estate/wood/rig...

# %%
def getDFfromUrl(url):
    print(f'Going gather data from URL:{url}')
    req = requests.get(url)
    if req.status_code != 200:
        print(f'Unexpected status code {req.status_code}. Stopping parse')
        return [] #return early and often principle
    soup = BeautifulSoup(req.text, 'lxml') # could skip soup variable as well but keeping for readability
    headline = soup.find('tr', id = "head_line")
    cindex = [el.text for el in headline.find_all('td')]
    cindex[0] = cindex[0].split()[0]
    cindex += ['URL'] #TODO add argument for this
    rows = soup.find_all('tr',id = re.compile(r'tr_*'))
    rowsdata = [getRowData(el) for el in rows[:-1]]
    return pd.DataFrame(rowsdata, columns=cindex)

# %%
df2 = getDFfromUrl(woodlist[12])
df2
# Out:
# Going gather data from URL:https://www.ss.com/lv/real-estate/wood/kuldiga-and-reg/sell/
#                                          Sludinājumi                Pagasts  \
# 0  Tiek pārdots ½ daļa no zemes gabala, kas sastā...           Padures pag.
# 1  Pārdod nekustamo īpašumu, platība 2.9ha. Cena ...  Rudbāržu pag.Rudbārži
# 2  Īpašumā atrodas 3 stāvu jaunbūve, dīķis un 4 h...                Kuldīga
#
#           m2        Cena                                                URL
# 0   9.90 ha.   15,000  €  https://www.ss.com/msg/lv/real-estate/wood/kul...
# 1   2.90 ha.      123  €  https://www.ss.com/msg/lv/real-estate/wood/kul...
# 2  28.80 ha.  138,000  €  https://www.ss.com/msg/lv/real-estate/wood/kul...

# %%
def getDFfromUrlList(urlist):
    dflist = []
    for ur in urlist:
        dflist.append(getDFfromUrl(ur))
    return pd.concat(dflist)

# %%
bigdf = getDFfromUrlList(woodlist)
bigdf
# Out:
# Going gather data from URL:https://www.ss.com/lv/real-estate/wood/riga-region/sell/
# Going gather data from URL:https://www.ss.com/lv/real-estate/wood/aizkraukle-and-reg/sell/
# Going gather data from URL:https://www.ss.com/lv/real-estate/wood/aluksne-and-reg/sell/
# Going gather data from URL:https://www.ss.com/lv/real-estate/wood/balvi-and-reg/sell/
# Going gather data from URL:https://www.ss.com/lv/real-estate/wood/bauska-and-reg/sell/
# Going gather data from URL:https://www.ss.com/lv/real-estate/wood/cesis-and-reg/sell/
# Going gather data from URL:https://www.ss.com/lv/real-estate/wood/daugavpils-and-reg/sell/
# Going gather data from URL:https://www.ss.com/lv/real-estate/wood/dobele-and-reg/sell/
# Going gather data from URL:https://www.ss.com/lv/real-estate/wood/gulbene-and-reg/sell/
# Going gather data from URL:https://www.ss.com/lv/real-estate/wood/jekabpils-and-reg/sell/
# Going gather data from URL:https://www.ss.com/lv/real-estate/wood/jelgava-and-reg/sell/
# Going gather data from URL:https://www.ss.com/lv/real-estate/wood/kraslava-and-reg/sell/
# Going gather data from URL:https://www.ss.com/lv/real-estate/wood/kuldiga-and-reg/sell/
# Going gather data from URL:https://www.ss.com/lv/real-estate/wood/liepaja-and-reg/sell/
# Going gather data from URL:https://www.ss.com/lv/real-estate/wood/limbadzi-and-reg/sell/
# Going gather data from URL:https://www.ss.com/lv/real-estate/wood/ludza-and-reg/sell/
# Going gather data from URL:https://www.ss.com/lv/real-estate/wood/madona-and-reg/sell/
# Going gather data from URL:https://www.ss.com/lv/real-estate/wood/ogre-and-reg/sell/
# Going gather data from URL:https://www.ss.com/lv/real-estate/wood/preili-and-reg/sell/
# Going gather data from URL:https://www.ss.com/lv/real-estate/wood/rezekne-and-reg/sell/
# Going gather data from URL:https://www.ss.com/lv/real-estate/wood/saldus-and-reg/sell/
# Going gather data from URL:https://www.ss.com/lv/real-estate/wood/talsi-and-reg/sell/
# Going gather data from URL:https://www.ss.com/lv/real-estate/wood/tukums-and-reg/sell/
# Going gather data from URL:https://www.ss.com/lv/real-estate/wood/valka-and-reg/sell/
# Going gather data from URL:https://www.ss.com/lv/real-estate/wood/valmiera-and-reg/sell/
# Going gather data from URL:https://www.ss.com/lv/real-estate/wood/ventspils-and-reg/sell/
# Going gather data from URL:https://www.ss.com/lv/real-estate/wood/other/sell/
#           Cena                     Pagasts  Pilsēta/rajons  \
# 0   150,000  €       Allažu pag.Allažmuiža             NaN
# 1     5,000  €      Olaines pag.Pēternieki             NaN
# 2   100,000  €         Mālpils pag.Mālpils             NaN
# 3    30,000  €         Siguldas pag.Peltes             NaN
# 4    10,100  €                   Salaspils             NaN
# 5     8,000  €     Inčukalna nov.Inčukalns             NaN
# 6    18,000  €        Ropažu nov.Augšciems             NaN
# 7    55,000  €                     Baldone             NaN
# 8    14,000  €      Inčukalna nov.Krustiņi             NaN
# 9     6,000  €           Ropažu nov.Ropaži             NaN
# 10    6,000  €                      Olaine             NaN
# 11   20,000  €                  Sējas nov.             NaN
# 12    8,000  €                           -             NaN
# 13    5,800  €            Ādažu nov.Eimuri             NaN
# 0    21,850  €              Seces pag.Sece             NaN
# 1    25,000  €                 Jaunjelgava             NaN
# 2     7,200  €              Daudzeses pag.             NaN
# 3    20,000  €             Bebru pag.Ozoli             NaN
# 0     5,600  €           Jaunalūksnes pag.             NaN
# 1       123  €  Jaunalūksnes pag.Kolberģis             NaN
# 2         5  €           Virešu pag.Vireši             NaN
# 3    16,000  €           Jaunalūksnes pag.             NaN
# 0    21,000  €       Bērzpils pag.Bērzpils             NaN
# 1       200  €           Vecumu pag.Vecumi             NaN
# 2        20  €       Bērzpils pag.Beļauski             NaN
# 3       100  €                       Balvi             NaN
# 4    10,500  €                  Balvu pag.             NaN
# 5    25,000  €       Vectilžas pag.Ranguči             NaN
# 6      0.01  €                  Balvu pag.             NaN
# 0   650,000  €                  Codes pag.             NaN
# ..         ...                         ...             ...
# 5     3,200  €       Dekšāres pag.Dekšāres             NaN
# 6     2,000  €        Kaunatas pag.Černiki             NaN
# 7    13,000  €      Silmalas pag.Deneliški             NaN
# 8    12,000  €    Ozolmuižas pag.Ozolmuiža             NaN
# 0      1.30  €            Šķēdes pag.Šķēde             NaN
# 0   400,000  €      Valdgales pag.Valdgale             NaN
# 1    69,999  €         Dundagas pag.Dūmele             NaN
# 2    20,000  €                  Rojas pag.             NaN
# 3   139,000  €                 Abavas pag.             NaN
# 4    16,000  €                Laidzes pag.             NaN
# 0   130,000  €                Engures pag.             NaN
# 1        45  €                     Kandava             NaN
# 2    90,000  €              Sēmes pag.Sēme             NaN
# 3    55,907  €            Zantes pag.Zante             NaN
# 4    45,000  €               Kandavas pag.             NaN
# 0     1,000  €         Jērcēnu pag.Jērcēni             NaN
# 1    45,000  €       Zvārtavas pag.Vērsīši             NaN
# 2    45,000  €         Bilskas pag.Lobērģi             NaN
# 3    45,000  €       Zvārtavas pag.Cirgaļi             NaN
# 4    12,346  €    Grundzāles pag.Grundzāle             NaN
# 5   150,000  €          Bilskas pag.Bilska             NaN
# 0     2,500  €           Kocēnu pag.Kocēni             NaN
# 1    10,000  €         Rencēnu pag.Lizdēni             NaN
# 2    27,000  €      Vilpulkas pag.Vilpulka             NaN
# 3   150,000  €               Vaidavas pag.             NaN
# 4    50,000  €               Sēļu pag.Sēļi             NaN
# 0    32,000  €              Usmas pag.Usma             NaN
# 1       100  €          Tārgales pag.Lūžņa             NaN
# 2    21,777  €              Ances pag.Ance             NaN
# 0    23,000  €                         NaN  Аглонский край
#
#                                           Sludinājumi  \
# 0   Ja vēlies dzīvot ekoloģiskā lauku vidē un tajā...
# 1   Pardodu apaugumu, nodastots 2018 gada vasara. ...
# 2   Pārdod cirsmu Mālpils pagastā, Mālpils novadā....
# 3   Pārdod cirsmu Siguldas pagastā, Siguldas novad...
# 4   Tirgoju cirsmas iztrādes tiesības (kokus uz ce...
# 5   Kailcirtē tiek piedāvātas cirsmas 1. un 5. nog...
# 6   Pārdodu īpašumu - Indras, 7.8ha platībā, no ku...
# 7   Pārdodu Mežu kopā ar zemi Baldonē. Mežš 3, 18 ...
# 8   Privātai apbūvei paredzēts zemes gabals 5500 m...
# 9   Pārdodu cirsmas Ropažu novadā. \r\n\r\nMežā pi...
# 10  Pardodu cirsmas izstrades tiesibas. 200cm3, va...
# 11  Pārdodam izstrādātus mežus, platības nav liela...
# 12  Pārdod mežu Jūrmalā, inventarizācija nav veikt...
# 13  Pārdodu cirsmas izstrādes tiesības. Cirsma ir ...
# 0   Pārdod cirsmas, izcērtamā platība 1040m3, no k...
# 1   Pārdod kailcirti tuvu ceļam izstrādāt var jebk...
# 2   Pārdodu mežu Jaunjelgavas novada Daudzeses pag...
# 3                Meža zeme ar 25 gadus vecu mežaudzi.
# 0   Pārdod Īpašumu, Alūksnes nov. , Jaunalūksnes p...
# 1   Pārdošanā cirsma. Visi dokumenti sagatavoti, l...
# 2   Pārdodam kailcirti ar platību 2, 79ha. \r\natr...
# 3   Pardod meza ipasumu kas sastav no 5 meza gabal...
# 0   Pārdod zemi kopā ar mežu Balvu novads Bērzpils...
# 1                              Pardodas cirsma 267m3.
# 2   Pārdodu bērza meža cirsmu. Kailcirte 8, 3 ha. ...
# 3   Pārdodu cirsmu Susāju pagastā 0.83ha, cena run...
# 4   Pārdod cirsmu Balvu pagastā, Balvu novadā. Pār...
# 5   Tiek pārdots īpašums (mežs ar zemi kopā), zvan...
# 6   Pārdod cirsmu Bērzpils pagastā, Balvu novadā. ...
# 0   Tiek pārdota ražotne ar aprīkojumu Bauskas raj...
# ..                                                ...
# 5   Pārdod cirmu, kas atrodas Dekšāres pagastā, Vi...
# 6   Pārdodu savu 1/3 daļu no kopīpašuma, vai arī v...
# 7    Pardod necirstu meza ipasumu kuru var izstradat.
# 8   Pārdodu koku ciršanas apliecinājumu (derīgs lī...
# 0   Pārdod, apaugumu 3 ha zemes, ir meža inventari...
# 0   Īpašnieks pārdod īpašumu Kristiņi, Valdgales p...
# 1   Paliela daļa bērzs, priede--gan kā mežs, gan k...
# 2                                   Pārdod meža zemi.
# 3   Kadastra numuri:astoņi astoņi četri divi nulle...
# 4   Pārdodu mežu 5.1 ha. Labi piebraucams ceļš. Ne...
# 0   Kopplatība 15, 0 ha, meža zeme 11, 02 ha, mežs...
# 1   Pārdodu labas kvalitātes sauskaltušus zāģbaļķu...
# 2   Īpašnieks pārdod mežu 32ha platībā Tukuma nov,...
# 3   Īpašums ar kopplatību 12, 7 ha, no tā Mežs- 5,...
# 4   Pārdod nekustamo īpašumu: dominējošā zemes kat...
# 0                         Pārdodas cirsma un apaugumi
# 1                                  Pārdodu meža audzi
# 2                                Pārdodu meža īpašumu
# 3                                  Pārdodu meža audzi
# 4   Vēlamies pārdot sagatavotu cirsmu izstrādei 3....
# 5   Zeme un mežs. Lauksaimniecības zeme apmežojusi...
# 0                          Cirsma priede, egle, bērzs
# 1   Pārdodu kailcirti, 250 m3, P56, E55, B66, Ba68...
# 2   Pārdodu 3 gab. cirsmas 195m3, 1280m3 un 450m3....
# 3   Pārdodu nezāģētu mežu. Pārsvarā priežu mežs ar...
# 4                          Pārdod mežu ar zemi 25 ha.
# 0   Zemes kopējā paltība ir 4, 9ha, no kuriem 3, 6...
# 1   Kopšanas cirte. Labs piebraucamais ceļš. Zvanī...
# 2              Pārdod daļēji izstrādātu meža īapšumu.
# 0   Продается два участка - земля с лесом. Один уч...
#
#                                                   URL          m2
# 0   https://www.ss.com/msg/lv/real-estate/wood/rig...   32.30 ha.
# 1   https://www.ss.com/msg/lv/real-estate/wood/rig...       1 ha.
# 2   https://www.ss.com/msg/lv/real-estate/wood/rig...    9.90 ha.
# 3   https://www.ss.com/msg/lv/real-estate/wood/rig...    2.30 ha.
# 4   https://www.ss.com/msg/lv/real-estate/wood/rig...    2.30 ha.
# 5   https://www.ss.com/msg/lv/real-estate/wood/rig...    0.50 ha.
# 6   https://www.ss.com/msg/lv/real-estate/wood/rig...    7.80 ha.
# 7   https://www.ss.com/msg/lv/real-estate/wood/rig...    4.13 ha.
# 8   https://www.ss.com/msg/lv/real-estate/wood/rig...     5500 m²
# 9   https://www.ss.com/msg/lv/real-estate/wood/rig...       3 ha.
# 10  https://www.ss.com/msg/lv/real-estate/wood/rig...       1 ha.
# 11  https://www.ss.com/msg/lv/real-estate/wood/rig...      15 ha.
# 12  https://www.ss.com/msg/lv/real-estate/wood/rig...    4.61 ha.
# 13  https://www.ss.com/msg/lv/real-estate/wood/rig...    0.35 ha.
# 0   https://www.ss.com/msg/lv/real-estate/wood/aiz...   12.92 ha.
# 1   https://www.ss.com/msg/lv/real-estate/wood/aiz...    0.70 ha.
# 2   https://www.ss.com/msg/lv/real-estate/wood/aiz...    7.20 ha.
# 3   https://www.ss.com/msg/lv/real-estate/wood/aiz...    6.80 ha.
# 0   https://www.ss.com/msg/lv/real-estate/wood/alu...    7.92 ha.
# 1   https://www.ss.com/msg/lv/real-estate/wood/alu...    0.50 ha.
# 2   https://www.ss.com/msg/lv/real-estate/wood/alu...    2.79 ha.
# 3   https://www.ss.com/msg/lv/real-estate/wood/alu...       5 ha.
# 0   https://www.ss.com/msg/lv/real-estate/wood/bal...    7.70 ha.
# 1   https://www.ss.com/msg/lv/real-estate/wood/bal...    0.90 ha.
# 2   https://www.ss.com/msg/lv/real-estate/wood/bal...    8.30 ha.
# 3   https://www.ss.com/msg/lv/real-estate/wood/bal...    0.83 ha.
# 4   https://www.ss.com/msg/lv/real-estate/wood/bal...    1.60 ha.
# 5   https://www.ss.com/msg/lv/real-estate/wood/bal...   14.90 ha.
# 6   https://www.ss.com/msg/lv/real-estate/wood/bal...       2 ha.
# 0   https://www.ss.com/msg/lv/real-estate/wood/bau...    2.15 ha.
# ..                                                ...         ...
# 5   https://www.ss.com/msg/lv/real-estate/wood/rez...    1.40 ha.
# 6   https://www.ss.com/msg/lv/real-estate/wood/rez...    5.20 ha.
# 7   https://www.ss.com/msg/lv/real-estate/wood/rez...    5.85 ha.
# 8   https://www.ss.com/msg/lv/real-estate/wood/rez...    1.12 ha.
# 0   https://www.ss.com/msg/lv/real-estate/wood/sal...       3 ha.
# 0   https://www.ss.com/msg/lv/real-estate/wood/tal...  109.90 ha.
# 1   https://www.ss.com/msg/lv/real-estate/wood/tal...   11.20 ha.
# 2   https://www.ss.com/msg/lv/real-estate/wood/tal...   13.60 ha.
# 3   https://www.ss.com/msg/lv/real-estate/wood/tal...   26.40 ha.
# 4   https://www.ss.com/msg/lv/real-estate/wood/tal...    5.10 ha.
# 0   https://www.ss.com/msg/lv/real-estate/wood/tuk...      15 ha.
# 1   https://www.ss.com/msg/lv/real-estate/wood/tuk...       1 ha.
# 2   https://www.ss.com/msg/lv/real-estate/wood/tuk...      32 ha.
# 3   https://www.ss.com/msg/lv/real-estate/wood/tuk...   12.70 ha.
# 4   https://www.ss.com/msg/lv/real-estate/wood/tuk...   18.24 ha.
# 0   https://www.ss.com/msg/lv/real-estate/wood/val...       7 ha.
# 1   https://www.ss.com/msg/lv/real-estate/wood/val...   10.50 ha.
# 2   https://www.ss.com/msg/lv/real-estate/wood/val...   19.80 ha.
# 3   https://www.ss.com/msg/lv/real-estate/wood/val...   10.70 ha.
# 4   https://www.ss.com/msg/lv/real-estate/wood/val...    3.12 ha.
# 5   https://www.ss.com/msg/lv/real-estate/wood/val...   60.10 ha.
# 0   https://www.ss.com/msg/lv/real-estate/wood/val...    0.55 ha.
# 1   https://www.ss.com/msg/lv/real-estate/wood/val...       1 ha.
# 2   https://www.ss.com/msg/lv/real-estate/wood/val...    4.50 ha.
# 3   https://www.ss.com/msg/lv/real-estate/wood/val...   23.80 ha.
# 4   https://www.ss.com/msg/lv/real-estate/wood/val...      25 ha.
# 0   https://www.ss.com/msg/lv/real-estate/wood/ven...    4.90 ha.
# 1   https://www.ss.com/msg/lv/real-estate/wood/ven...    2.50 ha.
# 2   https://www.ss.com/msg/lv/real-estate/wood/ven...   18.30 ha.
# 0   https://www.ss.com/msg/lv/real-estate/wood/oth...    3.10 ha.
#
# [135 rows x 6 columns]

# %%
# https://stackoverflow.com/questions/10607688/how-to-create-a-file-name-with-the-current-date-time-in-python
import time
timestr = time.strftime("%Y%m%d-%H%M%S")

#https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.to_excel.html
# Let's use with context manager so we do not forget to close writer!
with pd.ExcelWriter(f'sellers_{timestr}.xlsx') as writer:
    bigdf.to_excel(writer, sheet_name='Sheet_name_1')
