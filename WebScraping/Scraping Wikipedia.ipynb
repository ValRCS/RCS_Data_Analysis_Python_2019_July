# %%
# scraping https://en.wikipedia.org/wiki/List_of_countries_and_dependencies_by_population
import pandas as pd

# %%
df = pd.read_html("https://en.wikipedia.org/wiki/List_of_countries_and_dependencies_by_population", header=0)[0]
df.head()
# Out:
#   Rank Country(or dependent territory)  Population            Date  \
# 0    1                   China[Note 2]  1396930000  April 17, 2019
# 1    2                   India[Note 3]  1346060000  April 17, 2019
# 2    3           United States[Note 4]   329045000  April 17, 2019
# 3    4                       Indonesia   268074600    July 1, 2019
# 4    5                          Brazil   209785000  April 17, 2019
#
#   % of worldpopulation                      Source
# 0                18.1%   Official population clock
# 1                17.5%   Official population clock
# 2                4.27%   Official population clock
# 3                3.48%  Official annual projection
# 4                2.72%   Official population clock

# %%
df.to_csv('Countries.csv')

# %%
dfss = pd.read_html("https://www.ss.com/lv/real-estate/flats/riga/centre/sell/")[4]
dfss.head()
# Out:
#                       0                     1  \
# 0  Sludinājumi \tdatums  Sludinājumi \tdatums
# 1                   NaN                   NaN
# 2                   NaN                   NaN
# 3                   NaN                   NaN
# 4                   NaN                   NaN
#
#                                                    2             3     4   5  \
# 0                               Sludinājumi \tdatums          Iela  Ist.  m2
# 1  Īpašnieks pārdod omulīgu 2 istabu dzīvokli pir...  Brīvības 111     2  57
# 2  Продаётся квартира со свежим ремонтом, только ...     Gogoļa 13     2  48
# 3  Продаётся квартира, которая была переделана по...  Pētersalas 7     4  98
# 4  Продаётся квартира без ремонта. Туалет в кварт...  Pērnavas 37a     1  23
#
#        6        7         8         9
# 0  Stāvs   Sērija  Cena, m2      Cena
# 1    2/5  P. kara   1,474 €  84,000 €
# 2    4/5  P. kara   1,385 €  66,500 €
# 3    1/5  P. kara     714 €  69,999 €
# ...
