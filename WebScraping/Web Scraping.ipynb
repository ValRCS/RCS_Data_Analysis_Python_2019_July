# %%
import pandas as pd

# %%
tlist = pd.read_html('https://www.ss.com/lv/transport/cars/volkswagen/')

# %%
type(tlist)
# Out:
# list

# %%
len(tlist)
# Out:
# 10

# %%
tlist[7]
# Out:
#                                                     0        1  \
# 0                                Sludinājumi \tdatums  Modelis
# 1                                                 NaN      NaN
# 2                                                 NaN      NaN
# 3                                                 NaN      NaN
# 4                                                 NaN      NaN
# 5                                                 NaN      NaN
# 6                                                 NaN      NaN
# 7                                                 NaN      NaN
# 8                                                 NaN      NaN
# 9                                                 NaN      NaN
# 10                                                NaN      NaN
# 11                                                NaN      NaN
# 12                                                NaN      NaN
# 13                                                NaN      NaN
# 14                                                NaN      NaN
# 15                                                NaN      NaN
# 16                                                NaN      NaN
# 17                                                NaN      NaN
# 18                                                NaN      NaN
# 19                                                NaN      NaN
# 20                                                NaN      NaN
# 21                                                NaN      NaN
# 22                                                NaN      NaN
# 23                                                NaN      NaN
# 24                                                NaN      NaN
# 25                                                NaN      NaN
# 26                                                NaN      NaN
# 27                                                NaN      NaN
# 28                                                NaN      NaN
# 29                                                NaN      NaN
# 30                                                NaN      NaN
# 31  load_script_async("/w_inc/reklama.728.php?0||1...      NaN
#
#                                                     2            3         4  \
# 0                                                Gads        Tilp.  Nobrauk.
# 1   Pārdod VW Passat B7 ar bagātu komplektāciju. U...  Passat (B7)      2012
# 2   Lv/ru. 1.9Tdi. Laba, ekonomiska un ērta ģimene...       Toledo      2005
# 3   Caddy Life Maxi Webasto Navi Rns 315 Tikko pēc...        Caddy      2008
# 4   Labs darba zirdziņš ar ekonomisku dīzeļu 1, 9l...  Passat (B5)      2000
# 5   Mainitas siksnas Ella. 160zs. Laba stavokli. S...  Passat (B5)      2004
# 6   Pārdodu Volkswagen Golf V 2.0 Tdi. Motora jaud...       Golf 5      2008
# 7   T4 buss no Nīderlandes, 8+1 vietas, garā bāze....  Transporter      2001
# 8   VW Caravelle 2.5td 96kw, Отличное состояние, W...    Caravelle      2009
# 9   Sveiki, tiek pārdots labi kopts un saudzīgi br...       Sharan      2002
# 10  VW Passat Variant 2.0Tdi (103kw) Dsg Automātis...  Passat (B7)      2012
# 11  100 % īsts nobraukums - ļoti maziņš - tikai 93...       Golf 4      2000
# 12  VW Touareg 3.0D 176 Kw ar 240 zs. Individual k...      Touareg      2009
# 13  Pārdod VW Polo 2007.gada 1.4 Tdi (super ekonom...         Polo      2007
# 14  No Austrijas. VW Golf-4, 1.9Tdi, 66Kw, 2001g. ...       Golf 4      2001
# 15  08.09.2008 pirma registracija. labais 77kw diz...       Golf 5      2008
# 16  Pārdodu ļoti labi aprīkotu B6 universāli, 2.0 ...  Passat (B6)      2005
# 17  VW Touran 1.9 Diesel. 7-Мест. Гаражное хранени...       Touran      2003
# 18  Pārdodu vw passat b6 2.0tdi tehniski un vizuāl...  Passat (B6)      2006
# 19  Pārdodu auto labā tehniskā stāvoklī, jo ir ieg...       Touran      2007
# 20  Pārdodu vai mainu. 1.9dīzeļmotora golfs. Lec u...       Golf 4      1999
# 21  Pardod golfu ar svaigu skati un loti pilnu kom...       Golf 4      1999
# 22             Pārdodu wolksvagen T4. Tiko izieta TA.           T4      1994
# 23  Labdien. vēlos pārdot šo VW Polo. Mašīnai ir j...         Polo      1998
# 24  Pārdodu VW Golf 2.0 Benzin/gaze. Kvalitatīvs, ...       Golf 4      1999
# 25  VW Golf 6. 2.0Tdi 103kw ar 140 hp (common rail...       Golf 6      2012
# 26  Pārdodas passat labā tehniskā stāvoklī, virsū ...  Passat (B4)      1994
# 27  Normāls braucamais labā stāvoklī. Labas ziemas...       Golf 4      2003
# 28  Labs, ekonomisks auto. Nomainīta eļļa. TA līdz...       Golf 4      2001
# 29  Продам Passat 1998 года, 1.9 Tdi, 81kw, один и...  Passat (B5)      1998
# 30                     Braucams tik riepas janomaina.  Passat (B6)      2007
# 31                                                NaN          NaN       NaN
#
#        5           6              7
# 0   Cena         NaN            NaN
# 1   2.0D  258 tūkst.       10,500 €
# 2   1.9D           -  2,250 €maiņai
# 3   1.9D           -        4,190 €
# 4   1.9D  291 tūkst.        1,350 €
# 5   1.9D  306 tūkst.        2,850 €
# 6   2.0D  163 tūkst.        4,700 €
# 7   1.9D  254 tūkst.        2,950 €
# 8   2.5D  289 tūkst.        6,100 €
# 9   1.9D  278 tūkst.        1,850 €
# 10  2.0D  182 tūkst.        9,500 €
# 11   1.6           -        1,890 €
# 12  3.0D  220 tūkst.       10,000 €
# 13  1.4D           -        2,490 €
# 14  1.9D           -        2,350 €
# 15  1.9D  240 tūkst.        3,800 €
# 16  2.0D  343 tūkst.        3,000 €
# 17  1.9D           -        2,850 €
# 18  2.0D  298 tūkst.        2,992 €
# 19  2.0D  340 tūkst.        3,590 €
# 20  1.9D  260 tūkst.        1,000 €
# 21  1.9D  420 tūkst.        1,150 €
# 22  1.9D  325 tūkst.        1,600 €
# 23   1.4  282 tūkst.        1,000 €
# 24   2.0           -        1,590 €
# 25  2.0D  271 tūkst.        5,550 €
# 26   1.8  279 tūkst.          750 €
# 27  1.9D  350 tūkst.        1,700 €
# 28   1.4  292 tūkst.        1,350 €
# 29  1.9D  340 tūkst.        1,230 €
# 30  2.0D  224 tūkst.        1,800 €
# 31   NaN         NaN            NaN

# %%
df = tlist[7]

# %%
df
# Out:
#                                                     0        1  \
# 0                                Sludinājumi \tdatums  Modelis
# 1                                                 NaN      NaN
# 2                                                 NaN      NaN
# 3                                                 NaN      NaN
# 4                                                 NaN      NaN
# 5                                                 NaN      NaN
# 6                                                 NaN      NaN
# 7                                                 NaN      NaN
# 8                                                 NaN      NaN
# 9                                                 NaN      NaN
# 10                                                NaN      NaN
# 11                                                NaN      NaN
# 12                                                NaN      NaN
# 13                                                NaN      NaN
# 14                                                NaN      NaN
# 15                                                NaN      NaN
# 16                                                NaN      NaN
# 17                                                NaN      NaN
# 18                                                NaN      NaN
# 19                                                NaN      NaN
# 20                                                NaN      NaN
# 21                                                NaN      NaN
# 22                                                NaN      NaN
# 23                                                NaN      NaN
# 24                                                NaN      NaN
# 25                                                NaN      NaN
# 26                                                NaN      NaN
# 27                                                NaN      NaN
# 28                                                NaN      NaN
# 29                                                NaN      NaN
# 30                                                NaN      NaN
# 31  load_script_async("/w_inc/reklama.728.php?0||1...      NaN
#
#                                                     2            3         4  \
# 0                                                Gads        Tilp.  Nobrauk.
# 1   Pārdod VW Passat B7 ar bagātu komplektāciju. U...  Passat (B7)      2012
# 2   Lv/ru. 1.9Tdi. Laba, ekonomiska un ērta ģimene...       Toledo      2005
# 3   Caddy Life Maxi Webasto Navi Rns 315 Tikko pēc...        Caddy      2008
# 4   Labs darba zirdziņš ar ekonomisku dīzeļu 1, 9l...  Passat (B5)      2000
# 5   Mainitas siksnas Ella. 160zs. Laba stavokli. S...  Passat (B5)      2004
# 6   Pārdodu Volkswagen Golf V 2.0 Tdi. Motora jaud...       Golf 5      2008
# 7   T4 buss no Nīderlandes, 8+1 vietas, garā bāze....  Transporter      2001
# 8   VW Caravelle 2.5td 96kw, Отличное состояние, W...    Caravelle      2009
# 9   Sveiki, tiek pārdots labi kopts un saudzīgi br...       Sharan      2002
# 10  VW Passat Variant 2.0Tdi (103kw) Dsg Automātis...  Passat (B7)      2012
# 11  100 % īsts nobraukums - ļoti maziņš - tikai 93...       Golf 4      2000
# 12  VW Touareg 3.0D 176 Kw ar 240 zs. Individual k...      Touareg      2009
# 13  Pārdod VW Polo 2007.gada 1.4 Tdi (super ekonom...         Polo      2007
# 14  No Austrijas. VW Golf-4, 1.9Tdi, 66Kw, 2001g. ...       Golf 4      2001
# 15  08.09.2008 pirma registracija. labais 77kw diz...       Golf 5      2008
# 16  Pārdodu ļoti labi aprīkotu B6 universāli, 2.0 ...  Passat (B6)      2005
# 17  VW Touran 1.9 Diesel. 7-Мест. Гаражное хранени...       Touran      2003
# 18  Pārdodu vw passat b6 2.0tdi tehniski un vizuāl...  Passat (B6)      2006
# 19  Pārdodu auto labā tehniskā stāvoklī, jo ir ieg...       Touran      2007
# 20  Pārdodu vai mainu. 1.9dīzeļmotora golfs. Lec u...       Golf 4      1999
# 21  Pardod golfu ar svaigu skati un loti pilnu kom...       Golf 4      1999
# 22             Pārdodu wolksvagen T4. Tiko izieta TA.           T4      1994
# 23  Labdien. vēlos pārdot šo VW Polo. Mašīnai ir j...         Polo      1998
# 24  Pārdodu VW Golf 2.0 Benzin/gaze. Kvalitatīvs, ...       Golf 4      1999
# 25  VW Golf 6. 2.0Tdi 103kw ar 140 hp (common rail...       Golf 6      2012
# 26  Pārdodas passat labā tehniskā stāvoklī, virsū ...  Passat (B4)      1994
# 27  Normāls braucamais labā stāvoklī. Labas ziemas...       Golf 4      2003
# 28  Labs, ekonomisks auto. Nomainīta eļļa. TA līdz...       Golf 4      2001
# 29  Продам Passat 1998 года, 1.9 Tdi, 81kw, один и...  Passat (B5)      1998
# 30                     Braucams tik riepas janomaina.  Passat (B6)      2007
# 31                                                NaN          NaN       NaN
#
#        5           6              7
# 0   Cena         NaN            NaN
# 1   2.0D  258 tūkst.       10,500 €
# 2   1.9D           -  2,250 €maiņai
# 3   1.9D           -        4,190 €
# 4   1.9D  291 tūkst.        1,350 €
# 5   1.9D  306 tūkst.        2,850 €
# 6   2.0D  163 tūkst.        4,700 €
# 7   1.9D  254 tūkst.        2,950 €
# 8   2.5D  289 tūkst.        6,100 €
# 9   1.9D  278 tūkst.        1,850 €
# 10  2.0D  182 tūkst.        9,500 €
# 11   1.6           -        1,890 €
# 12  3.0D  220 tūkst.       10,000 €
# 13  1.4D           -        2,490 €
# 14  1.9D           -        2,350 €
# 15  1.9D  240 tūkst.        3,800 €
# 16  2.0D  343 tūkst.        3,000 €
# 17  1.9D           -        2,850 €
# 18  2.0D  298 tūkst.        2,992 €
# 19  2.0D  340 tūkst.        3,590 €
# 20  1.9D  260 tūkst.        1,000 €
# 21  1.9D  420 tūkst.        1,150 €
# 22  1.9D  325 tūkst.        1,600 €
# 23   1.4  282 tūkst.        1,000 €
# 24   2.0           -        1,590 €
# 25  2.0D  271 tūkst.        5,550 €
# 26   1.8  279 tūkst.          750 €
# 27  1.9D  350 tūkst.        1,700 €
# 28   1.4  292 tūkst.        1,350 €
# 29  1.9D  340 tūkst.        1,230 €
# 30  2.0D  224 tūkst.        1,800 €
# 31   NaN         NaN            NaN

# %%
df.columns
# Out:
# Int64Index([0, 1, 2, 3, 4, 5, 6, 7], dtype='int64')

# %%
df.columns = df[0]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-9edb213532b0> in <module>()
# ----> 1 df.columns = df[0]
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in __setattr__(self, name, value)
#    3625         try:
#    3626             object.__getattribute__(self, name)
# -> 3627             return object.__setattr__(self, name, value)
#    3628         except AttributeError:
#    3629             pass
#
# pandas/_libs/properties.pyx in pandas._libs.properties.AxisProperty.__set__()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in _set_axis(self, axis, labels)
#     557
#     558     def _set_axis(self, axis, labels):
# --> 559         self._data.set_axis(axis, labels)
#     560         self._clear_item_cache()
#     561
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals.py in set_axis(self, axis, new_labels)
#    3072             raise ValueError('Length mismatch: Expected axis has %d elements, '
#    3073                              'new values have %d elements' %
# -> 3074                              (old_len, new_len))
#    3075
#    3076         self.axes[axis] = new_labels
#
# ValueError: Length mismatch: Expected axis has 8 elements, new values have 32 elements

# %%
df[0]
# Out:
# 0                                  Sludinājumi \tdatums
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# 5                                                   NaN
# 6                                                   NaN
# 7                                                   NaN
# 8                                                   NaN
# 9                                                   NaN
# 10                                                  NaN
# 11                                                  NaN
# 12                                                  NaN
# 13                                                  NaN
# 14                                                  NaN
# 15                                                  NaN
# 16                                                  NaN
# 17                                                  NaN
# 18                                                  NaN
# 19                                                  NaN
# 20                                                  NaN
# 21                                                  NaN
# 22                                                  NaN
# 23                                                  NaN
# 24                                                  NaN
# 25                                                  NaN
# 26                                                  NaN
# 27                                                  NaN
# 28                                                  NaN
# 29                                                  NaN
# 30                                                  NaN
# 31    load_script_async("/w_inc/reklama.728.php?0||1...
# Name: 0, dtype: object

# %%
df.iloc[0,:]
# Out:
# 0    Sludinājumi \tdatums
# 1                 Modelis
# 2                    Gads
# 3                   Tilp.
# 4                Nobrauk.
# 5                    Cena
# 6                     NaN
# 7                     NaN
# Name: 0, dtype: object

# %%
## How to change column values
df.columns = df.iloc[0,:]

# %%
df
# Out:
# 0                                Sludinājumi \tdatums  Modelis  \
# 0                                Sludinājumi \tdatums  Modelis
# 1                                                 NaN      NaN
# 2                                                 NaN      NaN
# 3                                                 NaN      NaN
# 4                                                 NaN      NaN
# 5                                                 NaN      NaN
# 6                                                 NaN      NaN
# 7                                                 NaN      NaN
# 8                                                 NaN      NaN
# 9                                                 NaN      NaN
# 10                                                NaN      NaN
# 11                                                NaN      NaN
# 12                                                NaN      NaN
# 13                                                NaN      NaN
# 14                                                NaN      NaN
# 15                                                NaN      NaN
# 16                                                NaN      NaN
# 17                                                NaN      NaN
# 18                                                NaN      NaN
# 19                                                NaN      NaN
# 20                                                NaN      NaN
# 21                                                NaN      NaN
# 22                                                NaN      NaN
# 23                                                NaN      NaN
# 24                                                NaN      NaN
# 25                                                NaN      NaN
# 26                                                NaN      NaN
# 27                                                NaN      NaN
# 28                                                NaN      NaN
# 29                                                NaN      NaN
# 30                                                NaN      NaN
# 31  load_script_async("/w_inc/reklama.728.php?0||1...      NaN
#
# 0                                                Gads        Tilp.  Nobrauk.  \
# 0                                                Gads        Tilp.  Nobrauk.
# 1   Pārdod VW Passat B7 ar bagātu komplektāciju. U...  Passat (B7)      2012
# 2   Lv/ru. 1.9Tdi. Laba, ekonomiska un ērta ģimene...       Toledo      2005
# 3   Caddy Life Maxi Webasto Navi Rns 315 Tikko pēc...        Caddy      2008
# 4   Labs darba zirdziņš ar ekonomisku dīzeļu 1, 9l...  Passat (B5)      2000
# 5   Mainitas siksnas Ella. 160zs. Laba stavokli. S...  Passat (B5)      2004
# 6   Pārdodu Volkswagen Golf V 2.0 Tdi. Motora jaud...       Golf 5      2008
# 7   T4 buss no Nīderlandes, 8+1 vietas, garā bāze....  Transporter      2001
# 8   VW Caravelle 2.5td 96kw, Отличное состояние, W...    Caravelle      2009
# 9   Sveiki, tiek pārdots labi kopts un saudzīgi br...       Sharan      2002
# 10  VW Passat Variant 2.0Tdi (103kw) Dsg Automātis...  Passat (B7)      2012
# 11  100 % īsts nobraukums - ļoti maziņš - tikai 93...       Golf 4      2000
# 12  VW Touareg 3.0D 176 Kw ar 240 zs. Individual k...      Touareg      2009
# 13  Pārdod VW Polo 2007.gada 1.4 Tdi (super ekonom...         Polo      2007
# 14  No Austrijas. VW Golf-4, 1.9Tdi, 66Kw, 2001g. ...       Golf 4      2001
# 15  08.09.2008 pirma registracija. labais 77kw diz...       Golf 5      2008
# 16  Pārdodu ļoti labi aprīkotu B6 universāli, 2.0 ...  Passat (B6)      2005
# 17  VW Touran 1.9 Diesel. 7-Мест. Гаражное хранени...       Touran      2003
# 18  Pārdodu vw passat b6 2.0tdi tehniski un vizuāl...  Passat (B6)      2006
# 19  Pārdodu auto labā tehniskā stāvoklī, jo ir ieg...       Touran      2007
# 20  Pārdodu vai mainu. 1.9dīzeļmotora golfs. Lec u...       Golf 4      1999
# 21  Pardod golfu ar svaigu skati un loti pilnu kom...       Golf 4      1999
# 22             Pārdodu wolksvagen T4. Tiko izieta TA.           T4      1994
# 23  Labdien. vēlos pārdot šo VW Polo. Mašīnai ir j...         Polo      1998
# 24  Pārdodu VW Golf 2.0 Benzin/gaze. Kvalitatīvs, ...       Golf 4      1999
# 25  VW Golf 6. 2.0Tdi 103kw ar 140 hp (common rail...       Golf 6      2012
# 26  Pārdodas passat labā tehniskā stāvoklī, virsū ...  Passat (B4)      1994
# 27  Normāls braucamais labā stāvoklī. Labas ziemas...       Golf 4      2003
# 28  Labs, ekonomisks auto. Nomainīta eļļa. TA līdz...       Golf 4      2001
# 29  Продам Passat 1998 года, 1.9 Tdi, 81kw, один и...  Passat (B5)      1998
# 30                     Braucams tik riepas janomaina.  Passat (B6)      2007
# 31                                                NaN          NaN       NaN
#
# 0   Cena         NaN            NaN
# 0   Cena         NaN            NaN
# 1   2.0D  258 tūkst.       10,500 €
# 2   1.9D           -  2,250 €maiņai
# 3   1.9D           -        4,190 €
# 4   1.9D  291 tūkst.        1,350 €
# 5   1.9D  306 tūkst.        2,850 €
# 6   2.0D  163 tūkst.        4,700 €
# 7   1.9D  254 tūkst.        2,950 €
# 8   2.5D  289 tūkst.        6,100 €
# 9   1.9D  278 tūkst.        1,850 €
# 10  2.0D  182 tūkst.        9,500 €
# 11   1.6           -        1,890 €
# 12  3.0D  220 tūkst.       10,000 €
# 13  1.4D           -        2,490 €
# 14  1.9D           -        2,350 €
# 15  1.9D  240 tūkst.        3,800 €
# 16  2.0D  343 tūkst.        3,000 €
# 17  1.9D           -        2,850 €
# 18  2.0D  298 tūkst.        2,992 €
# 19  2.0D  340 tūkst.        3,590 €
# 20  1.9D  260 tūkst.        1,000 €
# 21  1.9D  420 tūkst.        1,150 €
# 22  1.9D  325 tūkst.        1,600 €
# 23   1.4  282 tūkst.        1,000 €
# 24   2.0           -        1,590 €
# 25  2.0D  271 tūkst.        5,550 €
# 26   1.8  279 tūkst.          750 €
# 27  1.9D  350 tūkst.        1,700 €
# 28   1.4  292 tūkst.        1,350 €
# 29  1.9D  340 tūkst.        1,230 €
# 30  2.0D  224 tūkst.        1,800 €
# 31   NaN         NaN            NaN
