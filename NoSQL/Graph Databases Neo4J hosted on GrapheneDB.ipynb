# %% [markdown]
# # RCS Graph Databases Neo4J hosted on GrapheneDB

# %% [markdown]
# ![Graph DB Example](https://upload.wikimedia.org/wikipedia/commons/thumb/3/3a/GraphDatabase_PropertyGraph.png/462px-GraphDatabase_PropertyGraph.png)

# %%
# what kind of graph is above ?

# %% [markdown]
# ## Neo4J
# https://neo4j.com/
#
# ![Neo4J](neo4jlogo.png)
#
# Open source, supports ACID, has high-availability clustering for enterprise deployments, and comes with a web-based administration tool that includes full transaction support and visual node-link graph explorer; accessible from most programming languages using its built-in REST web API interface, and a proprietary Bolt protocol with official drivers; most popular graph database in use as of January 2017(and still as of mid 2018)

# %% [markdown]
# ### Installation can be quirky so we have hosted solutions to rescue!
# https://www.graphenedb.com/ is the biggest prebuilt hosted solution provider for neo4
#
# ![GrapheneDB](graphenedb.png)

# %% [markdown]
# ## Python libraries for Neo4J and GrapheneDB
#
# https://neo4j.com/developer/python/
#
# https://docs.graphenedb.com/docs/python
#
# Official driver: https://github.com/neo4j/neo4j-python-driver

# %%
# !pip install neo4j-driver
# Out:
# Collecting neo4j-driver
#   Downloading https://files.pythonhosted.org/packages/fc/e2/ce6e4d08c0332e5cf501e4513872de5aca03f710bdb309cbc51f8daa7053/neo4j-driver-1.7.1.tar.gz
# Collecting neobolt<2,>=1.7.3 (from neo4j-driver)
#   Downloading https://files.pythonhosted.org/packages/b0/4c/929d8295be2a1ffb42569f4aec83bd376e02977c0da69fde87cb62a1208e/neobolt-1.7.3.tar.gz (182kB)
# Collecting neotime<2,>=1.7.1 (from neo4j-driver)
#   Downloading https://files.pythonhosted.org/packages/0b/7e/ca368a8d8e288be1352d4e2df35da1e01f8aaffbf526695df71630bcb8a6/neotime-1.7.4.tar.gz
# Requirement already satisfied: pytz in c:\programdata\anaconda3\lib\site-packages (from neotime<2,>=1.7.1->neo4j-driver)
# Requirement already satisfied: six in c:\programdata\anaconda3\lib\site-packages (from neotime<2,>=1.7.1->neo4j-driver)
# Building wheels for collected packages: neo4j-driver, neobolt, neotime
#   Running setup.py bdist_wheel for neo4j-driver: started
#   Running setup.py bdist_wheel for neo4j-driver: finished with status 'done'
#   Stored in directory: C:\Users\Val\AppData\Local\pip\Cache\wheels\93\10\17\db84bd8e4271df4dc66749d0be23dbc1d2583a7145dfd8c8d6
#   Running setup.py bdist_wheel for neobolt: started
#   Running setup.py bdist_wheel for neobolt: finished with status 'done'
#   Stored in directory: C:\Users\Val\AppData\Local\pip\Cache\wheels\9f\40\fc\c8dd751e3526cdd30c3483a57d512998f3774172dc2430bf5f
#   Running setup.py bdist_wheel for neotime: started
#   Running setup.py bdist_wheel for neotime: finished with status 'done'
#   Stored in directory: C:\Users\Val\AppData\Local\pip\Cache\wheels\d4\b4\c4\ab867cd0ac9e667f8cd269f9364fd1cb8ee75fe50f5ce97c79
# Successfully built neo4j-driver neobolt neotime
# Installing collected packages: neobolt, neotime, neo4j-driver
# Successfully installed neo4j-driver-1.7.1 neobolt-1.7.3 neotime-1.7.4
# You are using pip version 9.0.1, however version 19.0.1 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.

# %%
from neo4j import GraphDatabase, basic_auth

# %% [markdown]
# https://en.wikipedia.org/wiki/Bolt_(network_protocol)

# %%
pw = "willshowinclass"

# %%
driver = GraphDatabase.driver("bolt://hobby-ggackoeempicgbkeooibgpbl.dbs.graphenedb.com:24786", auth=basic_auth("RCS_U1", pw))

# %%
session = driver.session()

# %%
result = session.run("MATCH (n:Person) RETURN n.name AS name")
for record in result:
    print(record["name"])
session.close()
# Out:
# Keanu Reeves
# Carrie-Anne Moss
# Laurence Fishburne
# Hugo Weaving
# Lilly Wachowski
# Lana Wachowski
# Joel Silver
# Emil Eifrem
# Charlize Theron
# Al Pacino
# Taylor Hackford
# Tom Cruise
# Jack Nicholson
# Demi Moore
# Kevin Bacon
# Kiefer Sutherland
# Noah Wyle
# Cuba Gooding Jr.
# Kevin Pollak
# J.T. Walsh
# James Marshall
# Christopher Guest
# Rob Reiner
# Aaron Sorkin
# Kelly McGillis
# Val Kilmer
# Anthony Edwards
# Tom Skerritt
# Meg Ryan
# Tony Scott
# Jim Cash
# Renee Zellweger
# Kelly Preston
# Jerry O'Connell
# Jay Mohr
# Bonnie Hunt
# Regina King
# Jonathan Lipnicki
# Cameron Crowe
# River Phoenix
# Corey Feldman
# Wil Wheaton
# John Cusack
# Marshall Bell
# Helen Hunt
# Greg Kinnear
# James L. Brooks
# Annabella Sciorra
# Max von Sydow
# Werner Herzog
# Robin Williams
# Vincent Ward
# Ethan Hawke
# Rick Yune
# James Cromwell
# Scott Hicks
# Parker Posey
# Dave Chappelle
# Steve Zahn
# Tom Hanks
# Nora Ephron
# Rita Wilson
# Bill Pullman
# Victor Garber
# Rosie O'Donnell
# John Patrick Stanley
# Nathan Lane
# Billy Crystal
# Carrie Fisher
# Bruno Kirby
# Liv Tyler
# Brooke Langton
# Gene Hackman
# Orlando Jones
# Howard Deutch
# Christian Bale
# Zach Grenier
# Mike Nichols
# Richard Harris
# Clint Eastwood
# Takeshi Kitano
# Dina Meyer
# Ice-T
# Robert Longo
# Halle Berry
# Jim Broadbent
# Tom Tykwer
# David Mitchell
# Stefan Arndt
# Ian McKellen
# Audrey Tautou
# Paul Bettany
# Ron Howard
# Natalie Portman
# Stephen Rea
# John Hurt
# Ben Miles
# Emile Hirsch
# John Goodman
# Susan Sarandon
# Matthew Fox
# Christina Ricci
# Rain
# Naomie Harris
# Michael Clarke Duncan
# David Morse
# Sam Rockwell
# Gary Sinise
# Patricia Clarkson
# Frank Darabont
# Frank Langella
# Michael Sheen
# Oliver Platt
# Danny DeVito
# John C. Reilly
# Ed Harris
# Bill Paxton
# Philip Seymour Hoffman
# Jan de Bont
# Robert Zemeckis
# Milos Forman
# Diane Keaton
# Nancy Meyers
# Chris Columbus
# Julia Roberts
# Madonna
# Geena Davis
# Lori Petty
# Penny Marshall
# Paul Blythe
# Angela Scope
# Jessica Thompson
# James Thompson

# %%
def neoq(q, driver=driver): # we are too lazy to supply driver
    session = driver.session()
    result = session.run(q)
    for record in result:
        print(record)
    session.close()
    return result

# %%
neoq("MATCH (n:Person) RETURN n.name AS name")
# Out:
# <Record name='Keanu Reeves'>
# <Record name='Carrie-Anne Moss'>
# <Record name='Laurence Fishburne'>
# <Record name='Hugo Weaving'>
# <Record name='Lilly Wachowski'>
# <Record name='Lana Wachowski'>
# <Record name='Joel Silver'>
# <Record name='Emil Eifrem'>
# <Record name='Charlize Theron'>
# <Record name='Al Pacino'>
# <Record name='Taylor Hackford'>
# <Record name='Tom Cruise'>
# <Record name='Jack Nicholson'>
# <Record name='Demi Moore'>
# <Record name='Kevin Bacon'>
# <Record name='Kiefer Sutherland'>
# <Record name='Noah Wyle'>
# <Record name='Cuba Gooding Jr.'>
# <Record name='Kevin Pollak'>
# <Record name='J.T. Walsh'>
# <Record name='James Marshall'>
# <Record name='Christopher Guest'>
# <Record name='Rob Reiner'>
# <Record name='Aaron Sorkin'>
# <Record name='Kelly McGillis'>
# <Record name='Val Kilmer'>
# <Record name='Anthony Edwards'>
# <Record name='Tom Skerritt'>
# <Record name='Meg Ryan'>
# <Record name='Tony Scott'>
# <Record name='Jim Cash'>
# <Record name='Renee Zellweger'>
# <Record name='Kelly Preston'>
# <Record name="Jerry O'Connell">
# <Record name='Jay Mohr'>
# <Record name='Bonnie Hunt'>
# <Record name='Regina King'>
# <Record name='Jonathan Lipnicki'>
# <Record name='Cameron Crowe'>
# <Record name='River Phoenix'>
# <Record name='Corey Feldman'>
# <Record name='Wil Wheaton'>
# <Record name='John Cusack'>
# <Record name='Marshall Bell'>
# <Record name='Helen Hunt'>
# <Record name='Greg Kinnear'>
# <Record name='James L. Brooks'>
# <Record name='Annabella Sciorra'>
# <Record name='Max von Sydow'>
# <Record name='Werner Herzog'>
# <Record name='Robin Williams'>
# <Record name='Vincent Ward'>
# <Record name='Ethan Hawke'>
# <Record name='Rick Yune'>
# <Record name='James Cromwell'>
# <Record name='Scott Hicks'>
# <Record name='Parker Posey'>
# <Record name='Dave Chappelle'>
# <Record name='Steve Zahn'>
# <Record name='Tom Hanks'>
# <Record name='Nora Ephron'>
# <Record name='Rita Wilson'>
# <Record name='Bill Pullman'>
# <Record name='Victor Garber'>
# <Record name="Rosie O'Donnell">
# <Record name='John Patrick Stanley'>
# <Record name='Nathan Lane'>
# <Record name='Billy Crystal'>
# <Record name='Carrie Fisher'>
# <Record name='Bruno Kirby'>
# <Record name='Liv Tyler'>
# <Record name='Brooke Langton'>
# <Record name='Gene Hackman'>
# <Record name='Orlando Jones'>
# <Record name='Howard Deutch'>
# <Record name='Christian Bale'>
# <Record name='Zach Grenier'>
# <Record name='Mike Nichols'>
# <Record name='Richard Harris'>
# <Record name='Clint Eastwood'>
# <Record name='Takeshi Kitano'>
# <Record name='Dina Meyer'>
# <Record name='Ice-T'>
# <Record name='Robert Longo'>
# <Record name='Halle Berry'>
# <Record name='Jim Broadbent'>
# <Record name='Tom Tykwer'>
# <Record name='David Mitchell'>
# <Record name='Stefan Arndt'>
# <Record name='Ian McKellen'>
# <Record name='Audrey Tautou'>
# <Record name='Paul Bettany'>
# <Record name='Ron Howard'>
# <Record name='Natalie Portman'>
# <Record name='Stephen Rea'>
# <Record name='John Hurt'>
# <Record name='Ben Miles'>
# <Record name='Emile Hirsch'>
# <Record name='John Goodman'>
# <Record name='Susan Sarandon'>
# <Record name='Matthew Fox'>
# <Record name='Christina Ricci'>
# <Record name='Rain'>
# <Record name='Naomie Harris'>
# <Record name='Michael Clarke Duncan'>
# <Record name='David Morse'>
# <Record name='Sam Rockwell'>
# <Record name='Gary Sinise'>
# <Record name='Patricia Clarkson'>
# <Record name='Frank Darabont'>
# <Record name='Frank Langella'>
# <Record name='Michael Sheen'>
# <Record name='Oliver Platt'>
# <Record name='Danny DeVito'>
# <Record name='John C. Reilly'>
# <Record name='Ed Harris'>
# <Record name='Bill Paxton'>
# <Record name='Philip Seymour Hoffman'>
# <Record name='Jan de Bont'>
# <Record name='Robert Zemeckis'>
# <Record name='Milos Forman'>
# <Record name='Diane Keaton'>
# <Record name='Nancy Meyers'>
# <Record name='Chris Columbus'>
# <Record name='Julia Roberts'>
# <Record name='Madonna'>
# <Record name='Geena Davis'>
# <Record name='Lori Petty'>
# <Record name='Penny Marshall'>
# <Record name='Paul Blythe'>
# <Record name='Angela Scope'>
# <Record name='Jessica Thompson'>
# <Record name='James Thompson'>

# %%
neoq("MATCH (n) RETURN n")
# Out:
# <Record n=<Node id=0 labels={'Movie'} properties={'title': 'The Matrix', 'tagline': 'Welcome to the Real World', 'released': 1999}>>
# <Record n=<Node id=1 labels={'Person'} properties={'name': 'Keanu Reeves', 'born': 1964}>>
# <Record n=<Node id=2 labels={'Person'} properties={'name': 'Carrie-Anne Moss', 'born': 1967}>>
# <Record n=<Node id=3 labels={'Person'} properties={'name': 'Laurence Fishburne', 'born': 1961}>>
# <Record n=<Node id=4 labels={'Person'} properties={'name': 'Hugo Weaving', 'born': 1960}>>
# <Record n=<Node id=5 labels={'Person'} properties={'name': 'Lilly Wachowski', 'born': 1967}>>
# <Record n=<Node id=6 labels={'Person'} properties={'name': 'Lana Wachowski', 'born': 1965}>>
# <Record n=<Node id=7 labels={'Person'} properties={'name': 'Joel Silver', 'born': 1952}>>
# <Record n=<Node id=8 labels={'Person'} properties={'name': 'Emil Eifrem', 'born': 1978}>>
# <Record n=<Node id=9 labels={'Movie'} properties={'title': 'The Matrix Reloaded', 'tagline': 'Free your mind', 'released': 2003}>>
# <Record n=<Node id=10 labels={'Movie'} properties={'title': 'The Matrix Revolutions', 'tagline': 'Everything that has a beginning has an end', 'released': 2003}>>
# <Record n=<Node id=11 labels={'Movie'} properties={'title': "The Devil's Advocate", 'tagline': 'Evil has its winning ways', 'released': 1997}>>
# <Record n=<Node id=12 labels={'Person'} properties={'name': 'Charlize Theron', 'born': 1975}>>
# <Record n=<Node id=13 labels={'Person'} properties={'name': 'Al Pacino', 'born': 1940}>>
# <Record n=<Node id=14 labels={'Person'} properties={'name': 'Taylor Hackford', 'born': 1944}>>
# <Record n=<Node id=15 labels={'Movie'} properties={'title': 'A Few Good Men', 'tagline': "In the heart of the nation's capital, in a courthouse of the U.S. government, one man will stop at nothing to keep his honor, and one will stop at nothing to find the truth.", 'released': 1992}>>
# <Record n=<Node id=16 labels={'Person'} properties={'name': 'Tom Cruise', 'born': 1962}>>
# <Record n=<Node id=17 labels={'Person'} properties={'name': 'Jack Nicholson', 'born': 1937}>>
# <Record n=<Node id=18 labels={'Person'} properties={'name': 'Demi Moore', 'born': 1962}>>
# <Record n=<Node id=19 labels={'Person'} properties={'name': 'Kevin Bacon', 'born': 1958}>>
# <Record n=<Node id=20 labels={'Person'} properties={'name': 'Kiefer Sutherland', 'born': 1966}>>
# <Record n=<Node id=21 labels={'Person'} properties={'name': 'Noah Wyle', 'born': 1971}>>
# <Record n=<Node id=22 labels={'Person'} properties={'name': 'Cuba Gooding Jr.', 'born': 1968}>>
# <Record n=<Node id=23 labels={'Person'} properties={'name': 'Kevin Pollak', 'born': 1957}>>
# <Record n=<Node id=24 labels={'Person'} properties={'name': 'J.T. Walsh', 'born': 1943}>>
# <Record n=<Node id=25 labels={'Person'} properties={'name': 'James Marshall', 'born': 1967}>>
# <Record n=<Node id=26 labels={'Person'} properties={'name': 'Christopher Guest', 'born': 1948}>>
# <Record n=<Node id=27 labels={'Person'} properties={'name': 'Rob Reiner', 'born': 1947}>>
# <Record n=<Node id=28 labels={'Person'} properties={'name': 'Aaron Sorkin', 'born': 1961}>>
# <Record n=<Node id=29 labels={'Movie'} properties={'title': 'Top Gun', 'tagline': 'I feel the need, the need for speed.', 'released': 1986}>>
# <Record n=<Node id=30 labels={'Person'} properties={'name': 'Kelly McGillis', 'born': 1957}>>
# <Record n=<Node id=31 labels={'Person'} properties={'name': 'Val Kilmer', 'born': 1959}>>
# <Record n=<Node id=32 labels={'Person'} properties={'name': 'Anthony Edwards', 'born': 1962}>>
# <Record n=<Node id=33 labels={'Person'} properties={'name': 'Tom Skerritt', 'born': 1933}>>
# <Record n=<Node id=34 labels={'Person'} properties={'name': 'Meg Ryan', 'born': 1961}>>
# <Record n=<Node id=35 labels={'Person'} properties={'name': 'Tony Scott', 'born': 1944}>>
# <Record n=<Node id=36 labels={'Person'} properties={'name': 'Jim Cash', 'born': 1941}>>
# <Record n=<Node id=37 labels={'Movie'} properties={'title': 'Jerry Maguire', 'tagline': 'The rest of his life begins now.', 'released': 2000}>>
# <Record n=<Node id=38 labels={'Person'} properties={'name': 'Renee Zellweger', 'born': 1969}>>
# <Record n=<Node id=39 labels={'Person'} properties={'name': 'Kelly Preston', 'born': 1962}>>
# <Record n=<Node id=40 labels={'Person'} properties={'name': "Jerry O'Connell", 'born': 1974}>>
# <Record n=<Node id=41 labels={'Person'} properties={'name': 'Jay Mohr', 'born': 1970}>>
# <Record n=<Node id=42 labels={'Person'} properties={'name': 'Bonnie Hunt', 'born': 1961}>>
# <Record n=<Node id=43 labels={'Person'} properties={'name': 'Regina King', 'born': 1971}>>
# <Record n=<Node id=44 labels={'Person'} properties={'name': 'Jonathan Lipnicki', 'born': 1996}>>
# <Record n=<Node id=45 labels={'Person'} properties={'name': 'Cameron Crowe', 'born': 1957}>>
# <Record n=<Node id=46 labels={'Movie'} properties={'title': 'Stand By Me', 'tagline': "For some, it's the last real taste of innocence, and the first real taste of life. But for everyone, it's the time that memories are made of.", 'released': 1986}>>
# <Record n=<Node id=47 labels={'Person'} properties={'name': 'River Phoenix', 'born': 1970}>>
# <Record n=<Node id=48 labels={'Person'} properties={'name': 'Corey Feldman', 'born': 1971}>>
# <Record n=<Node id=49 labels={'Person'} properties={'name': 'Wil Wheaton', 'born': 1972}>>
# <Record n=<Node id=50 labels={'Person'} properties={'name': 'John Cusack', 'born': 1966}>>
# <Record n=<Node id=51 labels={'Person'} properties={'name': 'Marshall Bell', 'born': 1942}>>
# <Record n=<Node id=52 labels={'Movie'} properties={'title': 'As Good as It Gets', 'tagline': 'A comedy from the heart that goes for the throat.', 'released': 1997}>>
# <Record n=<Node id=53 labels={'Person'} properties={'name': 'Helen Hunt', 'born': 1963}>>
# <Record n=<Node id=54 labels={'Person'} properties={'name': 'Greg Kinnear', 'born': 1963}>>
# <Record n=<Node id=55 labels={'Person'} properties={'name': 'James L. Brooks', 'born': 1940}>>
# <Record n=<Node id=56 labels={'Movie'} properties={'title': 'What Dreams May Come', 'tagline': 'After life there is more. The end is just the beginning.', 'released': 1998}>>
# <Record n=<Node id=57 labels={'Person'} properties={'name': 'Annabella Sciorra', 'born': 1960}>>
# <Record n=<Node id=58 labels={'Person'} properties={'name': 'Max von Sydow', 'born': 1929}>>
# <Record n=<Node id=59 labels={'Person'} properties={'name': 'Werner Herzog', 'born': 1942}>>
# <Record n=<Node id=60 labels={'Person'} properties={'name': 'Robin Williams', 'born': 1951}>>
# <Record n=<Node id=61 labels={'Person'} properties={'name': 'Vincent Ward', 'born': 1956}>>
# <Record n=<Node id=62 labels={'Movie'} properties={'title': 'Snow Falling on Cedars', 'tagline': 'First loves last. Forever.', 'released': 1999}>>
# <Record n=<Node id=63 labels={'Person'} properties={'name': 'Ethan Hawke', 'born': 1970}>>
# <Record n=<Node id=64 labels={'Person'} properties={'name': 'Rick Yune', 'born': 1971}>>
# <Record n=<Node id=65 labels={'Person'} properties={'name': 'James Cromwell', 'born': 1940}>>
# <Record n=<Node id=66 labels={'Person'} properties={'name': 'Scott Hicks', 'born': 1953}>>
# <Record n=<Node id=67 labels={'Movie'} properties={'title': "You've Got Mail", 'tagline': 'At odds in life... in love on-line.', 'released': 1998}>>
# <Record n=<Node id=68 labels={'Person'} properties={'name': 'Parker Posey', 'born': 1968}>>
# <Record n=<Node id=69 labels={'Person'} properties={'name': 'Dave Chappelle', 'born': 1973}>>
# <Record n=<Node id=70 labels={'Person'} properties={'name': 'Steve Zahn', 'born': 1967}>>
# <Record n=<Node id=71 labels={'Person'} properties={'name': 'Tom Hanks', 'born': 1956}>>
# <Record n=<Node id=72 labels={'Person'} properties={'name': 'Nora Ephron', 'born': 1941}>>
# <Record n=<Node id=73 labels={'Movie'} properties={'title': 'Sleepless in Seattle', 'tagline': 'What if someone you never met, someone you never saw, someone you never knew was the only someone for you?', 'released': 1993}>>
# <Record n=<Node id=74 labels={'Person'} properties={'name': 'Rita Wilson', 'born': 1956}>>
# <Record n=<Node id=75 labels={'Person'} properties={'name': 'Bill Pullman', 'born': 1953}>>
# <Record n=<Node id=76 labels={'Person'} properties={'name': 'Victor Garber', 'born': 1949}>>
# <Record n=<Node id=77 labels={'Person'} properties={'name': "Rosie O'Donnell", 'born': 1962}>>
# <Record n=<Node id=78 labels={'Movie'} properties={'title': 'Joe Versus the Volcano', 'tagline': 'A story of love, lava and burning desire.', 'released': 1990}>>
# <Record n=<Node id=79 labels={'Person'} properties={'name': 'John Patrick Stanley', 'born': 1950}>>
# <Record n=<Node id=80 labels={'Person'} properties={'name': 'Nathan Lane', 'born': 1956}>>
# <Record n=<Node id=81 labels={'Movie'} properties={'title': 'When Harry Met Sally', 'tagline': 'At odds in life... in love on-line.', 'released': 1998}>>
# <Record n=<Node id=82 labels={'Person'} properties={'name': 'Billy Crystal', 'born': 1948}>>
# <Record n=<Node id=83 labels={'Person'} properties={'name': 'Carrie Fisher', 'born': 1956}>>
# <Record n=<Node id=84 labels={'Person'} properties={'name': 'Bruno Kirby', 'born': 1949}>>
# <Record n=<Node id=85 labels={'Movie'} properties={'title': 'That Thing You Do', 'tagline': 'In every life there comes a time when that thing you dream becomes that thing you do', 'released': 1996}>>
# <Record n=<Node id=86 labels={'Person'} properties={'name': 'Liv Tyler', 'born': 1977}>>
# <Record n=<Node id=87 labels={'Movie'} properties={'title': 'The Replacements', 'tagline': 'Pain heals, Chicks dig scars... Glory lasts forever', 'released': 2000}>>
# <Record n=<Node id=88 labels={'Person'} properties={'name': 'Brooke Langton', 'born': 1970}>>
# <Record n=<Node id=89 labels={'Person'} properties={'name': 'Gene Hackman', 'born': 1930}>>
# <Record n=<Node id=90 labels={'Person'} properties={'name': 'Orlando Jones', 'born': 1968}>>
# <Record n=<Node id=91 labels={'Person'} properties={'name': 'Howard Deutch', 'born': 1950}>>
# <Record n=<Node id=92 labels={'Movie'} properties={'title': 'RescueDawn', 'tagline': "Based on the extraordinary true story of one man's fight for freedom", 'released': 2006}>>
# <Record n=<Node id=93 labels={'Person'} properties={'name': 'Christian Bale', 'born': 1974}>>
# <Record n=<Node id=94 labels={'Person'} properties={'name': 'Zach Grenier', 'born': 1954}>>
# <Record n=<Node id=95 labels={'Movie'} properties={'title': 'The Birdcage', 'tagline': 'Come as you are', 'released': 1996}>>
# <Record n=<Node id=96 labels={'Person'} properties={'name': 'Mike Nichols', 'born': 1931}>>
# <Record n=<Node id=97 labels={'Movie'} properties={'title': 'Unforgiven', 'tagline': "It's a hell of a thing, killing a man", 'released': 1992}>>
# <Record n=<Node id=98 labels={'Person'} properties={'name': 'Richard Harris', 'born': 1930}>>
# <Record n=<Node id=99 labels={'Person'} properties={'name': 'Clint Eastwood', 'born': 1930}>>
# <Record n=<Node id=100 labels={'Movie'} properties={'title': 'Johnny Mnemonic', 'tagline': 'The hottest data on earth. In the coolest head in town', 'released': 1995}>>
# <Record n=<Node id=101 labels={'Person'} properties={'name': 'Takeshi Kitano', 'born': 1947}>>
# <Record n=<Node id=102 labels={'Person'} properties={'name': 'Dina Meyer', 'born': 1968}>>
# <Record n=<Node id=103 labels={'Person'} properties={'name': 'Ice-T', 'born': 1958}>>
# <Record n=<Node id=104 labels={'Person'} properties={'name': 'Robert Longo', 'born': 1953}>>
# <Record n=<Node id=105 labels={'Movie'} properties={'title': 'Cloud Atlas', 'tagline': 'Everything is connected', 'released': 2012}>>
# <Record n=<Node id=106 labels={'Person'} properties={'name': 'Halle Berry', 'born': 1966}>>
# <Record n=<Node id=107 labels={'Person'} properties={'name': 'Jim Broadbent', 'born': 1949}>>
# <Record n=<Node id=108 labels={'Person'} properties={'name': 'Tom Tykwer', 'born': 1965}>>
# <Record n=<Node id=109 labels={'Person'} properties={'name': 'David Mitchell', 'born': 1969}>>
# <Record n=<Node id=110 labels={'Person'} properties={'name': 'Stefan Arndt', 'born': 1961}>>
# <Record n=<Node id=111 labels={'Movie'} properties={'title': 'The Da Vinci Code', 'tagline': 'Break The Codes', 'released': 2006}>>
# <Record n=<Node id=112 labels={'Person'} properties={'name': 'Ian McKellen', 'born': 1939}>>
# <Record n=<Node id=113 labels={'Person'} properties={'name': 'Audrey Tautou', 'born': 1976}>>
# <Record n=<Node id=114 labels={'Person'} properties={'name': 'Paul Bettany', 'born': 1971}>>
# <Record n=<Node id=115 labels={'Person'} properties={'name': 'Ron Howard', 'born': 1954}>>
# <Record n=<Node id=116 labels={'Movie'} properties={'title': 'V for Vendetta', 'tagline': 'Freedom! Forever!', 'released': 2006}>>
# <Record n=<Node id=117 labels={'Person'} properties={'name': 'Natalie Portman', 'born': 1981}>>
# <Record n=<Node id=118 labels={'Person'} properties={'name': 'Stephen Rea', 'born': 1946}>>
# <Record n=<Node id=119 labels={'Person'} properties={'name': 'John Hurt', 'born': 1940}>>
# <Record n=<Node id=120 labels={'Person'} properties={'name': 'Ben Miles', 'born': 1967}>>
# <Record n=<Node id=121 labels={'Movie'} properties={'title': 'Speed Racer', 'tagline': 'Speed has no limits', 'released': 2008}>>
# <Record n=<Node id=122 labels={'Person'} properties={'name': 'Emile Hirsch', 'born': 1985}>>
# <Record n=<Node id=123 labels={'Person'} properties={'name': 'John Goodman', 'born': 1960}>>
# <Record n=<Node id=124 labels={'Person'} properties={'name': 'Susan Sarandon', 'born': 1946}>>
# <Record n=<Node id=125 labels={'Person'} properties={'name': 'Matthew Fox', 'born': 1966}>>
# <Record n=<Node id=126 labels={'Person'} properties={'name': 'Christina Ricci', 'born': 1980}>>
# <Record n=<Node id=127 labels={'Person'} properties={'name': 'Rain', 'born': 1982}>>
# <Record n=<Node id=128 labels={'Movie'} properties={'title': 'Ninja Assassin', 'tagline': 'Prepare to enter a secret world of assassins', 'released': 2009}>>
# <Record n=<Node id=129 labels={'Person'} properties={'name': 'Naomie Harris'}>>
# <Record n=<Node id=130 labels={'Movie'} properties={'title': 'The Green Mile', 'tagline': "Walk a mile you'll never forget.", 'released': 1999}>>
# <Record n=<Node id=131 labels={'Person'} properties={'name': 'Michael Clarke Duncan', 'born': 1957}>>
# <Record n=<Node id=132 labels={'Person'} properties={'name': 'David Morse', 'born': 1953}>>
# <Record n=<Node id=133 labels={'Person'} properties={'name': 'Sam Rockwell', 'born': 1968}>>
# <Record n=<Node id=134 labels={'Person'} properties={'name': 'Gary Sinise', 'born': 1955}>>
# <Record n=<Node id=135 labels={'Person'} properties={'name': 'Patricia Clarkson', 'born': 1959}>>
# <Record n=<Node id=136 labels={'Person'} properties={'name': 'Frank Darabont', 'born': 1959}>>
# <Record n=<Node id=137 labels={'Movie'} properties={'title': 'Frost/Nixon', 'tagline': '400 million people were waiting for the truth.', 'released': 2008}>>
# <Record n=<Node id=138 labels={'Person'} properties={'name': 'Frank Langella', 'born': 1938}>>
# <Record n=<Node id=139 labels={'Person'} properties={'name': 'Michael Sheen', 'born': 1969}>>
# <Record n=<Node id=140 labels={'Person'} properties={'name': 'Oliver Platt', 'born': 1960}>>
# <Record n=<Node id=141 labels={'Movie'} properties={'title': 'Hoffa', 'tagline': "He didn't want law. He wanted justice.", 'released': 1992}>>
# <Record n=<Node id=142 labels={'Person'} properties={'name': 'Danny DeVito', 'born': 1944}>>
# <Record n=<Node id=143 labels={'Person'} properties={'name': 'John C. Reilly', 'born': 1965}>>
# <Record n=<Node id=144 labels={'Movie'} properties={'title': 'Apollo 13', 'tagline': 'Houston, we have a problem.', 'released': 1995}>>
# <Record n=<Node id=145 labels={'Person'} properties={'name': 'Ed Harris', 'born': 1950}>>
# <Record n=<Node id=146 labels={'Person'} properties={'name': 'Bill Paxton', 'born': 1955}>>
# <Record n=<Node id=147 labels={'Movie'} properties={'title': 'Twister', 'tagline': "Don't Breathe. Don't Look Back.", 'released': 1996}>>
# <Record n=<Node id=148 labels={'Person'} properties={'name': 'Philip Seymour Hoffman', 'born': 1967}>>
# <Record n=<Node id=149 labels={'Person'} properties={'name': 'Jan de Bont', 'born': 1943}>>
# <Record n=<Node id=150 labels={'Movie'} properties={'title': 'Cast Away', 'tagline': 'At the edge of the world, his journey begins.', 'released': 2000}>>
# <Record n=<Node id=151 labels={'Person'} properties={'name': 'Robert Zemeckis', 'born': 1951}>>
# <Record n=<Node id=152 labels={'Movie'} properties={'title': "One Flew Over the Cuckoo's Nest", 'tagline': "If he's crazy, what does that make you?", 'released': 1975}>>
# <Record n=<Node id=153 labels={'Person'} properties={'name': 'Milos Forman', 'born': 1932}>>
# <Record n=<Node id=154 labels={'Movie'} properties={'title': "Something's Gotta Give", 'released': 2003}>>
# <Record n=<Node id=155 labels={'Person'} properties={'name': 'Diane Keaton', 'born': 1946}>>
# <Record n=<Node id=156 labels={'Person'} properties={'name': 'Nancy Meyers', 'born': 1949}>>
# <Record n=<Node id=157 labels={'Movie'} properties={'title': 'Bicentennial Man', 'tagline': "One robot's 200 year journey to become an ordinary man.", 'released': 1999}>>
# <Record n=<Node id=158 labels={'Person'} properties={'name': 'Chris Columbus', 'born': 1958}>>
# <Record n=<Node id=159 labels={'Movie'} properties={'title': "Charlie Wilson's War", 'tagline': "A stiff drink. A little mascara. A lot of nerve. Who said they couldn't bring down the Soviet empire.", 'released': 2007}>>
# <Record n=<Node id=160 labels={'Person'} properties={'name': 'Julia Roberts', 'born': 1967}>>
# <Record n=<Node id=161 labels={'Movie'} properties={'title': 'The Polar Express', 'tagline': 'This Holiday Season… Believe', 'released': 2004}>>
# <Record n=<Node id=162 labels={'Movie'} properties={'title': 'A League of Their Own', 'tagline': 'Once in a lifetime you get a chance to do something different.', 'released': 1992}>>
# <Record n=<Node id=163 labels={'Person'} properties={'name': 'Madonna', 'born': 1954}>>
# <Record n=<Node id=164 labels={'Person'} properties={'name': 'Geena Davis', 'born': 1956}>>
# <Record n=<Node id=165 labels={'Person'} properties={'name': 'Lori Petty', 'born': 1963}>>
# <Record n=<Node id=166 labels={'Person'} properties={'name': 'Penny Marshall', 'born': 1943}>>
# <Record n=<Node id=167 labels={'Person'} properties={'name': 'Paul Blythe'}>>
# <Record n=<Node id=168 labels={'Person'} properties={'name': 'Angela Scope'}>>
# <Record n=<Node id=169 labels={'Person'} properties={'name': 'Jessica Thompson'}>>
# <Record n=<Node id=170 labels={'Person'} properties={'name': 'James Thompson'}>>

# %%
res = neoq("cypher MATCH p = ()-[]-() RETURN p")
# Out:
# <Record p=<Path start=<Node id=8 labels={'Person'} properties={'name': 'Emil Eifrem', 'born': 1978}> end=<Node id=0 labels={'Movie'} properties={'title': 'The Matrix', 'tagline': 'Welcome to the Real World', 'released': 1999}> size=1>>
# <Record p=<Path start=<Node id=7 labels={'Person'} properties={'name': 'Joel Silver', 'born': 1952}> end=<Node id=0 labels={'Movie'} properties={'title': 'The Matrix', 'tagline': 'Welcome to the Real World', 'released': 1999}> size=1>>
# <Record p=<Path start=<Node id=6 labels={'Person'} properties={'name': 'Lana Wachowski', 'born': 1965}> end=<Node id=0 labels={'Movie'} properties={'title': 'The Matrix', 'tagline': 'Welcome to the Real World', 'released': 1999}> size=1>>
# <Record p=<Path start=<Node id=5 labels={'Person'} properties={'name': 'Lilly Wachowski', 'born': 1967}> end=<Node id=0 labels={'Movie'} properties={'title': 'The Matrix', 'tagline': 'Welcome to the Real World', 'released': 1999}> size=1>>
# <Record p=<Path start=<Node id=4 labels={'Person'} properties={'name': 'Hugo Weaving', 'born': 1960}> end=<Node id=0 labels={'Movie'} properties={'title': 'The Matrix', 'tagline': 'Welcome to the Real World', 'released': 1999}> size=1>>
# <Record p=<Path start=<Node id=3 labels={'Person'} properties={'name': 'Laurence Fishburne', 'born': 1961}> end=<Node id=0 labels={'Movie'} properties={'title': 'The Matrix', 'tagline': 'Welcome to the Real World', 'released': 1999}> size=1>>
# <Record p=<Path start=<Node id=2 labels={'Person'} properties={'name': 'Carrie-Anne Moss', 'born': 1967}> end=<Node id=0 labels={'Movie'} properties={'title': 'The Matrix', 'tagline': 'Welcome to the Real World', 'released': 1999}> size=1>>
# <Record p=<Path start=<Node id=1 labels={'Person'} properties={'name': 'Keanu Reeves', 'born': 1964}> end=<Node id=0 labels={'Movie'} properties={'title': 'The Matrix', 'tagline': 'Welcome to the Real World', 'released': 1999}> size=1>>
# <Record p=<Path start=<Node id=154 labels={'Movie'} properties={'title': "Something's Gotta Give", 'released': 2003}> end=<Node id=1 labels={'Person'} properties={'name': 'Keanu Reeves', 'born': 1964}> size=1>>
# <Record p=<Path start=<Node id=100 labels={'Movie'} properties={'title': 'Johnny Mnemonic', 'tagline': 'The hottest data on earth. In the coolest head in town', 'released': 1995}> end=<Node id=1 labels={'Person'} properties={'name': 'Keanu Reeves', 'born': 1964}> size=1>>
# <Record p=<Path start=<Node id=87 labels={'Movie'} properties={'title': 'The Replacements', 'tagline': 'Pain heals, Chicks dig scars... Glory lasts forever', 'released': 2000}> end=<Node id=1 labels={'Person'} properties={'name': 'Keanu Reeves', 'born': 1964}> size=1>>
# <Record p=<Path start=<Node id=11 labels={'Movie'} properties={'title': "The Devil's Advocate", 'tagline': 'Evil has its winning ways', 'released': 1997}> end=<Node id=1 labels={'Person'} properties={'name': 'Keanu Reeves', 'born': 1964}> size=1>>
# <Record p=<Path start=<Node id=10 labels={'Movie'} properties={'title': 'The Matrix Revolutions', 'tagline': 'Everything that has a beginning has an end', 'released': 2003}> end=<Node id=1 labels={'Person'} properties={'name': 'Keanu Reeves', 'born': 1964}> size=1>>
# <Record p=<Path start=<Node id=9 labels={'Movie'} properties={'title': 'The Matrix Reloaded', 'tagline': 'Free your mind', 'released': 2003}> end=<Node id=1 labels={'Person'} properties={'name': 'Keanu Reeves', 'born': 1964}> size=1>>
# <Record p=<Path start=<Node id=0 labels={'Movie'} properties={'title': 'The Matrix', 'tagline': 'Welcome to the Real World', 'released': 1999}> end=<Node id=1 labels={'Person'} properties={'name': 'Keanu Reeves', 'born': 1964}> size=1>>
# <Record p=<Path start=<Node id=10 labels={'Movie'} properties={'title': 'The Matrix Revolutions', 'tagline': 'Everything that has a beginning has an end', 'released': 2003}> end=<Node id=2 labels={'Person'} properties={'name': 'Carrie-Anne Moss', 'born': 1967}> size=1>>
# <Record p=<Path start=<Node id=9 labels={'Movie'} properties={'title': 'The Matrix Reloaded', 'tagline': 'Free your mind', 'released': 2003}> end=<Node id=2 labels={'Person'} properties={'name': 'Carrie-Anne Moss', 'born': 1967}> size=1>>
# <Record p=<Path start=<Node id=0 labels={'Movie'} properties={'title': 'The Matrix', 'tagline': 'Welcome to the Real World', 'released': 1999}> end=<Node id=2 labels={'Person'} properties={'name': 'Carrie-Anne Moss', 'born': 1967}> size=1>>
# <Record p=<Path start=<Node id=10 labels={'Movie'} properties={'title': 'The Matrix Revolutions', 'tagline': 'Everything that has a beginning has an end', 'released': 2003}> end=<Node id=3 labels={'Person'} properties={'name': 'Laurence Fishburne', 'born': 1961}> size=1>>
# <Record p=<Path start=<Node id=9 labels={'Movie'} properties={'title': 'The Matrix Reloaded', 'tagline': 'Free your mind', 'released': 2003}> end=<Node id=3 labels={'Person'} properties={'name': 'Laurence Fishburne', 'born': 1961}> size=1>>
# <Record p=<Path start=<Node id=0 labels={'Movie'} properties={'title': 'The Matrix', 'tagline': 'Welcome to the Real World', 'released': 1999}> end=<Node id=3 labels={'Person'} properties={'name': 'Laurence Fishburne', 'born': 1961}> size=1>>
# <Record p=<Path start=<Node id=116 labels={'Movie'} properties={'title': 'V for Vendetta', 'tagline': 'Freedom! Forever!', 'released': 2006}> end=<Node id=4 labels={'Person'} properties={'name': 'Hugo Weaving', 'born': 1960}> size=1>>
# <Record p=<Path start=<Node id=105 labels={'Movie'} properties={'title': 'Cloud Atlas', 'tagline': 'Everything is connected', 'released': 2012}> end=<Node id=4 labels={'Person'} properties={'name': 'Hugo Weaving', 'born': 1960}> size=1>>
# <Record p=<Path start=<Node id=10 labels={'Movie'} properties={'title': 'The Matrix Revolutions', 'tagline': 'Everything that has a beginning has an end', 'released': 2003}> end=<Node id=4 labels={'Person'} properties={'name': 'Hugo Weaving', 'born': 1960}> size=1>>
# <Record p=<Path start=<Node id=9 labels={'Movie'} properties={'title': 'The Matrix Reloaded', 'tagline': 'Free your mind', 'released': 2003}> end=<Node id=4 labels={'Person'} properties={'name': 'Hugo Weaving', 'born': 1960}> size=1>>
# <Record p=<Path start=<Node id=0 labels={'Movie'} properties={'title': 'The Matrix', 'tagline': 'Welcome to the Real World', 'released': 1999}> end=<Node id=4 labels={'Person'} properties={'name': 'Hugo Weaving', 'born': 1960}> size=1>>
# <Record p=<Path start=<Node id=128 labels={'Movie'} properties={'title': 'Ninja Assassin', 'tagline': 'Prepare to enter a secret world of assassins', 'released': 2009}> end=<Node id=5 labels={'Person'} properties={'name': 'Lilly Wachowski', 'born': 1967}> size=1>>
# <Record p=<Path start=<Node id=116 labels={'Movie'} properties={'title': 'V for Vendetta', 'tagline': 'Freedom! Forever!', 'released': 2006}> end=<Node id=5 labels={'Person'} properties={'name': 'Lilly Wachowski', 'born': 1967}> size=1>>
# <Record p=<Path start=<Node id=121 labels={'Movie'} properties={'title': 'Speed Racer', 'tagline': 'Speed has no limits', 'released': 2008}> end=<Node id=5 labels={'Person'} properties={'name': 'Lilly Wachowski', 'born': 1967}> size=1>>
# <Record p=<Path start=<Node id=121 labels={'Movie'} properties={'title': 'Speed Racer', 'tagline': 'Speed has no limits', 'released': 2008}> end=<Node id=5 labels={'Person'} properties={'name': 'Lilly Wachowski', 'born': 1967}> size=1>>
# <Record p=<Path start=<Node id=116 labels={'Movie'} properties={'title': 'V for Vendetta', 'tagline': 'Freedom! Forever!', 'released': 2006}> end=<Node id=5 labels={'Person'} properties={'name': 'Lilly Wachowski', 'born': 1967}> size=1>>
# <Record p=<Path start=<Node id=105 labels={'Movie'} properties={'title': 'Cloud Atlas', 'tagline': 'Everything is connected', 'released': 2012}> end=<Node id=5 labels={'Person'} properties={'name': 'Lilly Wachowski', 'born': 1967}> size=1>>
# <Record p=<Path start=<Node id=10 labels={'Movie'} properties={'title': 'The Matrix Revolutions', 'tagline': 'Everything that has a beginning has an end', 'released': 2003}> end=<Node id=5 labels={'Person'} properties={'name': 'Lilly Wachowski', 'born': 1967}> size=1>>
# <Record p=<Path start=<Node id=9 labels={'Movie'} properties={'title': 'The Matrix Reloaded', 'tagline': 'Free your mind', 'released': 2003}> end=<Node id=5 labels={'Person'} properties={'name': 'Lilly Wachowski', 'born': 1967}> size=1>>
# <Record p=<Path start=<Node id=0 labels={'Movie'} properties={'title': 'The Matrix', 'tagline': 'Welcome to the Real World', 'released': 1999}> end=<Node id=5 labels={'Person'} properties={'name': 'Lilly Wachowski', 'born': 1967}> size=1>>
# <Record p=<Path start=<Node id=128 labels={'Movie'} properties={'title': 'Ninja Assassin', 'tagline': 'Prepare to enter a secret world of assassins', 'released': 2009}> end=<Node id=6 labels={'Person'} properties={'name': 'Lana Wachowski', 'born': 1965}> size=1>>
# <Record p=<Path start=<Node id=116 labels={'Movie'} properties={'title': 'V for Vendetta', 'tagline': 'Freedom! Forever!', 'released': 2006}> end=<Node id=6 labels={'Person'} properties={'name': 'Lana Wachowski', 'born': 1965}> size=1>>
# <Record p=<Path start=<Node id=121 labels={'Movie'} properties={'title': 'Speed Racer', 'tagline': 'Speed has no limits', 'released': 2008}> end=<Node id=6 labels={'Person'} properties={'name': 'Lana Wachowski', 'born': 1965}> size=1>>
# <Record p=<Path start=<Node id=121 labels={'Movie'} properties={'title': 'Speed Racer', 'tagline': 'Speed has no limits', 'released': 2008}> end=<Node id=6 labels={'Person'} properties={'name': 'Lana Wachowski', 'born': 1965}> size=1>>
# <Record p=<Path start=<Node id=116 labels={'Movie'} properties={'title': 'V for Vendetta', 'tagline': 'Freedom! Forever!', 'released': 2006}> end=<Node id=6 labels={'Person'} properties={'name': 'Lana Wachowski', 'born': 1965}> size=1>>
# <Record p=<Path start=<Node id=105 labels={'Movie'} properties={'title': 'Cloud Atlas', 'tagline': 'Everything is connected', 'released': 2012}> end=<Node id=6 labels={'Person'} properties={'name': 'Lana Wachowski', 'born': 1965}> size=1>>
# <Record p=<Path start=<Node id=10 labels={'Movie'} properties={'title': 'The Matrix Revolutions', 'tagline': 'Everything that has a beginning has an end', 'released': 2003}> end=<Node id=6 labels={'Person'} properties={'name': 'Lana Wachowski', 'born': 1965}> size=1>>
# <Record p=<Path start=<Node id=9 labels={'Movie'} properties={'title': 'The Matrix Reloaded', 'tagline': 'Free your mind', 'released': 2003}> end=<Node id=6 labels={'Person'} properties={'name': 'Lana Wachowski', 'born': 1965}> size=1>>
# <Record p=<Path start=<Node id=0 labels={'Movie'} properties={'title': 'The Matrix', 'tagline': 'Welcome to the Real World', 'released': 1999}> end=<Node id=6 labels={'Person'} properties={'name': 'Lana Wachowski', 'born': 1965}> size=1>>
# <Record p=<Path start=<Node id=128 labels={'Movie'} properties={'title': 'Ninja Assassin', 'tagline': 'Prepare to enter a secret world of assassins', 'released': 2009}> end=<Node id=7 labels={'Person'} properties={'name': 'Joel Silver', 'born': 1952}> size=1>>
# <Record p=<Path start=<Node id=121 labels={'Movie'} properties={'title': 'Speed Racer', 'tagline': 'Speed has no limits', 'released': 2008}> end=<Node id=7 labels={'Person'} properties={'name': 'Joel Silver', 'born': 1952}> size=1>>
# <Record p=<Path start=<Node id=116 labels={'Movie'} properties={'title': 'V for Vendetta', 'tagline': 'Freedom! Forever!', 'released': 2006}> end=<Node id=7 labels={'Person'} properties={'name': 'Joel Silver', 'born': 1952}> size=1>>
# <Record p=<Path start=<Node id=10 labels={'Movie'} properties={'title': 'The Matrix Revolutions', 'tagline': 'Everything that has a beginning has an end', 'released': 2003}> end=<Node id=7 labels={'Person'} properties={'name': 'Joel Silver', 'born': 1952}> size=1>>
# <Record p=<Path start=<Node id=9 labels={'Movie'} properties={'title': 'The Matrix Reloaded', 'tagline': 'Free your mind', 'released': 2003}> end=<Node id=7 labels={'Person'} properties={'name': 'Joel Silver', 'born': 1952}> size=1>>
# <Record p=<Path start=<Node id=0 labels={'Movie'} properties={'title': 'The Matrix', 'tagline': 'Welcome to the Real World', 'released': 1999}> end=<Node id=7 labels={'Person'} properties={'name': 'Joel Silver', 'born': 1952}> size=1>>
# <Record p=<Path start=<Node id=0 labels={'Movie'} properties={'title': 'The Matrix', 'tagline': 'Welcome to the Real World', 'released': 1999}> end=<Node id=8 labels={'Person'} properties={'name': 'Emil Eifrem', 'born': 1978}> size=1>>
# <Record p=<Path start=<Node id=7 labels={'Person'} properties={'name': 'Joel Silver', 'born': 1952}> end=<Node id=9 labels={'Movie'} properties={'title': 'The Matrix Reloaded', 'tagline': 'Free your mind', 'released': 2003}> size=1>>
# <Record p=<Path start=<Node id=6 labels={'Person'} properties={'name': 'Lana Wachowski', 'born': 1965}> end=<Node id=9 labels={'Movie'} properties={'title': 'The Matrix Reloaded', 'tagline': 'Free your mind', 'released': 2003}> size=1>>
# <Record p=<Path start=<Node id=5 labels={'Person'} properties={'name': 'Lilly Wachowski', 'born': 1967}> end=<Node id=9 labels={'Movie'} properties={'title': 'The Matrix Reloaded', 'tagline': 'Free your mind', 'released': 2003}> size=1>>
# <Record p=<Path start=<Node id=4 labels={'Person'} properties={'name': 'Hugo Weaving', 'born': 1960}> end=<Node id=9 labels={'Movie'} properties={'title': 'The Matrix Reloaded', 'tagline': 'Free your mind', 'released': 2003}> size=1>>
# <Record p=<Path start=<Node id=3 labels={'Person'} properties={'name': 'Laurence Fishburne', 'born': 1961}> end=<Node id=9 labels={'Movie'} properties={'title': 'The Matrix Reloaded', 'tagline': 'Free your mind', 'released': 2003}> size=1>>
# <Record p=<Path start=<Node id=2 labels={'Person'} properties={'name': 'Carrie-Anne Moss', 'born': 1967}> end=<Node id=9 labels={'Movie'} properties={'title': 'The Matrix Reloaded', 'tagline': 'Free your mind', 'released': 2003}> size=1>>
# <Record p=<Path start=<Node id=1 labels={'Person'} properties={'name': 'Keanu Reeves', 'born': 1964}> end=<Node id=9 labels={'Movie'} properties={'title': 'The Matrix Reloaded', 'tagline': 'Free your mind', 'released': 2003}> size=1>>
# <Record p=<Path start=<Node id=6 labels={'Person'} properties={'name': 'Lana Wachowski', 'born': 1965}> end=<Node id=10 labels={'Movie'} properties={'title': 'The Matrix Revolutions', 'tagline': 'Everything that has a beginning has an end', 'released': 2003}> size=1>>
# <Record p=<Path start=<Node id=7 labels={'Person'} properties={'name': 'Joel Silver', 'born': 1952}> end=<Node id=10 labels={'Movie'} properties={'title': 'The Matrix Revolutions', 'tagline': 'Everything that has a beginning has an end', 'released': 2003}> size=1>>
# <Record p=<Path start=<Node id=4 labels={'Person'} properties={'name': 'Hugo Weaving', 'born': 1960}> end=<Node id=10 labels={'Movie'} properties={'title': 'The Matrix Revolutions', 'tagline': 'Everything that has a beginning has an end', 'released': 2003}> size=1>>
# <Record p=<Path start=<Node id=5 labels={'Person'} properties={'name': 'Lilly Wachowski', 'born': 1967}> end=<Node id=10 labels={'Movie'} properties={'title': 'The Matrix Revolutions', 'tagline': 'Everything that has a beginning has an end', 'released': 2003}> size=1>>
# <Record p=<Path start=<Node id=2 labels={'Person'} properties={'name': 'Carrie-Anne Moss', 'born': 1967}> end=<Node id=10 labels={'Movie'} properties={'title': 'The Matrix Revolutions', 'tagline': 'Everything that has a beginning has an end', 'released': 2003}> size=1>>
# <Record p=<Path start=<Node id=3 labels={'Person'} properties={'name': 'Laurence Fishburne', 'born': 1961}> end=<Node id=10 labels={'Movie'} properties={'title': 'The Matrix Revolutions', 'tagline': 'Everything that has a beginning has an end', 'released': 2003}> size=1>>
# <Record p=<Path start=<Node id=1 labels={'Person'} properties={'name': 'Keanu Reeves', 'born': 1964}> end=<Node id=10 labels={'Movie'} properties={'title': 'The Matrix Revolutions', 'tagline': 'Everything that has a beginning has an end', 'released': 2003}> size=1>>
# <Record p=<Path start=<Node id=13 labels={'Person'} properties={'name': 'Al Pacino', 'born': 1940}> end=<Node id=11 labels={'Movie'} properties={'title': "The Devil's Advocate", 'tagline': 'Evil has its winning ways', 'released': 1997}> size=1>>
# <Record p=<Path start=<Node id=14 labels={'Person'} properties={'name': 'Taylor Hackford', 'born': 1944}> end=<Node id=11 labels={'Movie'} properties={'title': "The Devil's Advocate", 'tagline': 'Evil has its winning ways', 'released': 1997}> size=1>>
# <Record p=<Path start=<Node id=1 labels={'Person'} properties={'name': 'Keanu Reeves', 'born': 1964}> end=<Node id=11 labels={'Movie'} properties={'title': "The Devil's Advocate", 'tagline': 'Evil has its winning ways', 'released': 1997}> size=1>>
# <Record p=<Path start=<Node id=12 labels={'Person'} properties={'name': 'Charlize Theron', 'born': 1975}> end=<Node id=11 labels={'Movie'} properties={'title': "The Devil's Advocate", 'tagline': 'Evil has its winning ways', 'released': 1997}> size=1>>
# <Record p=<Path start=<Node id=85 labels={'Movie'} properties={'title': 'That Thing You Do', 'tagline': 'In every life there comes a time when that thing you dream becomes that thing you do', 'released': 1996}> end=<Node id=12 labels={'Person'} properties={'name': 'Charlize Theron', 'born': 1975}> size=1>>
# <Record p=<Path start=<Node id=11 labels={'Movie'} properties={'title': "The Devil's Advocate", 'tagline': 'Evil has its winning ways', 'released': 1997}> end=<Node id=12 labels={'Person'} properties={'name': 'Charlize Theron', 'born': 1975}> size=1>>
# <Record p=<Path start=<Node id=11 labels={'Movie'} properties={'title': "The Devil's Advocate", 'tagline': 'Evil has its winning ways', 'released': 1997}> end=<Node id=13 labels={'Person'} properties={'name': 'Al Pacino', 'born': 1940}> size=1>>
# <Record p=<Path start=<Node id=11 labels={'Movie'} properties={'title': "The Devil's Advocate", 'tagline': 'Evil has its winning ways', 'released': 1997}> end=<Node id=14 labels={'Person'} properties={'name': 'Taylor Hackford', 'born': 1944}> size=1>>
# <Record p=<Path start=<Node id=28 labels={'Person'} properties={'name': 'Aaron Sorkin', 'born': 1961}> end=<Node id=15 labels={'Movie'} properties={'title': 'A Few Good Men', 'tagline': "In the heart of the nation's capital, in a courthouse of the U.S. government, one man will stop at nothing to keep his honor, and one will stop at nothing to find the truth.", 'released': 1992}> size=1>>
# <Record p=<Path start=<Node id=26 labels={'Person'} properties={'name': 'Christopher Guest', 'born': 1948}> end=<Node id=15 labels={'Movie'} properties={'title': 'A Few Good Men', 'tagline': "In the heart of the nation's capital, in a courthouse of the U.S. government, one man will stop at nothing to keep his honor, and one will stop at nothing to find the truth.", 'released': 1992}> size=1>>
# <Record p=<Path start=<Node id=28 labels={'Person'} properties={'name': 'Aaron Sorkin', 'born': 1961}> end=<Node id=15 labels={'Movie'} properties={'title': 'A Few Good Men', 'tagline': "In the heart of the nation's capital, in a courthouse of the U.S. government, one man will stop at nothing to keep his honor, and one will stop at nothing to find the truth.", 'released': 1992}> size=1>>
# <Record p=<Path start=<Node id=27 labels={'Person'} properties={'name': 'Rob Reiner', 'born': 1947}> end=<Node id=15 labels={'Movie'} properties={'title': 'A Few Good Men', 'tagline': "In the heart of the nation's capital, in a courthouse of the U.S. government, one man will stop at nothing to keep his honor, and one will stop at nothing to find the truth.", 'released': 1992}> size=1>>
# <Record p=<Path start=<Node id=23 labels={'Person'} properties={'name': 'Kevin Pollak', 'born': 1957}> end=<Node id=15 labels={'Movie'} properties={'title': 'A Few Good Men', 'tagline': "In the heart of the nation's capital, in a courthouse of the U.S. government, one man will stop at nothing to keep his honor, and one will stop at nothing to find the truth.", 'released': 1992}> size=1>>
# <Record p=<Path start=<Node id=22 labels={'Person'} properties={'name': 'Cuba Gooding Jr.', 'born': 1968}> end=<Node id=15 labels={'Movie'} properties={'title': 'A Few Good Men', 'tagline': "In the heart of the nation's capital, in a courthouse of the U.S. government, one man will stop at nothing to keep his honor, and one will stop at nothing to find the truth.", 'released': 1992}> size=1>>
# <Record p=<Path start=<Node id=25 labels={'Person'} properties={'name': 'James Marshall', 'born': 1967}> end=<Node id=15 labels={'Movie'} properties={'title': 'A Few Good Men', 'tagline': "In the heart of the nation's capital, in a courthouse of the U.S. government, one man will stop at nothing to keep his honor, and one will stop at nothing to find the truth.", 'released': 1992}> size=1>>
# <Record p=<Path start=<Node id=24 labels={'Person'} properties={'name': 'J.T. Walsh', 'born': 1943}> end=<Node id=15 labels={'Movie'} properties={'title': 'A Few Good Men', 'tagline': "In the heart of the nation's capital, in a courthouse of the U.S. government, one man will stop at nothing to keep his honor, and one will stop at nothing to find the truth.", 'released': 1992}> size=1>>
# <Record p=<Path start=<Node id=20 labels={'Person'} properties={'name': 'Kiefer Sutherland', 'born': 1966}> end=<Node id=15 labels={'Movie'} properties={'title': 'A Few Good Men', 'tagline': "In the heart of the nation's capital, in a courthouse of the U.S. government, one man will stop at nothing to keep his honor, and one will stop at nothing to find the truth.", 'released': 1992}> size=1>>
# <Record p=<Path start=<Node id=21 labels={'Person'} properties={'name': 'Noah Wyle', 'born': 1971}> end=<Node id=15 labels={'Movie'} properties={'title': 'A Few Good Men', 'tagline': "In the heart of the nation's capital, in a courthouse of the U.S. government, one man will stop at nothing to keep his honor, and one will stop at nothing to find the truth.", 'released': 1992}> size=1>>
# <Record p=<Path start=<Node id=18 labels={'Person'} properties={'name': 'Demi Moore', 'born': 1962}> end=<Node id=15 labels={'Movie'} properties={'title': 'A Few Good Men', 'tagline': "In the heart of the nation's capital, in a courthouse of the U.S. government, one man will stop at nothing to keep his honor, and one will stop at nothing to find the truth.", 'released': 1992}> size=1>>
# <Record p=<Path start=<Node id=19 labels={'Person'} properties={'name': 'Kevin Bacon', 'born': 1958}> end=<Node id=15 labels={'Movie'} properties={'title': 'A Few Good Men', 'tagline': "In the heart of the nation's capital, in a courthouse of the U.S. government, one man will stop at nothing to keep his honor, and one will stop at nothing to find the truth.", 'released': 1992}> size=1>>
# <Record p=<Path start=<Node id=16 labels={'Person'} properties={'name': 'Tom Cruise', 'born': 1962}> end=<Node id=15 labels={'Movie'} properties={'title': 'A Few Good Men', 'tagline': "In the heart of the nation's capital, in a courthouse of the U.S. government, one man will stop at nothing to keep his honor, and one will stop at nothing to find the truth.", 'released': 1992}> size=1>>
# <Record p=<Path start=<Node id=17 labels={'Person'} properties={'name': 'Jack Nicholson', 'born': 1937}> end=<Node id=15 labels={'Movie'} properties={'title': 'A Few Good Men', 'tagline': "In the heart of the nation's capital, in a courthouse of the U.S. government, one man will stop at nothing to keep his honor, and one will stop at nothing to find the truth.", 'released': 1992}> size=1>>
# <Record p=<Path start=<Node id=37 labels={'Movie'} properties={'title': 'Jerry Maguire', 'tagline': 'The rest of his life begins now.', 'released': 2000}> end=<Node id=16 labels={'Person'} properties={'name': 'Tom Cruise', 'born': 1962}> size=1>>
# <Record p=<Path start=<Node id=29 labels={'Movie'} properties={'title': 'Top Gun', 'tagline': 'I feel the need, the need for speed.', 'released': 1986}> end=<Node id=16 labels={'Person'} properties={'name': 'Tom Cruise', 'born': 1962}> size=1>>
# <Record p=<Path start=<Node id=15 labels={'Movie'} properties={'title': 'A Few Good Men', 'tagline': "In the heart of the nation's capital, in a courthouse of the U.S. government, one man will stop at nothing to keep his honor, and one will stop at nothing to find the truth.", 'released': 1992}> end=<Node id=16 labels={'Person'} properties={'name': 'Tom Cruise', 'born': 1962}> size=1>>
# <Record p=<Path start=<Node id=154 labels={'Movie'} properties={'title': "Something's Gotta Give", 'released': 2003}> end=<Node id=17 labels={'Person'} properties={'name': 'Jack Nicholson', 'born': 1937}> size=1>>
# <Record p=<Path start=<Node id=152 labels={'Movie'} properties={'title': "One Flew Over the Cuckoo's Nest", 'tagline': "If he's crazy, what does that make you?", 'released': 1975}> end=<Node id=17 labels={'Person'} properties={'name': 'Jack Nicholson', 'born': 1937}> size=1>>
# <Record p=<Path start=<Node id=141 labels={'Movie'} properties={'title': 'Hoffa', 'tagline': "He didn't want law. He wanted justice.", 'released': 1992}> end=<Node id=17 labels={'Person'} properties={'name': 'Jack Nicholson', 'born': 1937}> size=1>>
# <Record p=<Path start=<Node id=52 labels={'Movie'} properties={'title': 'As Good as It Gets', 'tagline': 'A comedy from the heart that goes for the throat.', 'released': 1997}> end=<Node id=17 labels={'Person'} properties={'name': 'Jack Nicholson', 'born': 1937}> size=1>>
# <Record p=<Path start=<Node id=15 labels={'Movie'} properties={'title': 'A Few Good Men', 'tagline': "In the heart of the nation's capital, in a courthouse of the U.S. government, one man will stop at nothing to keep his honor, and one will stop at nothing to find the truth.", 'released': 1992}> end=<Node id=17 labels={'Person'} properties={'name': 'Jack Nicholson', 'born': 1937}> size=1>>
# <Record p=<Path start=<Node id=15 labels={'Movie'} properties={'title': 'A Few Good Men', 'tagline': "In the heart of the nation's capital, in a courthouse of the U.S. government, one man will stop at nothing to keep his honor, and one will stop at nothing to find the truth.", 'released': 1992}> end=<Node id=18 labels={'Person'} properties={'name': 'Demi Moore', 'born': 1962}> size=1>>
# <Record p=<Path start=<Node id=137 labels={'Movie'} properties={'title': 'Frost/Nixon', 'tagline': '400 million people were waiting for the truth.', 'released': 2008}> end=<Node id=19 labels={'Person'} properties={'name': 'Kevin Bacon', 'born': 1958}> size=1>>
# <Record p=<Path start=<Node id=144 labels={'Movie'} properties={'title': 'Apollo 13', 'tagline': 'Houston, we have a problem.', 'released': 1995}> end=<Node id=19 labels={'Person'} properties={'name': 'Kevin Bacon', 'born': 1958}> size=1>>
# <Record p=<Path start=<Node id=15 labels={'Movie'} properties={'title': 'A Few Good Men', 'tagline': "In the heart of the nation's capital, in a courthouse of the U.S. government, one man will stop at nothing to keep his honor, and one will stop at nothing to find the truth.", 'released': 1992}> end=<Node id=19 labels={'Person'} properties={'name': 'Kevin Bacon', 'born': 1958}> size=1>>
# <Record p=<Path start=<Node id=46 labels={'Movie'} properties={'title': 'Stand By Me', 'tagline': "For some, it's the last real taste of innocence, and the first real taste of life. But for everyone, it's the time that memories are made of.", 'released': 1986}> end=<Node id=20 labels={'Person'} properties={'name': 'Kiefer Sutherland', 'born': 1966}> size=1>>
# <Record p=<Path start=<Node id=15 labels={'Movie'} properties={'title': 'A Few Good Men', 'tagline': "In the heart of the nation's capital, in a courthouse of the U.S. government, one man will stop at nothing to keep his honor, and one will stop at nothing to find the truth.", 'released': 1992}> end=<Node id=20 labels={'Person'} properties={'name': 'Kiefer Sutherland', 'born': 1966}> size=1>>
# <Record p=<Path start=<Node id=15 labels={'Movie'} properties={'title': 'A Few Good Men', 'tagline': "In the heart of the nation's capital, in a courthouse of the U.S. government, one man will stop at nothing to keep his honor, and one will stop at nothing to find the truth.", 'released': 1992}> end=<Node id=21 labels={'Person'} properties={'name': 'Noah Wyle', 'born': 1971}> size=1>>
# <Record p=<Path start=<Node id=56 labels={'Movie'} properties={'title': 'What Dreams May Come', 'tagline': 'After life there is more. The end is just the beginning.', 'released': 1998}> end=<Node id=22 labels={'Person'} properties={'name': 'Cuba Gooding Jr.', 'born': 1968}> size=1>>
# <Record p=<Path start=<Node id=52 labels={'Movie'} properties={'title': 'As Good as It Gets', 'tagline': 'A comedy from the heart that goes for the throat.', 'released': 1997}> end=<Node id=22 labels={'Person'} properties={'name': 'Cuba Gooding Jr.', 'born': 1968}> size=1>>
# <Record p=<Path start=<Node id=37 labels={'Movie'} properties={'title': 'Jerry Maguire', 'tagline': 'The rest of his life begins now.', 'released': 2000}> end=<Node id=22 labels={'Person'} properties={'name': 'Cuba Gooding Jr.', 'born': 1968}> size=1>>
# <Record p=<Path start=<Node id=15 labels={'Movie'} properties={'title': 'A Few Good Men', 'tagline': "In the heart of the nation's capital, in a courthouse of the U.S. government, one man will stop at nothing to keep his honor, and one will stop at nothing to find the truth.", 'released': 1992}> end=<Node id=22 labels={'Person'} properties={'name': 'Cuba Gooding Jr.', 'born': 1968}> size=1>>
# <Record p=<Path start=<Node id=15 labels={'Movie'} properties={'title': 'A Few Good Men', 'tagline': "In the heart of the nation's capital, in a courthouse of the U.S. government, one man will stop at nothing to keep his honor, and one will stop at nothing to find the truth.", 'released': 1992}> end=<Node id=23 labels={'Person'} properties={'name': 'Kevin Pollak', 'born': 1957}> size=1>>
# <Record p=<Path start=<Node id=141 labels={'Movie'} properties={'title': 'Hoffa', 'tagline': "He didn't want law. He wanted justice.", 'released': 1992}> end=<Node id=24 labels={'Person'} properties={'name': 'J.T. Walsh', 'born': 1943}> size=1>>
# <Record p=<Path start=<Node id=15 labels={'Movie'} properties={'title': 'A Few Good Men', 'tagline': "In the heart of the nation's capital, in a courthouse of the U.S. government, one man will stop at nothing to keep his honor, and one will stop at nothing to find the truth.", 'released': 1992}> end=<Node id=24 labels={'Person'} properties={'name': 'J.T. Walsh', 'born': 1943}> size=1>>
# <Record p=<Path start=<Node id=128 labels={'Movie'} properties={'title': 'Ninja Assassin', 'tagline': 'Prepare to enter a secret world of assassins', 'released': 2009}> end=<Node id=25 labels={'Person'} properties={'name': 'James Marshall', 'born': 1967}> size=1>>
# <Record p=<Path start=<Node id=116 labels={'Movie'} properties={'title': 'V for Vendetta', 'tagline': 'Freedom! Forever!', 'released': 2006}> end=<Node id=25 labels={'Person'} properties={'name': 'James Marshall', 'born': 1967}> size=1>>
# <Record p=<Path start=<Node id=15 labels={'Movie'} properties={'title': 'A Few Good Men', 'tagline': "In the heart of the nation's capital, in a courthouse of the U.S. government, one man will stop at nothing to keep his honor, and one will stop at nothing to find the truth.", 'released': 1992}> end=<Node id=25 labels={'Person'} properties={'name': 'James Marshall', 'born': 1967}> size=1>>
# <Record p=<Path start=<Node id=15 labels={'Movie'} properties={'title': 'A Few Good Men', 'tagline': "In the heart of the nation's capital, in a courthouse of the U.S. government, one man will stop at nothing to keep his honor, and one will stop at nothing to find the truth.", 'released': 1992}> end=<Node id=26 labels={'Person'} properties={'name': 'Christopher Guest', 'born': 1948}> size=1>>
# <Record p=<Path start=<Node id=81 labels={'Movie'} properties={'title': 'When Harry Met Sally', 'tagline': 'At odds in life... in love on-line.', 'released': 1998}> end=<Node id=27 labels={'Person'} properties={'name': 'Rob Reiner', 'born': 1947}> size=1>>
# <Record p=<Path start=<Node id=81 labels={'Movie'} properties={'title': 'When Harry Met Sally', 'tagline': 'At odds in life... in love on-line.', 'released': 1998}> end=<Node id=27 labels={'Person'} properties={'name': 'Rob Reiner', 'born': 1947}> size=1>>
# <Record p=<Path start=<Node id=46 labels={'Movie'} properties={'title': 'Stand By Me', 'tagline': "For some, it's the last real taste of innocence, and the first real taste of life. But for everyone, it's the time that memories are made of.", 'released': 1986}> end=<Node id=27 labels={'Person'} properties={'name': 'Rob Reiner', 'born': 1947}> size=1>>
# <Record p=<Path start=<Node id=15 labels={'Movie'} properties={'title': 'A Few Good Men', 'tagline': "In the heart of the nation's capital, in a courthouse of the U.S. government, one man will stop at nothing to keep his honor, and one will stop at nothing to find the truth.", 'released': 1992}> end=<Node id=27 labels={'Person'} properties={'name': 'Rob Reiner', 'born': 1947}> size=1>>
# <Record p=<Path start=<Node id=15 labels={'Movie'} properties={'title': 'A Few Good Men', 'tagline': "In the heart of the nation's capital, in a courthouse of the U.S. government, one man will stop at nothing to keep his honor, and one will stop at nothing to find the truth.", 'released': 1992}> end=<Node id=28 labels={'Person'} properties={'name': 'Aaron Sorkin', 'born': 1961}> size=1>>
# <Record p=<Path start=<Node id=15 labels={'Movie'} properties={'title': 'A Few Good Men', 'tagline': "In the heart of the nation's capital, in a courthouse of the U.S. government, one man will stop at nothing to keep his honor, and one will stop at nothing to find the truth.", 'released': 1992}> end=<Node id=28 labels={'Person'} properties={'name': 'Aaron Sorkin', 'born': 1961}> size=1>>
# <Record p=<Path start=<Node id=34 labels={'Person'} properties={'name': 'Meg Ryan', 'born': 1961}> end=<Node id=29 labels={'Movie'} properties={'title': 'Top Gun', 'tagline': 'I feel the need, the need for speed.', 'released': 1986}> size=1>>
# <Record p=<Path start=<Node id=33 labels={'Person'} properties={'name': 'Tom Skerritt', 'born': 1933}> end=<Node id=29 labels={'Movie'} properties={'title': 'Top Gun', 'tagline': 'I feel the need, the need for speed.', 'released': 1986}> size=1>>
# <Record p=<Path start=<Node id=36 labels={'Person'} properties={'name': 'Jim Cash', 'born': 1941}> end=<Node id=29 labels={'Movie'} properties={'title': 'Top Gun', 'tagline': 'I feel the need, the need for speed.', 'released': 1986}> size=1>>
# <Record p=<Path start=<Node id=35 labels={'Person'} properties={'name': 'Tony Scott', 'born': 1944}> end=<Node id=29 labels={'Movie'} properties={'title': 'Top Gun', 'tagline': 'I feel the need, the need for speed.', 'released': 1986}> size=1>>
# <Record p=<Path start=<Node id=30 labels={'Person'} properties={'name': 'Kelly McGillis', 'born': 1957}> end=<Node id=29 labels={'Movie'} properties={'title': 'Top Gun', 'tagline': 'I feel the need, the need for speed.', 'released': 1986}> size=1>>
# <Record p=<Path start=<Node id=16 labels={'Person'} properties={'name': 'Tom Cruise', 'born': 1962}> end=<Node id=29 labels={'Movie'} properties={'title': 'Top Gun', 'tagline': 'I feel the need, the need for speed.', 'released': 1986}> size=1>>
# <Record p=<Path start=<Node id=32 labels={'Person'} properties={'name': 'Anthony Edwards', 'born': 1962}> end=<Node id=29 labels={'Movie'} properties={'title': 'Top Gun', 'tagline': 'I feel the need, the need for speed.', 'released': 1986}> size=1>>
# <Record p=<Path start=<Node id=31 labels={'Person'} properties={'name': 'Val Kilmer', 'born': 1959}> end=<Node id=29 labels={'Movie'} properties={'title': 'Top Gun', 'tagline': 'I feel the need, the need for speed.', 'released': 1986}> size=1>>
# <Record p=<Path start=<Node id=29 labels={'Movie'} properties={'title': 'Top Gun', 'tagline': 'I feel the need, the need for speed.', 'released': 1986}> end=<Node id=30 labels={'Person'} properties={'name': 'Kelly McGillis', 'born': 1957}> size=1>>
# <Record p=<Path start=<Node id=29 labels={'Movie'} properties={'title': 'Top Gun', 'tagline': 'I feel the need, the need for speed.', 'released': 1986}> end=<Node id=31 labels={'Person'} properties={'name': 'Val Kilmer', 'born': 1959}> size=1>>
# <Record p=<Path start=<Node id=29 labels={'Movie'} properties={'title': 'Top Gun', 'tagline': 'I feel the need, the need for speed.', 'released': 1986}> end=<Node id=32 labels={'Person'} properties={'name': 'Anthony Edwards', 'born': 1962}> size=1>>
# <Record p=<Path start=<Node id=29 labels={'Movie'} properties={'title': 'Top Gun', 'tagline': 'I feel the need, the need for speed.', 'released': 1986}> end=<Node id=33 labels={'Person'} properties={'name': 'Tom Skerritt', 'born': 1933}> size=1>>
# <Record p=<Path start=<Node id=78 labels={'Movie'} properties={'title': 'Joe Versus the Volcano', 'tagline': 'A story of love, lava and burning desire.', 'released': 1990}> end=<Node id=34 labels={'Person'} properties={'name': 'Meg Ryan', 'born': 1961}> size=1>>
# <Record p=<Path start=<Node id=81 labels={'Movie'} properties={'title': 'When Harry Met Sally', 'tagline': 'At odds in life... in love on-line.', 'released': 1998}> end=<Node id=34 labels={'Person'} properties={'name': 'Meg Ryan', 'born': 1961}> size=1>>
# <Record p=<Path start=<Node id=73 labels={'Movie'} properties={'title': 'Sleepless in Seattle', 'tagline': 'What if someone you never met, someone you never saw, someone you never knew was the only someone for you?', 'released': 1993}> end=<Node id=34 labels={'Person'} properties={'name': 'Meg Ryan', 'born': 1961}> size=1>>
# <Record p=<Path start=<Node id=67 labels={'Movie'} properties={'title': "You've Got Mail", 'tagline': 'At odds in life... in love on-line.', 'released': 1998}> end=<Node id=34 labels={'Person'} properties={'name': 'Meg Ryan', 'born': 1961}> size=1>>
# <Record p=<Path start=<Node id=29 labels={'Movie'} properties={'title': 'Top Gun', 'tagline': 'I feel the need, the need for speed.', 'released': 1986}> end=<Node id=34 labels={'Person'} properties={'name': 'Meg Ryan', 'born': 1961}> size=1>>
# <Record p=<Path start=<Node id=29 labels={'Movie'} properties={'title': 'Top Gun', 'tagline': 'I feel the need, the need for speed.', 'released': 1986}> end=<Node id=35 labels={'Person'} properties={'name': 'Tony Scott', 'born': 1944}> size=1>>
# <Record p=<Path start=<Node id=29 labels={'Movie'} properties={'title': 'Top Gun', 'tagline': 'I feel the need, the need for speed.', 'released': 1986}> end=<Node id=36 labels={'Person'} properties={'name': 'Jim Cash', 'born': 1941}> size=1>>
# <Record p=<Path start=<Node id=169 labels={'Person'} properties={'name': 'Jessica Thompson'}> end=<Node id=37 labels={'Movie'} properties={'title': 'Jerry Maguire', 'tagline': 'The rest of his life begins now.', 'released': 2000}> size=1>>
# <Record p=<Path start=<Node id=44 labels={'Person'} properties={'name': 'Jonathan Lipnicki', 'born': 1996}> end=<Node id=37 labels={'Movie'} properties={'title': 'Jerry Maguire', 'tagline': 'The rest of his life begins now.', 'released': 2000}> size=1>>
# <Record p=<Path start=<Node id=45 labels={'Person'} properties={'name': 'Cameron Crowe', 'born': 1957}> end=<Node id=37 labels={'Movie'} properties={'title': 'Jerry Maguire', 'tagline': 'The rest of his life begins now.', 'released': 2000}> size=1>>
# <Record p=<Path start=<Node id=45 labels={'Person'} properties={'name': 'Cameron Crowe', 'born': 1957}> end=<Node id=37 labels={'Movie'} properties={'title': 'Jerry Maguire', 'tagline': 'The rest of his life begins now.', 'released': 2000}> size=1>>
# <Record p=<Path start=<Node id=45 labels={'Person'} properties={'name': 'Cameron Crowe', 'born': 1957}> end=<Node id=37 labels={'Movie'} properties={'title': 'Jerry Maguire', 'tagline': 'The rest of his life begins now.', 'released': 2000}> size=1>>
# <Record p=<Path start=<Node id=40 labels={'Person'} properties={'name': "Jerry O'Connell", 'born': 1974}> end=<Node id=37 labels={'Movie'} properties={'title': 'Jerry Maguire', 'tagline': 'The rest of his life begins now.', 'released': 2000}> size=1>>
# <Record p=<Path start=<Node id=41 labels={'Person'} properties={'name': 'Jay Mohr', 'born': 1970}> end=<Node id=37 labels={'Movie'} properties={'title': 'Jerry Maguire', 'tagline': 'The rest of his life begins now.', 'released': 2000}> size=1>>
# <Record p=<Path start=<Node id=42 labels={'Person'} properties={'name': 'Bonnie Hunt', 'born': 1961}> end=<Node id=37 labels={'Movie'} properties={'title': 'Jerry Maguire', 'tagline': 'The rest of his life begins now.', 'released': 2000}> size=1>>
# <Record p=<Path start=<Node id=43 labels={'Person'} properties={'name': 'Regina King', 'born': 1971}> end=<Node id=37 labels={'Movie'} properties={'title': 'Jerry Maguire', 'tagline': 'The rest of his life begins now.', 'released': 2000}> size=1>>
# <Record p=<Path start=<Node id=16 labels={'Person'} properties={'name': 'Tom Cruise', 'born': 1962}> end=<Node id=37 labels={'Movie'} properties={'title': 'Jerry Maguire', 'tagline': 'The rest of his life begins now.', 'released': 2000}> size=1>>
# <Record p=<Path start=<Node id=22 labels={'Person'} properties={'name': 'Cuba Gooding Jr.', 'born': 1968}> end=<Node id=37 labels={'Movie'} properties={'title': 'Jerry Maguire', 'tagline': 'The rest of his life begins now.', 'released': 2000}> size=1>>
# <Record p=<Path start=<Node id=38 labels={'Person'} properties={'name': 'Renee Zellweger', 'born': 1969}> end=<Node id=37 labels={'Movie'} properties={'title': 'Jerry Maguire', 'tagline': 'The rest of his life begins now.', 'released': 2000}> size=1>>
# <Record p=<Path start=<Node id=39 labels={'Person'} properties={'name': 'Kelly Preston', 'born': 1962}> end=<Node id=37 labels={'Movie'} properties={'title': 'Jerry Maguire', 'tagline': 'The rest of his life begins now.', 'released': 2000}> size=1>>
# <Record p=<Path start=<Node id=37 labels={'Movie'} properties={'title': 'Jerry Maguire', 'tagline': 'The rest of his life begins now.', 'released': 2000}> end=<Node id=38 labels={'Person'} properties={'name': 'Renee Zellweger', 'born': 1969}> size=1>>
# <Record p=<Path start=<Node id=37 labels={'Movie'} properties={'title': 'Jerry Maguire', 'tagline': 'The rest of his life begins now.', 'released': 2000}> end=<Node id=39 labels={'Person'} properties={'name': 'Kelly Preston', 'born': 1962}> size=1>>
# <Record p=<Path start=<Node id=46 labels={'Movie'} properties={'title': 'Stand By Me', 'tagline': "For some, it's the last real taste of innocence, and the first real taste of life. But for everyone, it's the time that memories are made of.", 'released': 1986}> end=<Node id=40 labels={'Person'} properties={'name': "Jerry O'Connell", 'born': 1974}> size=1>>
# <Record p=<Path start=<Node id=37 labels={'Movie'} properties={'title': 'Jerry Maguire', 'tagline': 'The rest of his life begins now.', 'released': 2000}> end=<Node id=40 labels={'Person'} properties={'name': "Jerry O'Connell", 'born': 1974}> size=1>>
# <Record p=<Path start=<Node id=37 labels={'Movie'} properties={'title': 'Jerry Maguire', 'tagline': 'The rest of his life begins now.', 'released': 2000}> end=<Node id=41 labels={'Person'} properties={'name': 'Jay Mohr', 'born': 1970}> size=1>>
# <Record p=<Path start=<Node id=130 labels={'Movie'} properties={'title': 'The Green Mile', 'tagline': "Walk a mile you'll never forget.", 'released': 1999}> end=<Node id=42 labels={'Person'} properties={'name': 'Bonnie Hunt', 'born': 1961}> size=1>>
# <Record p=<Path start=<Node id=37 labels={'Movie'} properties={'title': 'Jerry Maguire', 'tagline': 'The rest of his life begins now.', 'released': 2000}> end=<Node id=42 labels={'Person'} properties={'name': 'Bonnie Hunt', 'born': 1961}> size=1>>
# <Record p=<Path start=<Node id=37 labels={'Movie'} properties={'title': 'Jerry Maguire', 'tagline': 'The rest of his life begins now.', 'released': 2000}> end=<Node id=43 labels={'Person'} properties={'name': 'Regina King', 'born': 1971}> size=1>>
# <Record p=<Path start=<Node id=37 labels={'Movie'} properties={'title': 'Jerry Maguire', 'tagline': 'The rest of his life begins now.', 'released': 2000}> end=<Node id=44 labels={'Person'} properties={'name': 'Jonathan Lipnicki', 'born': 1996}> size=1>>
# <Record p=<Path start=<Node id=37 labels={'Movie'} properties={'title': 'Jerry Maguire', 'tagline': 'The rest of his life begins now.', 'released': 2000}> end=<Node id=45 labels={'Person'} properties={'name': 'Cameron Crowe', 'born': 1957}> size=1>>
# <Record p=<Path start=<Node id=37 labels={'Movie'} properties={'title': 'Jerry Maguire', 'tagline': 'The rest of his life begins now.', 'released': 2000}> end=<Node id=45 labels={'Person'} properties={'name': 'Cameron Crowe', 'born': 1957}> size=1>>
# <Record p=<Path start=<Node id=37 labels={'Movie'} properties={'title': 'Jerry Maguire', 'tagline': 'The rest of his life begins now.', 'released': 2000}> end=<Node id=45 labels={'Person'} properties={'name': 'Cameron Crowe', 'born': 1957}> size=1>>
# <Record p=<Path start=<Node id=27 labels={'Person'} properties={'name': 'Rob Reiner', 'born': 1947}> end=<Node id=46 labels={'Movie'} properties={'title': 'Stand By Me', 'tagline': "For some, it's the last real taste of innocence, and the first real taste of life. But for everyone, it's the time that memories are made of.", 'released': 1986}> size=1>>
# <Record p=<Path start=<Node id=51 labels={'Person'} properties={'name': 'Marshall Bell', 'born': 1942}> end=<Node id=46 labels={'Movie'} properties={'title': 'Stand By Me', 'tagline': "For some, it's the last real taste of innocence, and the first real taste of life. But for everyone, it's the time that memories are made of.", 'released': 1986}> size=1>>
# <Record p=<Path start=<Node id=20 labels={'Person'} properties={'name': 'Kiefer Sutherland', 'born': 1966}> end=<Node id=46 labels={'Movie'} properties={'title': 'Stand By Me', 'tagline': "For some, it's the last real taste of innocence, and the first real taste of life. But for everyone, it's the time that memories are made of.", 'released': 1986}> size=1>>
# <Record p=<Path start=<Node id=50 labels={'Person'} properties={'name': 'John Cusack', 'born': 1966}> end=<Node id=46 labels={'Movie'} properties={'title': 'Stand By Me', 'tagline': "For some, it's the last real taste of innocence, and the first real taste of life. But for everyone, it's the time that memories are made of.", 'released': 1986}> size=1>>
# <Record p=<Path start=<Node id=49 labels={'Person'} properties={'name': 'Wil Wheaton', 'born': 1972}> end=<Node id=46 labels={'Movie'} properties={'title': 'Stand By Me', 'tagline': "For some, it's the last real taste of innocence, and the first real taste of life. But for everyone, it's the time that memories are made of.", 'released': 1986}> size=1>>
# <Record p=<Path start=<Node id=47 labels={'Person'} properties={'name': 'River Phoenix', 'born': 1970}> end=<Node id=46 labels={'Movie'} properties={'title': 'Stand By Me', 'tagline': "For some, it's the last real taste of innocence, and the first real taste of life. But for everyone, it's the time that memories are made of.", 'released': 1986}> size=1>>
# <Record p=<Path start=<Node id=40 labels={'Person'} properties={'name': "Jerry O'Connell", 'born': 1974}> end=<Node id=46 labels={'Movie'} properties={'title': 'Stand By Me', 'tagline': "For some, it's the last real taste of innocence, and the first real taste of life. But for everyone, it's the time that memories are made of.", 'released': 1986}> size=1>>
# <Record p=<Path start=<Node id=48 labels={'Person'} properties={'name': 'Corey Feldman', 'born': 1971}> end=<Node id=46 labels={'Movie'} properties={'title': 'Stand By Me', 'tagline': "For some, it's the last real taste of innocence, and the first real taste of life. But for everyone, it's the time that memories are made of.", 'released': 1986}> size=1>>
# ...
# <Record p=<Path start=<Node id=94 labels={'Person'} properties={'name': 'Zach Grenier', 'born': 1954}> end=<Node id=147 labels={'Movie'} properties={'title': 'Twister', 'tagline': "Don't Breathe. Don't Look Back.", 'released': 1996}> size=1>>
# <Record p=<Path start=<Node id=53 labels={'Person'} properties={'name': 'Helen Hunt', 'born': 1963}> end=<Node id=147 labels={'Movie'} properties={'title': 'Twister', 'tagline': "Don't Breathe. Don't Look Back.", 'released': 1996}> size=1>>
# <Record p=<Path start=<Node id=146 labels={'Person'} properties={'name': 'Bill Paxton', 'born': 1955}> end=<Node id=147 labels={'Movie'} properties={'title': 'Twister', 'tagline': "Don't Breathe. Don't Look Back.", 'released': 1996}> size=1>>
# <Record p=<Path start=<Node id=149 labels={'Person'} properties={'name': 'Jan de Bont', 'born': 1943}> end=<Node id=147 labels={'Movie'} properties={'title': 'Twister', 'tagline': "Don't Breathe. Don't Look Back.", 'released': 1996}> size=1>>
# <Record p=<Path start=<Node id=159 labels={'Movie'} properties={'title': "Charlie Wilson's War", 'tagline': "A stiff drink. A little mascara. A lot of nerve. Who said they couldn't bring down the Soviet empire.", 'released': 2007}> end=<Node id=148 labels={'Person'} properties={'name': 'Philip Seymour Hoffman', 'born': 1967}> size=1>>
# <Record p=<Path start=<Node id=147 labels={'Movie'} properties={'title': 'Twister', 'tagline': "Don't Breathe. Don't Look Back.", 'released': 1996}> end=<Node id=148 labels={'Person'} properties={'name': 'Philip Seymour Hoffman', 'born': 1967}> size=1>>
# <Record p=<Path start=<Node id=147 labels={'Movie'} properties={'title': 'Twister', 'tagline': "Don't Breathe. Don't Look Back.", 'released': 1996}> end=<Node id=149 labels={'Person'} properties={'name': 'Jan de Bont', 'born': 1943}> size=1>>
# <Record p=<Path start=<Node id=151 labels={'Person'} properties={'name': 'Robert Zemeckis', 'born': 1951}> end=<Node id=150 labels={'Movie'} properties={'title': 'Cast Away', 'tagline': 'At the edge of the world, his journey begins.', 'released': 2000}> size=1>>
# <Record p=<Path start=<Node id=53 labels={'Person'} properties={'name': 'Helen Hunt', 'born': 1963}> end=<Node id=150 labels={'Movie'} properties={'title': 'Cast Away', 'tagline': 'At the edge of the world, his journey begins.', 'released': 2000}> size=1>>
# <Record p=<Path start=<Node id=71 labels={'Person'} properties={'name': 'Tom Hanks', 'born': 1956}> end=<Node id=150 labels={'Movie'} properties={'title': 'Cast Away', 'tagline': 'At the edge of the world, his journey begins.', 'released': 2000}> size=1>>
# <Record p=<Path start=<Node id=161 labels={'Movie'} properties={'title': 'The Polar Express', 'tagline': 'This Holiday Season… Believe', 'released': 2004}> end=<Node id=151 labels={'Person'} properties={'name': 'Robert Zemeckis', 'born': 1951}> size=1>>
# <Record p=<Path start=<Node id=150 labels={'Movie'} properties={'title': 'Cast Away', 'tagline': 'At the edge of the world, his journey begins.', 'released': 2000}> end=<Node id=151 labels={'Person'} properties={'name': 'Robert Zemeckis', 'born': 1951}> size=1>>
# <Record p=<Path start=<Node id=153 labels={'Person'} properties={'name': 'Milos Forman', 'born': 1932}> end=<Node id=152 labels={'Movie'} properties={'title': "One Flew Over the Cuckoo's Nest", 'tagline': "If he's crazy, what does that make you?", 'released': 1975}> size=1>>
# <Record p=<Path start=<Node id=142 labels={'Person'} properties={'name': 'Danny DeVito', 'born': 1944}> end=<Node id=152 labels={'Movie'} properties={'title': "One Flew Over the Cuckoo's Nest", 'tagline': "If he's crazy, what does that make you?", 'released': 1975}> size=1>>
# <Record p=<Path start=<Node id=17 labels={'Person'} properties={'name': 'Jack Nicholson', 'born': 1937}> end=<Node id=152 labels={'Movie'} properties={'title': "One Flew Over the Cuckoo's Nest", 'tagline': "If he's crazy, what does that make you?", 'released': 1975}> size=1>>
# <Record p=<Path start=<Node id=152 labels={'Movie'} properties={'title': "One Flew Over the Cuckoo's Nest", 'tagline': "If he's crazy, what does that make you?", 'released': 1975}> end=<Node id=153 labels={'Person'} properties={'name': 'Milos Forman', 'born': 1932}> size=1>>
# <Record p=<Path start=<Node id=156 labels={'Person'} properties={'name': 'Nancy Meyers', 'born': 1949}> end=<Node id=154 labels={'Movie'} properties={'title': "Something's Gotta Give", 'released': 2003}> size=1>>
# <Record p=<Path start=<Node id=17 labels={'Person'} properties={'name': 'Jack Nicholson', 'born': 1937}> end=<Node id=154 labels={'Movie'} properties={'title': "Something's Gotta Give", 'released': 2003}> size=1>>
# <Record p=<Path start=<Node id=156 labels={'Person'} properties={'name': 'Nancy Meyers', 'born': 1949}> end=<Node id=154 labels={'Movie'} properties={'title': "Something's Gotta Give", 'released': 2003}> size=1>>
# <Record p=<Path start=<Node id=156 labels={'Person'} properties={'name': 'Nancy Meyers', 'born': 1949}> end=<Node id=154 labels={'Movie'} properties={'title': "Something's Gotta Give", 'released': 2003}> size=1>>
# <Record p=<Path start=<Node id=1 labels={'Person'} properties={'name': 'Keanu Reeves', 'born': 1964}> end=<Node id=154 labels={'Movie'} properties={'title': "Something's Gotta Give", 'released': 2003}> size=1>>
# <Record p=<Path start=<Node id=155 labels={'Person'} properties={'name': 'Diane Keaton', 'born': 1946}> end=<Node id=154 labels={'Movie'} properties={'title': "Something's Gotta Give", 'released': 2003}> size=1>>
# <Record p=<Path start=<Node id=154 labels={'Movie'} properties={'title': "Something's Gotta Give", 'released': 2003}> end=<Node id=155 labels={'Person'} properties={'name': 'Diane Keaton', 'born': 1946}> size=1>>
# <Record p=<Path start=<Node id=154 labels={'Movie'} properties={'title': "Something's Gotta Give", 'released': 2003}> end=<Node id=156 labels={'Person'} properties={'name': 'Nancy Meyers', 'born': 1949}> size=1>>
# <Record p=<Path start=<Node id=154 labels={'Movie'} properties={'title': "Something's Gotta Give", 'released': 2003}> end=<Node id=156 labels={'Person'} properties={'name': 'Nancy Meyers', 'born': 1949}> size=1>>
# <Record p=<Path start=<Node id=154 labels={'Movie'} properties={'title': "Something's Gotta Give", 'released': 2003}> end=<Node id=156 labels={'Person'} properties={'name': 'Nancy Meyers', 'born': 1949}> size=1>>
# <Record p=<Path start=<Node id=60 labels={'Person'} properties={'name': 'Robin Williams', 'born': 1951}> end=<Node id=157 labels={'Movie'} properties={'title': 'Bicentennial Man', 'tagline': "One robot's 200 year journey to become an ordinary man.", 'released': 1999}> size=1>>
# <Record p=<Path start=<Node id=140 labels={'Person'} properties={'name': 'Oliver Platt', 'born': 1960}> end=<Node id=157 labels={'Movie'} properties={'title': 'Bicentennial Man', 'tagline': "One robot's 200 year journey to become an ordinary man.", 'released': 1999}> size=1>>
# <Record p=<Path start=<Node id=158 labels={'Person'} properties={'name': 'Chris Columbus', 'born': 1958}> end=<Node id=157 labels={'Movie'} properties={'title': 'Bicentennial Man', 'tagline': "One robot's 200 year journey to become an ordinary man.", 'released': 1999}> size=1>>
# <Record p=<Path start=<Node id=157 labels={'Movie'} properties={'title': 'Bicentennial Man', 'tagline': "One robot's 200 year journey to become an ordinary man.", 'released': 1999}> end=<Node id=158 labels={'Person'} properties={'name': 'Chris Columbus', 'born': 1958}> size=1>>
# <Record p=<Path start=<Node id=71 labels={'Person'} properties={'name': 'Tom Hanks', 'born': 1956}> end=<Node id=159 labels={'Movie'} properties={'title': "Charlie Wilson's War", 'tagline': "A stiff drink. A little mascara. A lot of nerve. Who said they couldn't bring down the Soviet empire.", 'released': 2007}> size=1>>
# <Record p=<Path start=<Node id=160 labels={'Person'} properties={'name': 'Julia Roberts', 'born': 1967}> end=<Node id=159 labels={'Movie'} properties={'title': "Charlie Wilson's War", 'tagline': "A stiff drink. A little mascara. A lot of nerve. Who said they couldn't bring down the Soviet empire.", 'released': 2007}> size=1>>
# <Record p=<Path start=<Node id=148 labels={'Person'} properties={'name': 'Philip Seymour Hoffman', 'born': 1967}> end=<Node id=159 labels={'Movie'} properties={'title': "Charlie Wilson's War", 'tagline': "A stiff drink. A little mascara. A lot of nerve. Who said they couldn't bring down the Soviet empire.", 'released': 2007}> size=1>>
# <Record p=<Path start=<Node id=96 labels={'Person'} properties={'name': 'Mike Nichols', 'born': 1931}> end=<Node id=159 labels={'Movie'} properties={'title': "Charlie Wilson's War", 'tagline': "A stiff drink. A little mascara. A lot of nerve. Who said they couldn't bring down the Soviet empire.", 'released': 2007}> size=1>>
# <Record p=<Path start=<Node id=159 labels={'Movie'} properties={'title': "Charlie Wilson's War", 'tagline': "A stiff drink. A little mascara. A lot of nerve. Who said they couldn't bring down the Soviet empire.", 'released': 2007}> end=<Node id=160 labels={'Person'} properties={'name': 'Julia Roberts', 'born': 1967}> size=1>>
# <Record p=<Path start=<Node id=71 labels={'Person'} properties={'name': 'Tom Hanks', 'born': 1956}> end=<Node id=161 labels={'Movie'} properties={'title': 'The Polar Express', 'tagline': 'This Holiday Season… Believe', 'released': 2004}> size=1>>
# <Record p=<Path start=<Node id=151 labels={'Person'} properties={'name': 'Robert Zemeckis', 'born': 1951}> end=<Node id=161 labels={'Movie'} properties={'title': 'The Polar Express', 'tagline': 'This Holiday Season… Believe', 'released': 2004}> size=1>>
# <Record p=<Path start=<Node id=166 labels={'Person'} properties={'name': 'Penny Marshall', 'born': 1943}> end=<Node id=162 labels={'Movie'} properties={'title': 'A League of Their Own', 'tagline': 'Once in a lifetime you get a chance to do something different.', 'released': 1992}> size=1>>
# <Record p=<Path start=<Node id=71 labels={'Person'} properties={'name': 'Tom Hanks', 'born': 1956}> end=<Node id=162 labels={'Movie'} properties={'title': 'A League of Their Own', 'tagline': 'Once in a lifetime you get a chance to do something different.', 'released': 1992}> size=1>>
# <Record p=<Path start=<Node id=164 labels={'Person'} properties={'name': 'Geena Davis', 'born': 1956}> end=<Node id=162 labels={'Movie'} properties={'title': 'A League of Their Own', 'tagline': 'Once in a lifetime you get a chance to do something different.', 'released': 1992}> size=1>>
# <Record p=<Path start=<Node id=165 labels={'Person'} properties={'name': 'Lori Petty', 'born': 1963}> end=<Node id=162 labels={'Movie'} properties={'title': 'A League of Their Own', 'tagline': 'Once in a lifetime you get a chance to do something different.', 'released': 1992}> size=1>>
# <Record p=<Path start=<Node id=77 labels={'Person'} properties={'name': "Rosie O'Donnell", 'born': 1962}> end=<Node id=162 labels={'Movie'} properties={'title': 'A League of Their Own', 'tagline': 'Once in a lifetime you get a chance to do something different.', 'released': 1992}> size=1>>
# <Record p=<Path start=<Node id=163 labels={'Person'} properties={'name': 'Madonna', 'born': 1954}> end=<Node id=162 labels={'Movie'} properties={'title': 'A League of Their Own', 'tagline': 'Once in a lifetime you get a chance to do something different.', 'released': 1992}> size=1>>
# <Record p=<Path start=<Node id=146 labels={'Person'} properties={'name': 'Bill Paxton', 'born': 1955}> end=<Node id=162 labels={'Movie'} properties={'title': 'A League of Their Own', 'tagline': 'Once in a lifetime you get a chance to do something different.', 'released': 1992}> size=1>>
# <Record p=<Path start=<Node id=162 labels={'Movie'} properties={'title': 'A League of Their Own', 'tagline': 'Once in a lifetime you get a chance to do something different.', 'released': 1992}> end=<Node id=163 labels={'Person'} properties={'name': 'Madonna', 'born': 1954}> size=1>>
# <Record p=<Path start=<Node id=162 labels={'Movie'} properties={'title': 'A League of Their Own', 'tagline': 'Once in a lifetime you get a chance to do something different.', 'released': 1992}> end=<Node id=164 labels={'Person'} properties={'name': 'Geena Davis', 'born': 1956}> size=1>>
# <Record p=<Path start=<Node id=162 labels={'Movie'} properties={'title': 'A League of Their Own', 'tagline': 'Once in a lifetime you get a chance to do something different.', 'released': 1992}> end=<Node id=165 labels={'Person'} properties={'name': 'Lori Petty', 'born': 1963}> size=1>>
# <Record p=<Path start=<Node id=162 labels={'Movie'} properties={'title': 'A League of Their Own', 'tagline': 'Once in a lifetime you get a chance to do something different.', 'released': 1992}> end=<Node id=166 labels={'Person'} properties={'name': 'Penny Marshall', 'born': 1943}> size=1>>
# <Record p=<Path start=<Node id=168 labels={'Person'} properties={'name': 'Angela Scope'}> end=<Node id=167 labels={'Person'} properties={'name': 'Paul Blythe'}> size=1>>
# <Record p=<Path start=<Node id=167 labels={'Person'} properties={'name': 'Paul Blythe'}> end=<Node id=168 labels={'Person'} properties={'name': 'Angela Scope'}> size=1>>
# <Record p=<Path start=<Node id=169 labels={'Person'} properties={'name': 'Jessica Thompson'}> end=<Node id=168 labels={'Person'} properties={'name': 'Angela Scope'}> size=1>>
# <Record p=<Path start=<Node id=87 labels={'Movie'} properties={'title': 'The Replacements', 'tagline': 'Pain heals, Chicks dig scars... Glory lasts forever', 'released': 2000}> end=<Node id=168 labels={'Person'} properties={'name': 'Angela Scope'}> size=1>>
# <Record p=<Path start=<Node id=170 labels={'Person'} properties={'name': 'James Thompson'}> end=<Node id=169 labels={'Person'} properties={'name': 'Jessica Thompson'}> size=1>>
# <Record p=<Path start=<Node id=168 labels={'Person'} properties={'name': 'Angela Scope'}> end=<Node id=169 labels={'Person'} properties={'name': 'Jessica Thompson'}> size=1>>
# <Record p=<Path start=<Node id=87 labels={'Movie'} properties={'title': 'The Replacements', 'tagline': 'Pain heals, Chicks dig scars... Glory lasts forever', 'released': 2000}> end=<Node id=169 labels={'Person'} properties={'name': 'Jessica Thompson'}> size=1>>
# <Record p=<Path start=<Node id=105 labels={'Movie'} properties={'title': 'Cloud Atlas', 'tagline': 'Everything is connected', 'released': 2012}> end=<Node id=169 labels={'Person'} properties={'name': 'Jessica Thompson'}> size=1>>
# <Record p=<Path start=<Node id=95 labels={'Movie'} properties={'title': 'The Birdcage', 'tagline': 'Come as you are', 'released': 1996}> end=<Node id=169 labels={'Person'} properties={'name': 'Jessica Thompson'}> size=1>>
# <Record p=<Path start=<Node id=97 labels={'Movie'} properties={'title': 'Unforgiven', 'tagline': "It's a hell of a thing, killing a man", 'released': 1992}> end=<Node id=169 labels={'Person'} properties={'name': 'Jessica Thompson'}> size=1>>
# <Record p=<Path start=<Node id=111 labels={'Movie'} properties={'title': 'The Da Vinci Code', 'tagline': 'Break The Codes', 'released': 2006}> end=<Node id=169 labels={'Person'} properties={'name': 'Jessica Thompson'}> size=1>>
# <Record p=<Path start=<Node id=37 labels={'Movie'} properties={'title': 'Jerry Maguire', 'tagline': 'The rest of his life begins now.', 'released': 2000}> end=<Node id=169 labels={'Person'} properties={'name': 'Jessica Thompson'}> size=1>>
# <Record p=<Path start=<Node id=169 labels={'Person'} properties={'name': 'Jessica Thompson'}> end=<Node id=170 labels={'Person'} properties={'name': 'James Thompson'}> size=1>>
# <Record p=<Path start=<Node id=87 labels={'Movie'} properties={'title': 'The Replacements', 'tagline': 'Pain heals, Chicks dig scars... Glory lasts forever', 'released': 2000}> end=<Node id=170 labels={'Person'} properties={'name': 'James Thompson'}> size=1>>
# <Record p=<Path start=<Node id=111 labels={'Movie'} properties={'title': 'The Da Vinci Code', 'tagline': 'Break The Codes', 'released': 2006}> end=<Node id=170 labels={'Person'} properties={'name': 'James Thompson'}> size=1>>

# %%
type(res)
# Out:
# neo4j.BoltStatementResult

# %%
dir(res)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_hydrant',
#  '_keys',
#  '_records',
#  '_session',
#  '_summary',
#  'attached',
#  'consume',
#  'data',
#  'detach',
#  'graph',
#  'keys',
#  'parameters',
#  'peek',
#  'records',
#  'session',
#  'single',
#  'statement',
#  'summary',
#  'value',
#  'values',
#  'zipper']

# %%
dir(res.graph())
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_node_set_view',
#  '_nodes',
#  '_relationship_set_view',
#  '_relationship_types',
#  '_relationships',
#  'nodes',
#  'put_node',
#  'put_relationship',
#  'relationship_type',
#  'relationships']

# %%
list(res.graph().nodes)
# Out:
# [<Node id=8 labels={'Person'} properties={'name': 'Emil Eifrem', 'born': 1978}>,
#  <Node id=0 labels={'Movie'} properties={'title': 'The Matrix', 'tagline': 'Welcome to the Real World', 'released': 1999}>,
#  <Node id=7 labels={'Person'} properties={'name': 'Joel Silver', 'born': 1952}>,
#  <Node id=6 labels={'Person'} properties={'name': 'Lana Wachowski', 'born': 1965}>,
#  <Node id=5 labels={'Person'} properties={'name': 'Lilly Wachowski', 'born': 1967}>,
#  <Node id=4 labels={'Person'} properties={'name': 'Hugo Weaving', 'born': 1960}>,
#  <Node id=3 labels={'Person'} properties={'name': 'Laurence Fishburne', 'born': 1961}>,
#  <Node id=2 labels={'Person'} properties={'name': 'Carrie-Anne Moss', 'born': 1967}>,
#  <Node id=1 labels={'Person'} properties={'name': 'Keanu Reeves', 'born': 1964}>,
#  <Node id=154 labels={'Movie'} properties={'title': "Something's Gotta Give", 'released': 2003}>,
#  <Node id=100 labels={'Movie'} properties={'title': 'Johnny Mnemonic', 'tagline': 'The hottest data on earth. In the coolest head in town', 'released': 1995}>,
#  <Node id=87 labels={'Movie'} properties={'title': 'The Replacements', 'tagline': 'Pain heals, Chicks dig scars... Glory lasts forever', 'released': 2000}>,
#  <Node id=11 labels={'Movie'} properties={'title': "The Devil's Advocate", 'tagline': 'Evil has its winning ways', 'released': 1997}>,
#  <Node id=10 labels={'Movie'} properties={'title': 'The Matrix Revolutions', 'tagline': 'Everything that has a beginning has an end', 'released': 2003}>,
#  <Node id=9 labels={'Movie'} properties={'title': 'The Matrix Reloaded', 'tagline': 'Free your mind', 'released': 2003}>,
#  <Node id=116 labels={'Movie'} properties={'title': 'V for Vendetta', 'tagline': 'Freedom! Forever!', 'released': 2006}>,
#  <Node id=105 labels={'Movie'} properties={'title': 'Cloud Atlas', 'tagline': 'Everything is connected', 'released': 2012}>,
#  <Node id=128 labels={'Movie'} properties={'title': 'Ninja Assassin', 'tagline': 'Prepare to enter a secret world of assassins', 'released': 2009}>,
#  <Node id=121 labels={'Movie'} properties={'title': 'Speed Racer', 'tagline': 'Speed has no limits', 'released': 2008}>,
#  <Node id=13 labels={'Person'} properties={'name': 'Al Pacino', 'born': 1940}>,
#  <Node id=14 labels={'Person'} properties={'name': 'Taylor Hackford', 'born': 1944}>,
#  <Node id=12 labels={'Person'} properties={'name': 'Charlize Theron', 'born': 1975}>,
#  <Node id=85 labels={'Movie'} properties={'title': 'That Thing You Do', 'tagline': 'In every life there comes a time when that thing you dream becomes that thing you do', 'released': 1996}>,
#  <Node id=28 labels={'Person'} properties={'name': 'Aaron Sorkin', 'born': 1961}>,
#  <Node id=15 labels={'Movie'} properties={'title': 'A Few Good Men', 'tagline': "In the heart of the nation's capital, in a courthouse of the U.S. government, one man will stop at nothing to keep his honor, and one will stop at nothing to find the truth.", 'released': 1992}>,
#  <Node id=26 labels={'Person'} properties={'name': 'Christopher Guest', 'born': 1948}>,
#  <Node id=27 labels={'Person'} properties={'name': 'Rob Reiner', 'born': 1947}>,
#  <Node id=23 labels={'Person'} properties={'name': 'Kevin Pollak', 'born': 1957}>,
#  <Node id=22 labels={'Person'} properties={'name': 'Cuba Gooding Jr.', 'born': 1968}>,
#  <Node id=25 labels={'Person'} properties={'name': 'James Marshall', 'born': 1967}>,
#  <Node id=24 labels={'Person'} properties={'name': 'J.T. Walsh', 'born': 1943}>,
#  <Node id=20 labels={'Person'} properties={'name': 'Kiefer Sutherland', 'born': 1966}>,
#  <Node id=21 labels={'Person'} properties={'name': 'Noah Wyle', 'born': 1971}>,
#  <Node id=18 labels={'Person'} properties={'name': 'Demi Moore', 'born': 1962}>,
#  <Node id=19 labels={'Person'} properties={'name': 'Kevin Bacon', 'born': 1958}>,
#  <Node id=16 labels={'Person'} properties={'name': 'Tom Cruise', 'born': 1962}>,
#  <Node id=17 labels={'Person'} properties={'name': 'Jack Nicholson', 'born': 1937}>,
#  <Node id=37 labels={'Movie'} properties={'title': 'Jerry Maguire', 'tagline': 'The rest of his life begins now.', 'released': 2000}>,
#  <Node id=29 labels={'Movie'} properties={'title': 'Top Gun', 'tagline': 'I feel the need, the need for speed.', 'released': 1986}>,
#  <Node id=152 labels={'Movie'} properties={'title': "One Flew Over the Cuckoo's Nest", 'tagline': "If he's crazy, what does that make you?", 'released': 1975}>,
#  <Node id=141 labels={'Movie'} properties={'title': 'Hoffa', 'tagline': "He didn't want law. He wanted justice.", 'released': 1992}>,
#  <Node id=52 labels={'Movie'} properties={'title': 'As Good as It Gets', 'tagline': 'A comedy from the heart that goes for the throat.', 'released': 1997}>,
#  <Node id=137 labels={'Movie'} properties={'title': 'Frost/Nixon', 'tagline': '400 million people were waiting for the truth.', 'released': 2008}>,
#  <Node id=144 labels={'Movie'} properties={'title': 'Apollo 13', 'tagline': 'Houston, we have a problem.', 'released': 1995}>,
#  <Node id=46 labels={'Movie'} properties={'title': 'Stand By Me', 'tagline': "For some, it's the last real taste of innocence, and the first real taste of life. But for everyone, it's the time that memories are made of.", 'released': 1986}>,
#  <Node id=56 labels={'Movie'} properties={'title': 'What Dreams May Come', 'tagline': 'After life there is more. The end is just the beginning.', 'released': 1998}>,
#  <Node id=81 labels={'Movie'} properties={'title': 'When Harry Met Sally', 'tagline': 'At odds in life... in love on-line.', 'released': 1998}>,
#  <Node id=34 labels={'Person'} properties={'name': 'Meg Ryan', 'born': 1961}>,
#  <Node id=33 labels={'Person'} properties={'name': 'Tom Skerritt', 'born': 1933}>,
#  <Node id=36 labels={'Person'} properties={'name': 'Jim Cash', 'born': 1941}>,
#  <Node id=35 labels={'Person'} properties={'name': 'Tony Scott', 'born': 1944}>,
#  <Node id=30 labels={'Person'} properties={'name': 'Kelly McGillis', 'born': 1957}>,
#  <Node id=32 labels={'Person'} properties={'name': 'Anthony Edwards', 'born': 1962}>,
#  <Node id=31 labels={'Person'} properties={'name': 'Val Kilmer', 'born': 1959}>,
#  <Node id=78 labels={'Movie'} properties={'title': 'Joe Versus the Volcano', 'tagline': 'A story of love, lava and burning desire.', 'released': 1990}>,
#  <Node id=73 labels={'Movie'} properties={'title': 'Sleepless in Seattle', 'tagline': 'What if someone you never met, someone you never saw, someone you never knew was the only someone for you?', 'released': 1993}>,
#  <Node id=67 labels={'Movie'} properties={'title': "You've Got Mail", 'tagline': 'At odds in life... in love on-line.', 'released': 1998}>,
#  <Node id=169 labels={'Person'} properties={'name': 'Jessica Thompson'}>,
#  <Node id=44 labels={'Person'} properties={'name': 'Jonathan Lipnicki', 'born': 1996}>,
#  <Node id=45 labels={'Person'} properties={'name': 'Cameron Crowe', 'born': 1957}>,
#  <Node id=40 labels={'Person'} properties={'name': "Jerry O'Connell", 'born': 1974}>,
#  <Node id=41 labels={'Person'} properties={'name': 'Jay Mohr', 'born': 1970}>,
#  <Node id=42 labels={'Person'} properties={'name': 'Bonnie Hunt', 'born': 1961}>,
#  <Node id=43 labels={'Person'} properties={'name': 'Regina King', 'born': 1971}>,
#  <Node id=38 labels={'Person'} properties={'name': 'Renee Zellweger', 'born': 1969}>,
#  <Node id=39 labels={'Person'} properties={'name': 'Kelly Preston', 'born': 1962}>,
#  <Node id=130 labels={'Movie'} properties={'title': 'The Green Mile', 'tagline': "Walk a mile you'll never forget.", 'released': 1999}>,
#  <Node id=51 labels={'Person'} properties={'name': 'Marshall Bell', 'born': 1942}>,
#  <Node id=50 labels={'Person'} properties={'name': 'John Cusack', 'born': 1966}>,
#  <Node id=49 labels={'Person'} properties={'name': 'Wil Wheaton', 'born': 1972}>,
#  <Node id=47 labels={'Person'} properties={'name': 'River Phoenix', 'born': 1970}>,
#  <Node id=48 labels={'Person'} properties={'name': 'Corey Feldman', 'born': 1971}>,
#  <Node id=92 labels={'Movie'} properties={'title': 'RescueDawn', 'tagline': "Based on the extraordinary true story of one man's fight for freedom", 'released': 2006}>,
#  <Node id=55 labels={'Person'} properties={'name': 'James L. Brooks', 'born': 1940}>,
#  <Node id=54 labels={'Person'} properties={'name': 'Greg Kinnear', 'born': 1963}>,
#  <Node id=53 labels={'Person'} properties={'name': 'Helen Hunt', 'born': 1963}>,
#  <Node id=147 labels={'Movie'} properties={'title': 'Twister', 'tagline': "Don't Breathe. Don't Look Back.", 'released': 1996}>,
#  <Node id=150 labels={'Movie'} properties={'title': 'Cast Away', 'tagline': 'At the edge of the world, his journey begins.', 'released': 2000}>,
#  <Node id=57 labels={'Person'} properties={'name': 'Annabella Sciorra', 'born': 1960}>,
#  <Node id=60 labels={'Person'} properties={'name': 'Robin Williams', 'born': 1951}>,
#  <Node id=61 labels={'Person'} properties={'name': 'Vincent Ward', 'born': 1956}>,
#  <Node id=59 labels={'Person'} properties={'name': 'Werner Herzog', 'born': 1942}>,
#  <Node id=58 labels={'Person'} properties={'name': 'Max von Sydow', 'born': 1929}>,
#  <Node id=62 labels={'Movie'} properties={'title': 'Snow Falling on Cedars', 'tagline': 'First loves last. Forever.', 'released': 1999}>,
#  <Node id=157 labels={'Movie'} properties={'title': 'Bicentennial Man', 'tagline': "One robot's 200 year journey to become an ordinary man.", 'released': 1999}>,
#  <Node id=95 labels={'Movie'} properties={'title': 'The Birdcage', 'tagline': 'Come as you are', 'released': 1996}>,
#  <Node id=65 labels={'Person'} properties={'name': 'James Cromwell', 'born': 1940}>,
#  <Node id=66 labels={'Person'} properties={'name': 'Scott Hicks', 'born': 1953}>,
#  <Node id=64 labels={'Person'} properties={'name': 'Rick Yune', 'born': 1971}>,
#  <Node id=63 labels={'Person'} properties={'name': 'Ethan Hawke', 'born': 1970}>,
#  <Node id=72 labels={'Person'} properties={'name': 'Nora Ephron', 'born': 1941}>,
#  <Node id=69 labels={'Person'} properties={'name': 'Dave Chappelle', 'born': 1973}>,
#  <Node id=70 labels={'Person'} properties={'name': 'Steve Zahn', 'born': 1967}>,
#  <Node id=68 labels={'Person'} properties={'name': 'Parker Posey', 'born': 1968}>,
#  <Node id=71 labels={'Person'} properties={'name': 'Tom Hanks', 'born': 1956}>,
#  <Node id=159 labels={'Movie'} properties={'title': "Charlie Wilson's War", 'tagline': "A stiff drink. A little mascara. A lot of nerve. Who said they couldn't bring down the Soviet empire.", 'released': 2007}>,
#  <Node id=161 labels={'Movie'} properties={'title': 'The Polar Express', 'tagline': 'This Holiday Season… Believe', 'released': 2004}>,
#  <Node id=162 labels={'Movie'} properties={'title': 'A League of Their Own', 'tagline': 'Once in a lifetime you get a chance to do something different.', 'released': 1992}>,
#  <Node id=111 labels={'Movie'} properties={'title': 'The Da Vinci Code', 'tagline': 'Break The Codes', 'released': 2006}>,
#  <Node id=77 labels={'Person'} properties={'name': "Rosie O'Donnell", 'born': 1962}>,
#  <Node id=75 labels={'Person'} properties={'name': 'Bill Pullman', 'born': 1953}>,
#  <Node id=76 labels={'Person'} properties={'name': 'Victor Garber', 'born': 1949}>,
#  <Node id=74 labels={'Person'} properties={'name': 'Rita Wilson', 'born': 1956}>,
#  <Node id=79 labels={'Person'} properties={'name': 'John Patrick Stanley', 'born': 1950}>,
#  <Node id=80 labels={'Person'} properties={'name': 'Nathan Lane', 'born': 1956}>,
#  <Node id=84 labels={'Person'} properties={'name': 'Bruno Kirby', 'born': 1949}>,
#  <Node id=83 labels={'Person'} properties={'name': 'Carrie Fisher', 'born': 1956}>,
#  <Node id=82 labels={'Person'} properties={'name': 'Billy Crystal', 'born': 1948}>,
#  <Node id=86 labels={'Person'} properties={'name': 'Liv Tyler', 'born': 1977}>,
#  <Node id=168 labels={'Person'} properties={'name': 'Angela Scope'}>,
#  <Node id=170 labels={'Person'} properties={'name': 'James Thompson'}>,
#  <Node id=88 labels={'Person'} properties={'name': 'Brooke Langton', 'born': 1970}>,
#  <Node id=89 labels={'Person'} properties={'name': 'Gene Hackman', 'born': 1930}>,
#  <Node id=90 labels={'Person'} properties={'name': 'Orlando Jones', 'born': 1968}>,
#  <Node id=91 labels={'Person'} properties={'name': 'Howard Deutch', 'born': 1950}>,
#  <Node id=97 labels={'Movie'} properties={'title': 'Unforgiven', 'tagline': "It's a hell of a thing, killing a man", 'released': 1992}>,
#  <Node id=93 labels={'Person'} properties={'name': 'Christian Bale', 'born': 1974}>,
#  <Node id=94 labels={'Person'} properties={'name': 'Zach Grenier', 'born': 1954}>,
#  <Node id=96 labels={'Person'} properties={'name': 'Mike Nichols', 'born': 1931}>,
#  <Node id=99 labels={'Person'} properties={'name': 'Clint Eastwood', 'born': 1930}>,
#  <Node id=98 labels={'Person'} properties={'name': 'Richard Harris', 'born': 1930}>,
#  <Node id=102 labels={'Person'} properties={'name': 'Dina Meyer', 'born': 1968}>,
#  <Node id=103 labels={'Person'} properties={'name': 'Ice-T', 'born': 1958}>,
#  <Node id=101 labels={'Person'} properties={'name': 'Takeshi Kitano', 'born': 1947}>,
#  <Node id=104 labels={'Person'} properties={'name': 'Robert Longo', 'born': 1953}>,
#  <Node id=110 labels={'Person'} properties={'name': 'Stefan Arndt', 'born': 1961}>,
#  <Node id=109 labels={'Person'} properties={'name': 'David Mitchell', 'born': 1969}>,
#  <Node id=107 labels={'Person'} properties={'name': 'Jim Broadbent', 'born': 1949}>,
#  <Node id=108 labels={'Person'} properties={'name': 'Tom Tykwer', 'born': 1965}>,
#  <Node id=106 labels={'Person'} properties={'name': 'Halle Berry', 'born': 1966}>,
#  <Node id=115 labels={'Person'} properties={'name': 'Ron Howard', 'born': 1954}>,
#  <Node id=114 labels={'Person'} properties={'name': 'Paul Bettany', 'born': 1971}>,
#  <Node id=113 labels={'Person'} properties={'name': 'Audrey Tautou', 'born': 1976}>,
#  <Node id=112 labels={'Person'} properties={'name': 'Ian McKellen', 'born': 1939}>,
#  <Node id=120 labels={'Person'} properties={'name': 'Ben Miles', 'born': 1967}>,
#  <Node id=119 labels={'Person'} properties={'name': 'John Hurt', 'born': 1940}>,
#  <Node id=118 labels={'Person'} properties={'name': 'Stephen Rea', 'born': 1946}>,
#  <Node id=117 labels={'Person'} properties={'name': 'Natalie Portman', 'born': 1981}>,
#  <Node id=124 labels={'Person'} properties={'name': 'Susan Sarandon', 'born': 1946}>,
#  <Node id=125 labels={'Person'} properties={'name': 'Matthew Fox', 'born': 1966}>,
#  <Node id=126 labels={'Person'} properties={'name': 'Christina Ricci', 'born': 1980}>,
#  <Node id=127 labels={'Person'} properties={'name': 'Rain', 'born': 1982}>,
#  <Node id=122 labels={'Person'} properties={'name': 'Emile Hirsch', 'born': 1985}>,
#  <Node id=123 labels={'Person'} properties={'name': 'John Goodman', 'born': 1960}>,
#  <Node id=129 labels={'Person'} properties={'name': 'Naomie Harris'}>,
#  <Node id=131 labels={'Person'} properties={'name': 'Michael Clarke Duncan', 'born': 1957}>,
#  <Node id=135 labels={'Person'} properties={'name': 'Patricia Clarkson', 'born': 1959}>,
#  <Node id=134 labels={'Person'} properties={'name': 'Gary Sinise', 'born': 1955}>,
#  <Node id=136 labels={'Person'} properties={'name': 'Frank Darabont', 'born': 1959}>,
#  <Node id=132 labels={'Person'} properties={'name': 'David Morse', 'born': 1953}>,
#  <Node id=133 labels={'Person'} properties={'name': 'Sam Rockwell', 'born': 1968}>,
#  <Node id=140 labels={'Person'} properties={'name': 'Oliver Platt', 'born': 1960}>,
#  <Node id=139 labels={'Person'} properties={'name': 'Michael Sheen', 'born': 1969}>,
#  <Node id=138 labels={'Person'} properties={'name': 'Frank Langella', 'born': 1938}>,
#  <Node id=142 labels={'Person'} properties={'name': 'Danny DeVito', 'born': 1944}>,
#  <Node id=143 labels={'Person'} properties={'name': 'John C. Reilly', 'born': 1965}>,
#  <Node id=145 labels={'Person'} properties={'name': 'Ed Harris', 'born': 1950}>,
#  <Node id=146 labels={'Person'} properties={'name': 'Bill Paxton', 'born': 1955}>,
#  <Node id=148 labels={'Person'} properties={'name': 'Philip Seymour Hoffman', 'born': 1967}>,
#  <Node id=149 labels={'Person'} properties={'name': 'Jan de Bont', 'born': 1943}>,
#  <Node id=151 labels={'Person'} properties={'name': 'Robert Zemeckis', 'born': 1951}>,
#  <Node id=153 labels={'Person'} properties={'name': 'Milos Forman', 'born': 1932}>,
#  <Node id=156 labels={'Person'} properties={'name': 'Nancy Meyers', 'born': 1949}>,
#  <Node id=155 labels={'Person'} properties={'name': 'Diane Keaton', 'born': 1946}>,
#  <Node id=158 labels={'Person'} properties={'name': 'Chris Columbus', 'born': 1958}>,
#  <Node id=160 labels={'Person'} properties={'name': 'Julia Roberts', 'born': 1967}>,
#  <Node id=166 labels={'Person'} properties={'name': 'Penny Marshall', 'born': 1943}>,
#  <Node id=164 labels={'Person'} properties={'name': 'Geena Davis', 'born': 1956}>,
#  <Node id=165 labels={'Person'} properties={'name': 'Lori Petty', 'born': 1963}>,
#  <Node id=163 labels={'Person'} properties={'name': 'Madonna', 'born': 1954}>,
#  <Node id=167 labels={'Person'} properties={'name': 'Paul Blythe'}>]

# %% [markdown]
# More Docus on drivers
#
# https://neo4j.com/docs/developer-manual/current/drivers/cypher-values/

# %%
list(res)
# Out:
# []

# %%
gr = res.graph()

# %%
type(gr)
# Out:
# neo4j.types.graph.Graph

# %%
import networkx as nx

# %%
nx.draw(gr)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-18-0b116fd82f6e> in <module>()
# ----> 1 nx.draw(gr)
#
# C:\ProgramData\Anaconda3\lib\site-packages\networkx\drawing\nx_pylab.py in draw(G, pos, ax, **kwds)
#     124
#     125     try:
# --> 126         draw_networkx(G, pos=pos, ax=ax, **kwds)
#     127         ax.set_axis_off()
#     128         plt.draw_if_interactive()
#
# C:\ProgramData\Anaconda3\lib\site-packages\networkx\drawing\nx_pylab.py in draw_networkx(G, pos, arrows, with_labels, **kwds)
#     273
#     274     if pos is None:
# --> 275         pos = nx.drawing.spring_layout(G)  # default to spring layout
#     276
#     277     node_collection = draw_networkx_nodes(G, pos, **kwds)
#
# <decorator-gen-597> in fruchterman_reingold_layout(G, k, pos, fixed, iterations, threshold, weight, scale, center, dim, random_state)
#
# C:\ProgramData\Anaconda3\lib\site-packages\networkx\utils\decorators.py in _random_state(func, *args, **kwargs)
#     385         new_args = list(args)
#     386         new_args[random_state_index] = random_state_instance
# --> 387         return func(*new_args, **kwargs)
#     388     return _random_state
#
# C:\ProgramData\Anaconda3\lib\site-packages\networkx\drawing\layout.py in fruchterman_reingold_layout(G, k, pos, fixed, iterations, threshold, weight, scale, center, dim, random_state)
#     315     import numpy as np
#     316
# --> 317     G, center = _process_params(G, center, dim)
#     318
#     319     if fixed is not None:
#
# C:\ProgramData\Anaconda3\lib\site-packages\networkx\drawing\layout.py in _process_params(G, center, dim)
#      46     if not isinstance(G, nx.Graph):
#      47         empty_graph = nx.Graph()
# ---> 48         empty_graph.add_nodes_from(G)
#      49         G = empty_graph
#      50
#
# C:\ProgramData\Anaconda3\lib\site-packages\networkx\classes\graph.py in add_nodes_from(self, nodes_for_adding, **attr)
#     529
#     530         """
# --> 531         for n in nodes_for_adding:
#     532             # keep all this inside try/except because
#     533             # CPython throws TypeError on n not in self._node,
#
# TypeError: 'Graph' object is not iterable

# %%
# !pip install ipython-cypher
# Out:
# Collecting ipython-cypher
#   Downloading https://files.pythonhosted.org/packages/93/a3/de64e243a1a3d791e21e90a524ac4ac87c33192671897fc90efee54ad38d/ipython-cypher-0.2.6.tar.gz
# Collecting neo4jrestclient>=2.1.0 (from ipython-cypher)
#   Downloading https://files.pythonhosted.org/packages/95/4c/df54ba57f5838fd1ae162462f81d589b8352c6aa17d5b2a7a42e8abba048/neo4jrestclient-2.1.1.tar.gz (73kB)
# Collecting prettytable (from ipython-cypher)
#   Downloading https://files.pythonhosted.org/packages/ef/30/4b0746848746ed5941f052479e7c23d2b56d174b82f4fd34a25e389831f5/prettytable-0.7.2.tar.bz2
# Requirement already satisfied: ipython>=1.0 in c:\programdata\anaconda3\lib\site-packages (from ipython-cypher)
# Requirement already satisfied: requests>=2.1.0 in c:\programdata\anaconda3\lib\site-packages (from neo4jrestclient>=2.1.0->ipython-cypher)
# Requirement already satisfied: setuptools>=18.5 in c:\programdata\anaconda3\lib\site-packages (from ipython>=1.0->ipython-cypher)
# Requirement already satisfied: jedi>=0.10 in c:\programdata\anaconda3\lib\site-packages (from ipython>=1.0->ipython-cypher)
# Requirement already satisfied: decorator in c:\programdata\anaconda3\lib\site-packages (from ipython>=1.0->ipython-cypher)
# Requirement already satisfied: pickleshare in c:\programdata\anaconda3\lib\site-packages (from ipython>=1.0->ipython-cypher)
# Requirement already satisfied: simplegeneric>0.8 in c:\programdata\anaconda3\lib\site-packages (from ipython>=1.0->ipython-cypher)
# Requirement already satisfied: traitlets>=4.2 in c:\programdata\anaconda3\lib\site-packages (from ipython>=1.0->ipython-cypher)
# Requirement already satisfied: prompt_toolkit<2.0.0,>=1.0.4 in c:\programdata\anaconda3\lib\site-packages (from ipython>=1.0->ipython-cypher)
# Requirement already satisfied: pygments in c:\programdata\anaconda3\lib\site-packages (from ipython>=1.0->ipython-cypher)
# Requirement already satisfied: colorama in c:\programdata\anaconda3\lib\site-packages (from ipython>=1.0->ipython-cypher)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\programdata\anaconda3\lib\site-packages (from requests>=2.1.0->neo4jrestclient>=2.1.0->ipython-cypher)
# Requirement already satisfied: idna<2.7,>=2.5 in c:\programdata\anaconda3\lib\site-packages (from requests>=2.1.0->neo4jrestclient>=2.1.0->ipython-cypher)
# Requirement already satisfied: urllib3<1.23,>=1.21.1 in c:\programdata\anaconda3\lib\site-packages (from requests>=2.1.0->neo4jrestclient>=2.1.0->ipython-cypher)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\lib\site-packages (from requests>=2.1.0->neo4jrestclient>=2.1.0->ipython-cypher)
# Requirement already satisfied: parso==0.1.* in c:\programdata\anaconda3\lib\site-packages (from jedi>=0.10->ipython>=1.0->ipython-cypher)
# Requirement already satisfied: ipython_genutils in c:\programdata\anaconda3\lib\site-packages (from traitlets>=4.2->ipython>=1.0->ipython-cypher)
# Requirement already satisfied: six in c:\programdata\anaconda3\lib\site-packages (from traitlets>=4.2->ipython>=1.0->ipython-cypher)
# Requirement already satisfied: wcwidth in c:\programdata\anaconda3\lib\site-packages (from prompt_toolkit<2.0.0,>=1.0.4->ipython>=1.0->ipython-cypher)
# Building wheels for collected packages: ipython-cypher, neo4jrestclient, prettytable
#   Running setup.py bdist_wheel for ipython-cypher: started
#   Running setup.py bdist_wheel for ipython-cypher: finished with status 'done'
#   Stored in directory: C:\Users\Val\AppData\Local\pip\Cache\wheels\0e\1e\65\1e0128677b6e6483b90894965f43dd078966270d3dda930044
#   Running setup.py bdist_wheel for neo4jrestclient: started
#   Running setup.py bdist_wheel for neo4jrestclient: finished with status 'done'
#   Stored in directory: C:\Users\Val\AppData\Local\pip\Cache\wheels\0f\db\72\c3f14a1e15e0adfa09c1bc3c163b15e5730c36516c5fce2f9b
#   Running setup.py bdist_wheel for prettytable: started
#   Running setup.py bdist_wheel for prettytable: finished with status 'done'
#   Stored in directory: C:\Users\Val\AppData\Local\pip\Cache\wheels\80\34\1c\3967380d9676d162cb59513bd9dc862d0584e045a162095606
# Successfully built ipython-cypher neo4jrestclient prettytable
# Installing collected packages: neo4jrestclient, prettytable, ipython-cypher
# Successfully installed ipython-cypher-0.2.6 neo4jrestclient-2.1.1 prettytable-0.7.2
# You are using pip version 9.0.1, however version 19.0.1 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.

# %%
# https://stackoverflow.com/questions/33535018/easiest-way-to-draw-a-full-neo4j-graph-in-networkx

# %%
# %load_ext cypher
# %matplotlib inline

# %%
results = %cypher https://rcs-u1:willshowinclass@hobby-ggackoeempicgbkeooibgpbl.dbs.graphenedb.com:24780/db/data/ MATCH p = ()-[]-() RETURN p
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# 506 rows affected.

# %%
g = results.get_graph()

# %%
nx.draw(g)

# %%
results = %cypher MATCH p = ()-[]-() RETURN p
# of course this will not work on an external database without auth
# Out:
# Format: (http|https)://username:password@hostname:port/db/name
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     140             conn = connection.create_connection(
# --> 141                 (self.host, self.port), self.timeout, **extra_kw)
#     142
#
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      82     if err is not None:
# ---> 83         raise err
#      84
#
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      72                 sock.bind(source_address)
# ---> 73             sock.connect(sa)
#      74             return sock
#
# ConnectionRefusedError: [WinError 10061] No connection could be made because the target machine actively refused it
#
# During handling of the above exception, another exception occurred:
#
# NewConnectionError                        Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     600                                                   body=body, headers=headers,
# --> 601                                                   chunked=chunked)
#     602
#
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     356         else:
# --> 357             conn.request(method, url, **httplib_request_kw)
#     358
#
# C:\ProgramData\Anaconda3\lib\http\client.py in request(self, method, url, body, headers, encode_chunked)
#    1238         """Send a complete request to the server."""
# -> 1239         self._send_request(method, url, body, headers, encode_chunked)
#    1240
#
# C:\ProgramData\Anaconda3\lib\http\client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1284             body = _encode(body, 'body')
# -> 1285         self.endheaders(body, encode_chunked=encode_chunked)
#    1286
#
# C:\ProgramData\Anaconda3\lib\http\client.py in endheaders(self, message_body, encode_chunked)
#    1233             raise CannotSendHeader()
# -> 1234         self._send_output(message_body, encode_chunked=encode_chunked)
#    1235
#
# C:\ProgramData\Anaconda3\lib\http\client.py in _send_output(self, message_body, encode_chunked)
#    1025         del self._buffer[:]
# -> 1026         self.send(msg)
#    1027
#
# C:\ProgramData\Anaconda3\lib\http\client.py in send(self, data)
#     963             if self.auto_open:
# --> 964                 self.connect()
#     965             else:
#
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\connection.py in connect(self)
#     165     def connect(self):
# --> 166         conn = self._new_conn()
#     167         self._prepare_conn(conn)
#
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     149             raise NewConnectionError(
# --> 150                 self, "Failed to establish a new connection: %s" % e)
#     151
#
# NewConnectionError: <urllib3.connection.HTTPConnection object at 0x00000157962A7128>: Failed to establish a new connection: [WinError 10061] No connection could be made because the target machine actively refused it
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     439                     retries=self.max_retries,
# --> 440                     timeout=timeout
#     441                 )
#
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     638             retries = retries.increment(method, url, error=e, _pool=self,
# --> 639                                         _stacktrace=sys.exc_info()[2])
#     640             retries.sleep()
#
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\util\retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     387         if new_retry.is_exhausted():
# --> 388             raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     389
#
# MaxRetryError: HTTPConnectionPool(host='localhost', port=7474): Max retries exceeded with url: /db/data/ (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x00000157962A7128>: Failed to establish a new connection: [WinError 10061] No connection could be made because the target machine actively refused it',))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# <ipython-input-20-03b975d7b356> in <module>()
# ----> 1 results = get_ipython().run_line_magic('cypher', 'MATCH p = ()-[]-() RETURN p')
#       2 # of course this will not work on an external database without auth
#
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py in run_line_magic(self, magic_name, line, _stack_depth)
#    2093                 kwargs['local_ns'] = sys._getframe(stack_depth).f_locals
#    2094             with self.builtin_trap:
# -> 2095                 result = fn(*args,**kwargs)
#    2096             return result
#    2097
#
# <decorator-gen-609> in execute(self, line, cell, local_ns)
#
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# <decorator-gen-608> in execute(self, line, cell, local_ns)
#
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# C:\ProgramData\Anaconda3\lib\site-packages\cypher\magic.py in execute(self, line, cell, local_ns)
#     106         user_ns.update(local_ns)
#     107         parsed = parse("""{0}\n{1}""".format(line, cell), self)
# --> 108         conn = Connection.get(parsed['as'] or parsed['uri'], parsed['as'])
#     109         first_word = parsed['cypher'].split(None, 1)[:1]
#     110         if first_word and first_word[0].lower() == 'persist':
#
# C:\ProgramData\Anaconda3\lib\site-packages\cypher\connection.py in get(cls, descriptor, alias)
#      45                 cls.current = conn
#      46             else:
# ---> 47                 cls.current = Connection(descriptor, alias)
#      48         if cls.current:
#      49             return cls.current
#
# C:\ProgramData\Anaconda3\lib\site-packages\cypher\connection.py in __init__(self, connect_str, alias)
#      24                 gdb = GraphDatabase(self.connections[connect_str])
#      25             else:
# ---> 26                 gdb = GraphDatabase(connect_str)
#      27                 alias = alias or connect_str
#      28         except:
#
# C:\ProgramData\Anaconda3\lib\site-packages\neo4jrestclient\client.py in __init__(self, url, username, password, cert_file, key_file)
#      77         else:
#      78             self.url = "%s/" % url
# ---> 79         response = Request(**self._auth).get(self.url)
#      80         if response.status_code == 200:
#      81             response_json = response.json()
#
# C:\ProgramData\Anaconda3\lib\site-packages\neo4jrestclient\request.py in get(self, url, headers)
#      61         Returns the response object.
#      62         """
# ---> 63         return self._request('GET', url, headers=headers)
#      64
#      65     def post(self, url, data, headers=None):
#
# C:\ProgramData\Anaconda3\lib\site-packages\neo4jrestclient\request.py in _request(self, method, url, data, headers)
#     196             response = getattr(session, method)(root_uri, headers=headers,
#     197                                                 data=data, cert=cert,
# --> 198                                                 auth=auth, verify=verify)
#     199             if response.status_code == 401:
#     200                 raise StatusException(401, "Authorization Required")
#
# C:\ProgramData\Anaconda3\lib\site-packages\requests\sessions.py in get(self, url, **kwargs)
#     519
#     520         kwargs.setdefault('allow_redirects', True)
# --> 521         return self.request('GET', url, **kwargs)
#     522
#     523     def options(self, url, **kwargs):
#
# C:\ProgramData\Anaconda3\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     506         }
#     507         send_kwargs.update(settings)
# --> 508         resp = self.send(prep, **send_kwargs)
#     509
#     510         return resp
#
# C:\ProgramData\Anaconda3\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     616
#     617         # Send the request
# --> 618         r = adapter.send(request, **kwargs)
#     619
#     620         # Total elapsed time of the request (approximately)
#
# C:\ProgramData\Anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     506                 raise SSLError(e, request=request)
#     507
# --> 508             raise ConnectionError(e, request=request)
#     509
#     510         except ClosedPoolError as e:
#
# ConnectionError: HTTPConnectionPool(host='localhost', port=7474): Max retries exceeded with url: /db/data/ (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x00000157962A7128>: Failed to establish a new connection: [WinError 10061] No connection could be made because the target machine actively refused it',))

# %% [markdown]
# # Oficial Cypher Docs
#
# https://neo4j.com/docs/developer-manual/current/cypher/clauses/match/

# %%
# https://neo4j.com/docs/developer-manual/current/cypher/clauses/match/#relationship-basics

# %%
neoq("MATCH (:Person { name: 'Tom Hanks' })-->(movie) RETURN movie.title")
# Out:
# <Record movie.title="Charlie Wilson's War">
# <Record movie.title='The Polar Express'>
# <Record movie.title='A League of Their Own'>
# <Record movie.title='Cast Away'>
# <Record movie.title='Apollo 13'>
# <Record movie.title='The Green Mile'>
# <Record movie.title='The Da Vinci Code'>
# <Record movie.title='Cloud Atlas'>
# <Record movie.title='That Thing You Do'>
# <Record movie.title='That Thing You Do'>
# <Record movie.title='Joe Versus the Volcano'>
# <Record movie.title='Sleepless in Seattle'>
# <Record movie.title="You've Got Mail">

# %%
# Experimental NX library for Neo4J 
# https://medium.com/neo4j/experimental-a-networkx-esque-api-for-neo4j-graph-algorithms-4002baac45be

# %%
# !pip install git+https://github.com/neo4j-graph-analytics/networkx-neo4j.git#egg=networkx-neo4j
# Out:
# Collecting networkx-neo4j from git+https://github.com/neo4j-graph-analytics/networkx-neo4j.git#egg=networkx-neo4j
#   Cloning https://github.com/neo4j-graph-analytics/networkx-neo4j.git to c:\users\vdell\appdata\local\temp\pip-install-7dz8m1b6\networkx-neo4j
# Requirement already satisfied: neo4j-driver in c:\programdata\anaconda3\lib\site-packages (from networkx-neo4j) (1.6.1)
# Requirement already satisfied: neotime==1.0.0 in c:\programdata\anaconda3\lib\site-packages (from neo4j-driver->networkx-neo4j) (1.0.0)
# Requirement already satisfied: pytz in c:\programdata\anaconda3\lib\site-packages (from neotime==1.0.0->neo4j-driver->networkx-neo4j) (2017.3)
# Requirement already satisfied: six in c:\programdata\anaconda3\lib\site-packages (from neotime==1.0.0->neo4j-driver->networkx-neo4j) (1.11.0)
# Building wheels for collected packages: networkx-neo4j
#   Running setup.py bdist_wheel for networkx-neo4j: started
#   Running setup.py bdist_wheel for networkx-neo4j: finished with status 'done'
#   Stored in directory: C:\Users\vdell\AppData\Local\Temp\pip-ephem-wheel-cache-hp1kl4my\wheels\63\5d\88\63d97b85dc980a66b6253526caf0a1ad58ef73abe716a41acf
# Successfully built networkx-neo4j
# Installing collected packages: networkx-neo4j
# Successfully installed networkx-neo4j-0.0.1
# odpdown 0.4.1 requires lpod-python>=1.1.6, which is not installed.
# You are using pip version 10.0.1, however version 18.0 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.

# %%
import nxneo4j

# %%
config = {
    "node_label": "Character",
    "relationship_type": None,
    "identifier_property": "name"
}
G = nxneo4j.Graph(driver, config)

# %%
type(G)
# Out:
# nxneo4j.graph.Graph

# %%
communities = nxneo4j.community.label_propagation_communities(G)
sorted_communities = sorted(communities, key=lambda x: len(x), reverse=True)
for community in sorted_communities[:10]:
    print(list(community)[:10])
# Out:
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# <ipython-input-33-8f8864c5a042> in <module>()
#       1 communities = nxneo4j.community.label_propagation_communities(G)
# ----> 2 sorted_communities = sorted(communities, key=lambda x: len(x), reverse=True)
#       3 for community in sorted_communities[:10]:
#       4     print(list(community)[:10])
#
# C:\ProgramData\Anaconda3\lib\site-packages\nxneo4j\base_graph.py in label_propagation(self)
#     205             query = self.lpa_query % self.identifier_property
#     206
# --> 207             for row in session.run(query, params):
#     208                 yield set(row["nodes"])
#     209
#
# C:\ProgramData\Anaconda3\lib\site-packages\neo4j\v1\api.py in run(self, statement, parameters, **kwparameters)
#     329         if not self.has_transaction():
#     330             self._connection.send()
# --> 331             self._connection.fetch()
#     332
#     333         return result
#
# C:\ProgramData\Anaconda3\lib\site-packages\neo4j\bolt\connection.py in fetch(self)
#     288     def fetch(self):
#     289         try:
# --> 290             return self._fetch()
#     291         except self.error_handler.known_errors as error:
#     292             self.error_handler.handle(error, self.address)
#
# C:\ProgramData\Anaconda3\lib\site-packages\neo4j\bolt\connection.py in _fetch(self)
#     328             self._last_run_statement = None
#     329             log_debug("S: FAILURE (%r)", summary_metadata)
# --> 330             response.on_failure(summary_metadata or {})
#     331         else:
#     332             self._last_run_statement = None
#
# C:\ProgramData\Anaconda3\lib\site-packages\neo4j\v1\result.py in on_failure(metadata)
#      68             self.session._connection.acknowledge_failure()
#      69             on_footer(metadata)
# ---> 70             raise CypherError.hydrate(**metadata)
#      71
#      72         run_response.on_success = on_header
#
# ClientError: There is no procedure with the name `algo.labelPropagation.stream` registered for this database instance. Please ensure you've spelled the procedure name correctly and that the procedure is properly deployed.

# %%
sorted_pagerank = sorted(nxneo4j.centrality.pagerank(G).items(), key=lambda x: x[1], reverse=True)
for character, score in sorted_pagerank[:10]:
    print(character, score)
# Out:
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# <ipython-input-32-446b5130aab6> in <module>()
# ----> 1 sorted_pagerank = sorted(nxneo4j.centrality.pagerank(G).items(), key=lambda x: x[1], reverse=True)
#       2 for character, score in sorted_pagerank[:10]:
#       3     print(character, score)
#
# C:\ProgramData\Anaconda3\lib\site-packages\nxneo4j\centrality.py in pagerank(G, alpha, personalization, max_iter, tol, nstart, weight)
#      29              max_iter=100, tol=1.0e-8, nstart=None, weight='weight'):
#      30     # doesn't currently supported `personalization`, `tol`, `nstart`, `weight`
# ---> 31     return G.pagerank(alpha, max_iter)
#
# C:\ProgramData\Anaconda3\lib\site-packages\nxneo4j\base_graph.py in pagerank(self, alpha, max_iter)
#     148
#     149             query = self.pagerank_query % self.identifier_property
# --> 150             result = {row["node"]: row["score"] for row in session.run(query, params)}
#     151         return result
#     152
#
# C:\ProgramData\Anaconda3\lib\site-packages\neo4j\v1\api.py in run(self, statement, parameters, **kwparameters)
#     329         if not self.has_transaction():
#     330             self._connection.send()
# --> 331             self._connection.fetch()
#     332
#     333         return result
#
# C:\ProgramData\Anaconda3\lib\site-packages\neo4j\bolt\connection.py in fetch(self)
#     288     def fetch(self):
#     289         try:
# --> 290             return self._fetch()
#     291         except self.error_handler.known_errors as error:
#     292             self.error_handler.handle(error, self.address)
#
# C:\ProgramData\Anaconda3\lib\site-packages\neo4j\bolt\connection.py in _fetch(self)
#     328             self._last_run_statement = None
#     329             log_debug("S: FAILURE (%r)", summary_metadata)
# --> 330             response.on_failure(summary_metadata or {})
#     331         else:
#     332             self._last_run_statement = None
#
# C:\ProgramData\Anaconda3\lib\site-packages\neo4j\v1\result.py in on_failure(metadata)
#      68             self.session._connection.acknowledge_failure()
#      69             on_footer(metadata)
# ---> 70             raise CypherError.hydrate(**metadata)
#      71
#      72         run_response.on_success = on_header
#
# ClientError: There is no procedure with the name `algo.pageRank.stream` registered for this database instance. Please ensure you've spelled the procedure name correctly and that the procedure is properly deployed.

# %%
# interesting converting script for Neo4J to NetworkX https://gist.github.com/aanastasiou/6099561

# %% [markdown]
# **Note**: There is REST API but GrapheneDB recommend using their BOLT protocol
#
# https://docs.graphenedb.com/docs/connecting-to-your-database
